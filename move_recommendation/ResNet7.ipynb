# %%
# install libaries if needed

#pip install chess

# %%
import os
import datetime
import chess
import chess.engine
import random
import numpy as np
import math
from tqdm import tqdm
import io
import json
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import display, SVG
from sklearn.preprocessing import MinMaxScaler
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive

# %%
# helper function: download file from Google Drive

def download_from_drive(file_name='lichess_db_eval.jsonl.zst', asset_dir='Mengqi_Input'):
    gauth = GoogleAuth()
    gauth.DEFAULT_SETTINGS['client_config_file'] = 'client_secret_1057507276332-5mk9ac9q22rsmtm1idlqvpraq08ar8p5.apps.googleusercontent.com.json'
    gauth.LoadCredentialsFile("mycreds.txt")
    if gauth.credentials is None:
        gauth.LocalWebserverAuth()
    elif gauth.access_token_expired:
        gauth.Refresh()
    else:
        gauth.Authorize()
    gauth.SaveCredentialsFile("mycreds.txt")
    drive = GoogleDrive(gauth)

    def find_folder_id(folder_name):
        file_list = drive.ListFile({'q': f"title='{folder_name}' and mimeType='application/vnd.google-apps.folder' and trashed=false"}).GetList()
        for file in file_list:
            if file['title'] == folder_name:
                return file['id']
        return None

    def download_zst_file_from_drive(file_title, parent_id):
        query = f"'{parent_id}' in parents and trashed=false and title='{file_title}'"
        file_list = drive.ListFile({'q': query}).GetList()
        if not file_list:
            print(f"No file found with title: {file_title}")
            return None
        file = file_list[0]
        print("loading file...") #3min
        file.GetContentFile(file_title)
        return file_title

    asset_folder_id = find_folder_id(asset_dir)
    if asset_folder_id is None:
        print("Asset folder not found.")
        return None

    file_path = download_zst_file_from_drive(file_name, asset_folder_id)
    if file_path is None:
        return None

    print("Downloaded file: {}".format(file_path))

# %%
# Set the random seed
np.random.seed(42)

# %%
# load training data
for i in range(1,10):
    download_from_drive(file_name='dataset_lichess{}.Mar18.npz'.format(i), asset_dir='Mengqi_Input')
    data = np.load('dataset_lichess{}.Mar18.npz'.format(i))
    if i == 1:
        X = data['X']
        y = data['y']
    else:
        X = np.concatenate((X, data['X']))
        y = np.concatenate((y, data['y']))

idx_to_pick = np.concatenate((np.arange(0, 12), [14]))
inputdata = {'X': X[:,:,:,idx_to_pick], 'y': y}
# Out:
# loading file...
# Downloaded file: dataset_lichess1.Mar18.npz
# loading file...
# Downloaded file: dataset_lichess2.Mar18.npz
# loading file...
# Downloaded file: dataset_lichess3.Mar18.npz
# loading file...
# Downloaded file: dataset_lichess4.Mar18.npz
# loading file...
# Downloaded file: dataset_lichess5.Mar18.npz
# loading file...
# Downloaded file: dataset_lichess6.Mar18.npz
# loading file...
# Downloaded file: dataset_lichess7.Mar18.npz
# loading file...
# Downloaded file: dataset_lichess8.Mar18.npz
# loading file...
# Downloaded file: dataset_lichess9.Mar18.npz

# %%
fig, axs = plt.subplots(1, 1, figsize=(20, 5))

axs.scatter([e for e in range(len(inputdata['y']))], inputdata['y'])
axs.set_xlabel("data sample")
axs.set_ylabel("evaluation score")
axs.set_title("evaluation score distribution")
# Out:
# Text(0.5, 1.0, 'evaluation score distribution')

# %%
mean = np.mean(inputdata['y'])
std_dev = np.std(inputdata['y'])
thres_high = mean + 2 * std_dev
thres_low = mean - 2 * std_dev

print(thres_high)
print(thres_low)

# Find the indices of samples that satisfy the filtering condition
filtered_indices = np.where((inputdata['y'] <= thres_high) & (inputdata['y'] >= thres_low))[0]

# Get the filtered data based on the filtered indices
filtered_data = inputdata['y'][filtered_indices]
# Out:
# 507.62531026745927
# -399.41332253696027

# %%
filtered_data.shape
# Out:
# (848835,)

# %%
fig, axs = plt.subplots(1, 1, figsize=(20, 5))

axs.scatter([e for e in range(len(filtered_data))], filtered_data)
axs.set_xlabel("data sample")
axs.set_ylabel("evaluation score")
axs.set_title("evaluation score distribution after outlier removal")
# Out:
# Text(0.5, 1.0, 'evaluation score distribution after outlier removal')

# %%
X_filtered = X[filtered_indices]
X_filtered = X_filtered[:,:,:,idx_to_pick]
y_filtered = y[filtered_indices]
inputdata = {'X': X_filtered, 'y': y_filtered}

# %%
inputdata['X'].shape
# Out:
# (848835, 8, 8, 13)

# %%
# load validation data

download_from_drive(file_name='dataset_lichess10.Mar18.npz', asset_dir='Mengqi_Input')
valdata = np.load('dataset_lichess10.Mar18.npz')

mean = np.mean(valdata['y'])
std_dev = np.std(valdata['y'])
thres_high = mean + 2 * std_dev
thres_low = mean - 2 * std_dev

print(thres_high)
print(thres_low)

# Find the indices of samples that satisfy the filtering condition
filtered_indices = np.where((valdata['y'] <= thres_high) & (valdata['y'] >= thres_low))[0]

# Get the filtered data based on the filtered indices
filtered_data = inputdata['y'][filtered_indices]

X_filtered = valdata['X'][filtered_indices]
X_filtered = X_filtered[:,:,:,idx_to_pick]
y_filtered = valdata['y'][filtered_indices]
validation_set = {'X': X_filtered, 'y': y_filtered}
# Out:
# loading file...
# Downloaded file: dataset_lichess10.Mar18.npz
# 396.3441964522211
# -269.15814295056794

# %%
fig, axs = plt.subplots(1, 1, figsize=(20, 5))

axs.scatter([e for e in range(len(validation_set['y']))], validation_set['y'])
axs.set_xlabel("data sample")
axs.set_ylabel("evaluation score")
axs.set_title("validation set evaluation score distribution after outlier removal")
# Out:
# Text(0.5, 1.0, 'validation set evaluation score distribution after outlier removal')

# %%
# model components

class ConvBlock(nn.Module):
    def __init__(self, channel_in=13, channel_out=256, kernel_size=3, stride=1):
        super(ConvBlock, self).__init__()
        self.channel_in = channel_in
        self.conv1 = nn.Conv2d(channel_in, channel_out, kernel_size=kernel_size,
                               stride=stride, padding=1)
        self.bn1 = nn.BatchNorm2d(channel_out)

    def forward(self, s):
        if s.dtype != torch.float32:
            s = s.float()
        s = s.view(-1, self.channel_in, 8, 8)  # batch_size x channels x board_x x board_y
        s = self.conv1(s)
        s = self.bn1(s)
        s = F.relu(s)
        return s

class ResBlock(nn.Module):
    def __init__(self, channel_in=256, channel_out=256, kernel_size=3, stride=1,
                 downsample=None):
        super(ResBlock, self).__init__()
        padding = (kernel_size - 1) // 2
        self.conv1 = nn.Conv2d(channel_in, channel_out, kernel_size=kernel_size,
                               stride=stride,
                     padding=padding, bias=False)
        self.bn1 = nn.BatchNorm2d(channel_out)
        self.conv2 = nn.Conv2d(channel_out, channel_out, kernel_size=kernel_size,
                               stride=stride,
                     padding=padding, bias=False)
        self.bn2 = nn.BatchNorm2d(channel_out)
        self.downsample = downsample

    def forward(self, x):
        residual = x
        out = self.conv1(x)
        out = self.bn1(out)
        out = F.relu(out)
        out = self.conv2(out)
        out = self.bn2(out)
        if self.downsample is not None:
            residual = self.downsample(x)
        out += residual
        out = F.relu(out)
        return out

class OutBlock(nn.Module):
    def __init__(self):
        super(OutBlock, self).__init__()
        self.conv = nn.Conv2d(256, 1, kernel_size=1, stride=1)
        self.bn = nn.BatchNorm2d(1)
        self.fc1 = nn.Linear(8*8, 256)
        self.fc2 = nn.Linear(256, 1)

    def forward(self,s):
        v = self.conv(s)
        v = self.bn(v)
        v = F.relu(v)
        v = v.view(-1, 8*8)  # batch_size x channels x board_x x board_y
        v = self.fc1(v)
        v = F.relu(v)
        v = self.fc2(v)
        v = torch.tanh(v)

        return v

# %%
# 7 layers of residual blocks

class ResNet7(nn.Module):
    def __init__(self):
        super(ResNet7, self).__init__()
        self.conv = ConvBlock()
        self.resblocks = nn.ModuleList([ResBlock() for _ in range(7)])
        self.outblock = OutBlock()

    def forward(self,s):
        s = self.conv(s)
        for resblock in self.resblocks:
            s = resblock(s)
        s = self.outblock(s)
        return s

# %%
# initialize a normalizer for the evaluation score

normalizer = MinMaxScaler(feature_range=(-1, 1)).fit(inputdata['y'].reshape(-1,1))

# %%
class data_prep():
    def __init__(self, dataset): # dataset = np.array of (s, v)
        # self.X = dataset[:,0]
        # self.y = dataset[:,1]
        self.X = dataset['X']
        self.y = normalizer.transform(dataset['y'].reshape(-1,1))
        self.y = self.y.reshape(-1,)

    def __len__(self):
        return len(self.X)

    def __getitem__(self,idx):
        return self.X[idx].transpose(2,0,1), self.y[idx]

# %%
# validation function

def validate(net, val_loader, criterion):
    net.eval()  # Switch model to evaluation mode
    total_loss = 0.0
    num_batches = 0
    for i, data in enumerate(val_loader):
        state, value = data
        if cuda:
            state, value = state.cuda().float(), value.cuda().float()
        value = value.float()  # Convert to torch.float32
        with torch.no_grad():  # Disable gradient calculation
            value_pred = net(state)  # value_pred = torch.Size([batch, 1])
            loss = criterion(value_pred[:, 0], value)
        total_loss += loss.item()
        num_batches += 1
    average_loss = total_loss / num_batches
    return average_loss

# %%
def train(net, train_data, val_data, batch_size=100, epoch_start=0, epoch_stop=20, checkpoint_interval=10, early_stop_patience=5):
    cuda = torch.cuda.is_available()
    net.train()
    criterion = nn.MSELoss()
    optimizer = optim.Adam(net.parameters(), lr=0.01)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=5, factor=0.2)
    train_set = data_prep(train_data)
    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True,
                              num_workers=2, pin_memory=False)
    val_set = data_prep(val_data)
    val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False,
                            num_workers=2, pin_memory=False)
    losses_per_epoch = []
    val_losses_per_epoch = []
    lr = []
    patience_count = 0
    for epoch in range(epoch_start, epoch_stop):
        total_loss = 0.0
        losses_per_batch = []
        for i,data in enumerate(train_loader):
            state, value = data
            if cuda:
                state, value = state.cuda().float(), value.cuda().float()
            value = value.float()  # Convert to torch.float32
            optimizer.zero_grad()
            value_pred = net(state) # value_pred = torch.Size([batch, 1])
            loss = criterion(value_pred[:,0], value)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            if i % 10 == 9:    # print every 10 mini-batches of size = batch_size
                print('Process ID: %d [Epoch: %d, %5d/ %d points] total loss per batch: %.5f' %
                      (os.getpid(), epoch + 1, (i + 1)*batch_size, len(train_set), total_loss/10))
                print("Value:",value[0].item(),value_pred[0,0].item())
                losses_per_batch.append(total_loss/10)
                total_loss = 0.0
        losses_per_epoch.append(sum(losses_per_batch)/len(losses_per_batch))
        # Validation
        val_loss = validate(net, val_loader, criterion)
        print(f'Validation MSE Loss: {val_loss:.5f}')
        val_losses_per_epoch.append(val_loss)
        scheduler.step(val_loss)
        # Print learning rate
        current_lr = optimizer.param_groups[0]['lr']
        print(f"Current learning rate: {current_lr}")
        lr.append(current_lr)
        # Early stopping: validation loss has to reduce at least 5% per epoch
        if len(val_losses_per_epoch) >= 6:
            loss_avg = np.average(val_losses_per_epoch[-6:-1])
            if val_loss <= 0.95 * loss_avg:
                patience_count = 0  # Reset patience count
            else:
                patience_count += 1
        if patience_count >= early_stop_patience:
            np.savez("Supervised_Learning/model/ResNet7_Mar27_losses_per_epoch_epoch{}.npz".format(epoch+1),
                train_loss=losses_per_epoch,
                val_loss=val_losses_per_epoch,
                lr=lr
                )
            torch.save({'state_dict': net.state_dict()},
                  "Supervised_Learning/model/ResNet7_Mar27_training_checkpoint_epoch{}.ckpt".format(epoch+1))
            print(f'Early stopping! No improvement in validation loss for {early_stop_patience} epochs.')
            break
        # Save checkpoints
        if epoch % checkpoint_interval == 9:
            np.savez("Supervised_Learning/model/ResNet7_Mar27_losses_per_epoch_epoch{}.npz".format(epoch+1),
                   train_loss=losses_per_epoch,
                   val_loss=val_losses_per_epoch,
                   lr=lr
                   )
            losses_per_epoch = []
            val_losses_per_epoch = []
            lr = []
            torch.save({'state_dict': net.state_dict()},
                     "Supervised_Learning/model/ResNet7_Mar27_training_checkpoint_epoch{}.ckpt".format(epoch+1))

# %%
# train net
net = ResNet7()
cuda = torch.cuda.is_available()
if cuda:
    net.cuda()
train(net,inputdata, validation_set, epoch_stop=50)
# save results
torch.save({'state_dict': net.state_dict()}, "Supervised_Learning/model/ResNet7_March27_trained.pth.tar")
# Out:
# Streaming output truncated to the last 5000 lines.
# Value: -0.12141280621290207 -0.12499934434890747
# Process ID: 678 [Epoch: 18, 49000/ 848835 points] total loss per batch: 0.00891
# Value: 0.06401766091585159 -0.035968560725450516
# Process ID: 678 [Epoch: 18, 50000/ 848835 points] total loss per batch: 0.00955
# Value: -0.17880794405937195 -0.06122250482439995
# Process ID: 678 [Epoch: 18, 51000/ 848835 points] total loss per batch: 0.01009
# Value: -0.7350993156433105 -0.6885474920272827
# Process ID: 678 [Epoch: 18, 52000/ 848835 points] total loss per batch: 0.00817
# Value: -0.13024282455444336 -0.12402243912220001
# Process ID: 678 [Epoch: 18, 53000/ 848835 points] total loss per batch: 0.00835
# Value: -0.7373068332672119 -0.5912787914276123
# Process ID: 678 [Epoch: 18, 54000/ 848835 points] total loss per batch: 0.01101
# Value: 0.29801324009895325 0.2606138586997986
# Process ID: 678 [Epoch: 18, 55000/ 848835 points] total loss per batch: 0.00989
# Value: 0.366445928812027 0.39835044741630554
# Process ID: 678 [Epoch: 18, 56000/ 848835 points] total loss per batch: 0.00861
# Value: 0.06843267381191254 0.09758055955171585
# Process ID: 678 [Epoch: 18, 57000/ 848835 points] total loss per batch: 0.00805
# Value: 0.12141280621290207 0.10100830346345901
# Process ID: 678 [Epoch: 18, 58000/ 848835 points] total loss per batch: 0.00902
# Value: -0.04194260388612747 -0.08565474301576614
# Process ID: 678 [Epoch: 18, 59000/ 848835 points] total loss per batch: 0.00904
# Value: -0.10154525190591812 -0.0667412132024765
# Process ID: 678 [Epoch: 18, 60000/ 848835 points] total loss per batch: 0.00881
# Value: -0.026490066200494766 -0.07801671326160431
# Process ID: 678 [Epoch: 18, 61000/ 848835 points] total loss per batch: 0.00946
# Value: 0.07726269215345383 -0.021885447204113007
# Process ID: 678 [Epoch: 18, 62000/ 848835 points] total loss per batch: 0.00855
# Value: -0.2384105920791626 -0.20157554745674133
# Process ID: 678 [Epoch: 18, 63000/ 848835 points] total loss per batch: 0.01006
# Value: -0.01545253861695528 -0.02882196567952633
# Process ID: 678 [Epoch: 18, 64000/ 848835 points] total loss per batch: 0.01029
# Value: -0.011037527583539486 -0.0036823938135057688
# Process ID: 678 [Epoch: 18, 65000/ 848835 points] total loss per batch: 0.00975
# Value: -0.4128035306930542 -0.18849067389965057
# Process ID: 678 [Epoch: 18, 66000/ 848835 points] total loss per batch: 0.00941
# Value: -0.6821191906929016 -0.7861286401748657
# Process ID: 678 [Epoch: 18, 67000/ 848835 points] total loss per batch: 0.00981
# Value: -0.20309050381183624 -0.14135536551475525
# Process ID: 678 [Epoch: 18, 68000/ 848835 points] total loss per batch: 0.01033
# Value: -0.08167770504951477 -0.19242513179779053
# Process ID: 678 [Epoch: 18, 69000/ 848835 points] total loss per batch: 0.01120
# Value: -0.7880794405937195 -0.2801961302757263
# Process ID: 678 [Epoch: 18, 70000/ 848835 points] total loss per batch: 0.00867
# Value: -0.19646799564361572 -0.1807742416858673
# Process ID: 678 [Epoch: 18, 71000/ 848835 points] total loss per batch: 0.01011
# Value: -0.5982339978218079 -0.6472272872924805
# Process ID: 678 [Epoch: 18, 72000/ 848835 points] total loss per batch: 0.01097
# Value: -0.189845472574234 -0.2425994724035263
# Process ID: 678 [Epoch: 18, 73000/ 848835 points] total loss per batch: 0.00862
# Value: -0.2450331151485443 -0.14707446098327637
# Process ID: 678 [Epoch: 18, 74000/ 848835 points] total loss per batch: 0.00950
# Value: 0.1743929386138916 0.14083246886730194
# Process ID: 678 [Epoch: 18, 75000/ 848835 points] total loss per batch: 0.00810
# Value: -0.29139071702957153 -0.23163092136383057
# Process ID: 678 [Epoch: 18, 76000/ 848835 points] total loss per batch: 0.01054
# Value: 0.6269315481185913 0.5987110137939453
# Process ID: 678 [Epoch: 18, 77000/ 848835 points] total loss per batch: 0.01041
# Value: 0.11699779331684113 -0.00158834143076092
# Process ID: 678 [Epoch: 18, 78000/ 848835 points] total loss per batch: 0.00973
# Value: -0.18763796985149384 -0.13278336822986603
# Process ID: 678 [Epoch: 18, 79000/ 848835 points] total loss per batch: 0.00944
# Value: 0.0397351011633873 0.007606436964124441
# Process ID: 678 [Epoch: 18, 80000/ 848835 points] total loss per batch: 0.00958
# Value: 0.23399558663368225 0.2846468985080719
# Process ID: 678 [Epoch: 18, 81000/ 848835 points] total loss per batch: 0.00978
# Value: -0.2229580581188202 -0.1920350193977356
# Process ID: 678 [Epoch: 18, 82000/ 848835 points] total loss per batch: 0.01023
# Value: -0.057395145297050476 0.009335502982139587
# Process ID: 678 [Epoch: 18, 83000/ 848835 points] total loss per batch: 0.00920
# Value: -0.10596026480197906 -0.1277289092540741
# Process ID: 678 [Epoch: 18, 84000/ 848835 points] total loss per batch: 0.01063
# Value: -0.12803532183170319 -0.10412146151065826
# Process ID: 678 [Epoch: 18, 85000/ 848835 points] total loss per batch: 0.00917
# Value: 0.6887417435646057 0.6948368549346924
# Process ID: 678 [Epoch: 18, 86000/ 848835 points] total loss per batch: 0.01095
# Value: -0.11037527769804001 -0.05925377830862999
# Process ID: 678 [Epoch: 18, 87000/ 848835 points] total loss per batch: 0.01025
# Value: -0.17218543589115143 -0.17535102367401123
# Process ID: 678 [Epoch: 18, 88000/ 848835 points] total loss per batch: 0.00837
# Value: -0.11258278042078018 -0.13156048953533173
# Process ID: 678 [Epoch: 18, 89000/ 848835 points] total loss per batch: 0.00972
# Value: -0.10154525190591812 -0.20626236498355865
# Process ID: 678 [Epoch: 18, 90000/ 848835 points] total loss per batch: 0.00974
# Value: -0.13907285034656525 -0.12190092355012894
# Process ID: 678 [Epoch: 18, 91000/ 848835 points] total loss per batch: 0.01078
# Value: -0.04856512323021889 -0.018339794129133224
# Process ID: 678 [Epoch: 18, 92000/ 848835 points] total loss per batch: 0.00949
# Value: -0.13245032727718353 -0.20539933443069458
# Process ID: 678 [Epoch: 18, 93000/ 848835 points] total loss per batch: 0.01034
# Value: -0.11699779331684113 -0.05604999139904976
# Process ID: 678 [Epoch: 18, 94000/ 848835 points] total loss per batch: 0.01012
# Value: -0.9735099077224731 -0.9499108195304871
# Process ID: 678 [Epoch: 18, 95000/ 848835 points] total loss per batch: 0.00952
# Value: -0.2715231776237488 -0.2762677073478699
# Process ID: 678 [Epoch: 18, 96000/ 848835 points] total loss per batch: 0.01014
# Value: 0.008830022066831589 0.007463361136615276
# Process ID: 678 [Epoch: 18, 97000/ 848835 points] total loss per batch: 0.01083
# Value: 0.03752759471535683 -0.028659893199801445
# Process ID: 678 [Epoch: 18, 98000/ 848835 points] total loss per batch: 0.00904
# Value: -0.05298013240098953 -0.02966693602502346
# Process ID: 678 [Epoch: 18, 99000/ 848835 points] total loss per batch: 0.00901
# Value: -0.3487858772277832 -0.46166491508483887
# Process ID: 678 [Epoch: 18, 100000/ 848835 points] total loss per batch: 0.00922
# Value: -0.013245033100247383 -0.02268756926059723
# Process ID: 678 [Epoch: 18, 101000/ 848835 points] total loss per batch: 0.00961
# Value: -0.3112582862377167 -0.312667578458786
# Process ID: 678 [Epoch: 18, 102000/ 848835 points] total loss per batch: 0.01066
# Value: -0.12141280621290207 0.008265569806098938
# Process ID: 678 [Epoch: 18, 103000/ 848835 points] total loss per batch: 0.01032
# Value: -0.13245032727718353 -0.09779076278209686
# Process ID: 678 [Epoch: 18, 104000/ 848835 points] total loss per batch: 0.01022
# Value: -0.06181015446782112 0.001182371168397367
# Process ID: 678 [Epoch: 18, 105000/ 848835 points] total loss per batch: 0.00830
# Value: 0.3951434791088104 0.27962109446525574
# Process ID: 678 [Epoch: 18, 106000/ 848835 points] total loss per batch: 0.01095
# Value: -0.028697572648525238 -0.10681941360235214
# Process ID: 678 [Epoch: 18, 107000/ 848835 points] total loss per batch: 0.00937
# Value: -0.12141280621290207 -0.10991573333740234
# Process ID: 678 [Epoch: 18, 108000/ 848835 points] total loss per batch: 0.00922
# Value: 0.366445928812027 0.5001508593559265
# Process ID: 678 [Epoch: 18, 109000/ 848835 points] total loss per batch: 0.00861
# Value: -0.1677704155445099 -0.18774642050266266
# Process ID: 678 [Epoch: 18, 110000/ 848835 points] total loss per batch: 0.00978
# Value: -0.13245032727718353 -0.17661792039871216
# Process ID: 678 [Epoch: 18, 111000/ 848835 points] total loss per batch: 0.00881
# Value: 0.5099337697029114 0.24060216546058655
# Process ID: 678 [Epoch: 18, 112000/ 848835 points] total loss per batch: 0.00916
# Value: 0.22075055539608002 0.3503062129020691
# Process ID: 678 [Epoch: 18, 113000/ 848835 points] total loss per batch: 0.00965
# Value: -0.15231788158416748 -0.1224006935954094
# Process ID: 678 [Epoch: 18, 114000/ 848835 points] total loss per batch: 0.00979
# Value: -0.39955848455429077 -0.33871838450431824
# Process ID: 678 [Epoch: 18, 115000/ 848835 points] total loss per batch: 0.00905
# Value: 0.05298013240098953 -0.04693976044654846
# Process ID: 678 [Epoch: 18, 116000/ 848835 points] total loss per batch: 0.00909
# Value: 0.4061810076236725 0.6128291487693787
# Process ID: 678 [Epoch: 18, 117000/ 848835 points] total loss per batch: 0.00946
# Value: -0.16335541009902954 -0.1308036744594574
# Process ID: 678 [Epoch: 18, 118000/ 848835 points] total loss per batch: 0.00816
# Value: -0.07726269215345383 -0.019727366045117378
# Process ID: 678 [Epoch: 18, 119000/ 848835 points] total loss per batch: 0.00902
# Value: -0.24724061787128448 -0.32263410091400146
# Process ID: 678 [Epoch: 18, 120000/ 848835 points] total loss per batch: 0.00887
# Value: 0.024282561615109444 0.011260461993515491
# Process ID: 678 [Epoch: 18, 121000/ 848835 points] total loss per batch: 0.01025
# Value: 0.002207505516707897 -0.026994474232196808
# Process ID: 678 [Epoch: 18, 122000/ 848835 points] total loss per batch: 0.01001
# Value: -0.094922736287117 -0.03675061836838722
# Process ID: 678 [Epoch: 18, 123000/ 848835 points] total loss per batch: 0.00899
# Value: -0.05960264801979065 -0.051622264087200165
# Process ID: 678 [Epoch: 18, 124000/ 848835 points] total loss per batch: 0.01086
# Value: -0.08388520777225494 -0.04332221299409866
# Process ID: 678 [Epoch: 18, 125000/ 848835 points] total loss per batch: 0.00821
# Value: -0.13907285034656525 -0.009266315959393978
# Process ID: 678 [Epoch: 18, 126000/ 848835 points] total loss per batch: 0.00934
# Value: -0.004415011033415794 -0.12371326237916946
# Process ID: 678 [Epoch: 18, 127000/ 848835 points] total loss per batch: 0.01127
# Value: -0.23620308935642242 -0.19943127036094666
# Process ID: 678 [Epoch: 18, 128000/ 848835 points] total loss per batch: 0.00996
# Value: -0.13024282455444336 -0.19543416798114777
# Process ID: 678 [Epoch: 18, 129000/ 848835 points] total loss per batch: 0.01020
# Value: -0.3818984627723694 -0.347337931394577
# Process ID: 678 [Epoch: 18, 130000/ 848835 points] total loss per batch: 0.01054
# Value: 0.024282561615109444 0.02336139604449272
# Process ID: 678 [Epoch: 18, 131000/ 848835 points] total loss per batch: 0.00929
# Value: 0.04194260388612747 -0.030477793887257576
# Process ID: 678 [Epoch: 18, 132000/ 848835 points] total loss per batch: 0.01037
# Value: -0.1192052960395813 -0.14747503399848938
# Process ID: 678 [Epoch: 18, 133000/ 848835 points] total loss per batch: 0.00945
# Value: -0.013245033100247383 -0.06187865138053894
# Process ID: 678 [Epoch: 18, 134000/ 848835 points] total loss per batch: 0.01124
# Value: -0.026490066200494766 0.02437588758766651
# Process ID: 678 [Epoch: 18, 135000/ 848835 points] total loss per batch: 0.00889
# Value: -0.03752759471535683 -0.0443962998688221
# Process ID: 678 [Epoch: 18, 136000/ 848835 points] total loss per batch: 0.00904
# Value: -0.09713024646043777 -0.026067277416586876
# Process ID: 678 [Epoch: 18, 137000/ 848835 points] total loss per batch: 0.00895
# Value: -0.09713024646043777 -0.292050838470459
# Process ID: 678 [Epoch: 18, 138000/ 848835 points] total loss per batch: 0.01197
# Value: 0.743929386138916 0.805988073348999
# Process ID: 678 [Epoch: 18, 139000/ 848835 points] total loss per batch: 0.00862
# Value: 0.4547461271286011 0.6250373125076294
# Process ID: 678 [Epoch: 18, 140000/ 848835 points] total loss per batch: 0.01163
# Value: -0.4856512248516083 -0.044362541288137436
# Process ID: 678 [Epoch: 18, 141000/ 848835 points] total loss per batch: 0.01136
# Value: -0.04856512323021889 -0.03792255371809006
# Process ID: 678 [Epoch: 18, 142000/ 848835 points] total loss per batch: 0.00944
# Value: -0.12803532183170319 -0.13184906542301178
# Process ID: 678 [Epoch: 18, 143000/ 848835 points] total loss per batch: 0.01174
# Value: 0.013245033100247383 0.13804572820663452
# Process ID: 678 [Epoch: 18, 144000/ 848835 points] total loss per batch: 0.00955
# Value: -0.21854305267333984 -0.2597602307796478
# Process ID: 678 [Epoch: 18, 145000/ 848835 points] total loss per batch: 0.00995
# Value: -0.09271523356437683 -0.06167188286781311
# Process ID: 678 [Epoch: 18, 146000/ 848835 points] total loss per batch: 0.00859
# Value: -0.008830022066831589 0.03914831951260567
# Process ID: 678 [Epoch: 18, 147000/ 848835 points] total loss per batch: 0.00959
# Value: -0.2141280323266983 -0.13507184386253357
# Process ID: 678 [Epoch: 18, 148000/ 848835 points] total loss per batch: 0.01141
# Value: 0.3818984627723694 0.3119639456272125
# Process ID: 678 [Epoch: 18, 149000/ 848835 points] total loss per batch: 0.00991
# Value: -0.03311258181929588 0.0025941485073417425
# Process ID: 678 [Epoch: 18, 150000/ 848835 points] total loss per batch: 0.00924
# Value: 0.13907285034656525 0.12777099013328552
# Process ID: 678 [Epoch: 18, 151000/ 848835 points] total loss per batch: 0.00929
# Value: 0.366445928812027 0.18088288605213165
# Process ID: 678 [Epoch: 18, 152000/ 848835 points] total loss per batch: 0.00951
# Value: 0.017660044133663177 0.016882002353668213
# Process ID: 678 [Epoch: 18, 153000/ 848835 points] total loss per batch: 0.01038
# Value: 0.09933774918317795 -0.05842013284564018
# Process ID: 678 [Epoch: 18, 154000/ 848835 points] total loss per batch: 0.00970
# Value: -0.19646799564361572 -0.2318001538515091
# Process ID: 678 [Epoch: 18, 155000/ 848835 points] total loss per batch: 0.01031
# Value: -0.03752759471535683 -0.05781847611069679
# Process ID: 678 [Epoch: 18, 156000/ 848835 points] total loss per batch: 0.00870
# Value: -0.10375276207923889 -0.0961516797542572
# Process ID: 678 [Epoch: 18, 157000/ 848835 points] total loss per batch: 0.00907
# Value: -0.16997791826725006 -0.3062386214733124
# Process ID: 678 [Epoch: 18, 158000/ 848835 points] total loss per batch: 0.00978
# Value: -0.503311276435852 -0.5036541819572449
# Process ID: 678 [Epoch: 18, 159000/ 848835 points] total loss per batch: 0.00976
# Value: -0.17218543589115143 -0.15342110395431519
# Process ID: 678 [Epoch: 18, 160000/ 848835 points] total loss per batch: 0.01061
# Value: -0.13686534762382507 -0.14312432706356049
# Process ID: 678 [Epoch: 18, 161000/ 848835 points] total loss per batch: 0.01068
# Value: -0.33112582564353943 -0.2802846133708954
# Process ID: 678 [Epoch: 18, 162000/ 848835 points] total loss per batch: 0.00959
# Value: -0.13907285034656525 -0.08195178955793381
# Process ID: 678 [Epoch: 18, 163000/ 848835 points] total loss per batch: 0.00941
# Value: -0.04856512323021889 -0.04276665672659874
# Process ID: 678 [Epoch: 18, 164000/ 848835 points] total loss per batch: 0.00982
# Value: -0.9690949320793152 -0.9584099650382996
# Process ID: 678 [Epoch: 18, 165000/ 848835 points] total loss per batch: 0.00930
# Value: -0.20088300108909607 -0.21250922977924347
# Process ID: 678 [Epoch: 18, 166000/ 848835 points] total loss per batch: 0.00934
# Value: -0.10596026480197906 -0.14166821539402008
# Process ID: 678 [Epoch: 18, 167000/ 848835 points] total loss per batch: 0.01025
# Value: -0.26490065455436707 -0.17904192209243774
# Process ID: 678 [Epoch: 18, 168000/ 848835 points] total loss per batch: 0.01003
# Value: -0.1346578299999237 -0.1750926524400711
# Process ID: 678 [Epoch: 18, 169000/ 848835 points] total loss per batch: 0.00963
# Value: -0.21633553504943848 -0.16778564453125
# Process ID: 678 [Epoch: 18, 170000/ 848835 points] total loss per batch: 0.00946
# Value: 0.3487858772277832 0.2676478922367096
# Process ID: 678 [Epoch: 18, 171000/ 848835 points] total loss per batch: 0.01076
# Value: -0.04856512323021889 -0.06470032036304474
# Process ID: 678 [Epoch: 18, 172000/ 848835 points] total loss per batch: 0.01060
# Value: -0.16556291282176971 -0.21386989951133728
# Process ID: 678 [Epoch: 18, 173000/ 848835 points] total loss per batch: 0.00951
# Value: -0.10154525190591812 0.029051020741462708
# Process ID: 678 [Epoch: 18, 174000/ 848835 points] total loss per batch: 0.00978
# Value: -0.17660044133663177 -0.3736458122730255
# Process ID: 678 [Epoch: 18, 175000/ 848835 points] total loss per batch: 0.00971
# Value: -0.07284767925739288 -0.07209596782922745
# Process ID: 678 [Epoch: 18, 176000/ 848835 points] total loss per batch: 0.00949
# Value: 0.18763796985149384 0.260010689496994
# Process ID: 678 [Epoch: 18, 177000/ 848835 points] total loss per batch: 0.01069
# Value: 0.017660044133663177 -0.08455487340688705
# Process ID: 678 [Epoch: 18, 178000/ 848835 points] total loss per batch: 0.01026
# Value: 0.19205297529697418 0.18426592648029327
# Process ID: 678 [Epoch: 18, 179000/ 848835 points] total loss per batch: 0.01117
# Value: -0.026490066200494766 -0.05218690633773804
# Process ID: 678 [Epoch: 18, 180000/ 848835 points] total loss per batch: 0.00910
# Value: 0.09933774918317795 0.1639273315668106
# Process ID: 678 [Epoch: 18, 181000/ 848835 points] total loss per batch: 0.01057
# Value: 0.06181015446782112 0.06447328627109528
# Process ID: 678 [Epoch: 18, 182000/ 848835 points] total loss per batch: 0.00933
# Value: -0.04194260388612747 -0.018288133665919304
# Process ID: 678 [Epoch: 18, 183000/ 848835 points] total loss per batch: 0.00892
# Value: -0.1832229644060135 -0.2995060384273529
# Process ID: 678 [Epoch: 18, 184000/ 848835 points] total loss per batch: 0.01014
# Value: 0.7240617871284485 0.6077939867973328
# Process ID: 678 [Epoch: 18, 185000/ 848835 points] total loss per batch: 0.01024
# Value: -0.013245033100247383 -0.048897162079811096
# Process ID: 678 [Epoch: 18, 186000/ 848835 points] total loss per batch: 0.01030
# Value: -0.10154525190591812 -0.11004585772752762
# Process ID: 678 [Epoch: 18, 187000/ 848835 points] total loss per batch: 0.00847
# Value: -0.11258278042078018 -0.120977021753788
# Process ID: 678 [Epoch: 18, 188000/ 848835 points] total loss per batch: 0.01161
# Value: -0.22737306356430054 -0.2628384828567505
# Process ID: 678 [Epoch: 18, 189000/ 848835 points] total loss per batch: 0.01031
# Value: -0.06401766091585159 0.07658755034208298
# Process ID: 678 [Epoch: 18, 190000/ 848835 points] total loss per batch: 0.01145
# Value: 0.013245033100247383 -0.043266575783491135
# Process ID: 678 [Epoch: 18, 191000/ 848835 points] total loss per batch: 0.00862
# Value: 0.743929386138916 0.6588872671127319
# Process ID: 678 [Epoch: 18, 192000/ 848835 points] total loss per batch: 0.00862
# Value: -0.0066225165501236916 -0.04552093520760536
# Process ID: 678 [Epoch: 18, 193000/ 848835 points] total loss per batch: 0.00892
# Value: 0.23399558663368225 0.2517876923084259
# Process ID: 678 [Epoch: 18, 194000/ 848835 points] total loss per batch: 0.01012
# Value: 0.22075055539608002 0.27333784103393555
# Process ID: 678 [Epoch: 18, 195000/ 848835 points] total loss per batch: 0.01124
# Value: -0.10154525190591812 -0.0978761538863182
# Process ID: 678 [Epoch: 18, 196000/ 848835 points] total loss per batch: 0.01083
# Value: -0.6158940196037292 -0.4501669406890869
# Process ID: 678 [Epoch: 18, 197000/ 848835 points] total loss per batch: 0.00942
# Value: -0.03090507723391056 0.10567349195480347
# Process ID: 678 [Epoch: 18, 198000/ 848835 points] total loss per batch: 0.01062
# Value: 0.48123618960380554 0.5862748026847839
# Process ID: 678 [Epoch: 18, 199000/ 848835 points] total loss per batch: 0.01046
# Value: 0.3245033025741577 0.4672086238861084
# Process ID: 678 [Epoch: 18, 200000/ 848835 points] total loss per batch: 0.00962
# Value: -0.057395145297050476 -0.02150789648294449
# Process ID: 678 [Epoch: 18, 201000/ 848835 points] total loss per batch: 0.01008
# Value: -0.011037527583539486 -0.09402372688055038
# Process ID: 678 [Epoch: 18, 202000/ 848835 points] total loss per batch: 0.01121
# Value: -0.022075055167078972 -0.10000843554735184
# Process ID: 678 [Epoch: 18, 203000/ 848835 points] total loss per batch: 0.00973
# Value: 0.08830022066831589 0.052669234573841095
# Process ID: 678 [Epoch: 18, 204000/ 848835 points] total loss per batch: 0.01013
# Value: -0.08388520777225494 -0.07572127878665924
# Process ID: 678 [Epoch: 18, 205000/ 848835 points] total loss per batch: 0.01038
# Value: 0.20309050381183624 0.15274077653884888
# Process ID: 678 [Epoch: 18, 206000/ 848835 points] total loss per batch: 0.00898
# Value: 0.5165562629699707 0.3825284540653229
# Process ID: 678 [Epoch: 18, 207000/ 848835 points] total loss per batch: 0.01085
# Value: -0.028697572648525238 -0.0701301246881485
# Process ID: 678 [Epoch: 18, 208000/ 848835 points] total loss per batch: 0.01005
# Value: 0.34657835960388184 0.28641751408576965
# Process ID: 678 [Epoch: 18, 209000/ 848835 points] total loss per batch: 0.00944
# Value: 0.12141280621290207 0.007689863443374634
# Process ID: 678 [Epoch: 18, 210000/ 848835 points] total loss per batch: 0.00943
# Value: 0.620309054851532 0.7272602319717407
# Process ID: 678 [Epoch: 18, 211000/ 848835 points] total loss per batch: 0.00966
# Value: 0.17218543589115143 0.13035930693149567
# Process ID: 678 [Epoch: 18, 212000/ 848835 points] total loss per batch: 0.01024
# Value: -0.03311258181929588 -0.07333488762378693
# Process ID: 678 [Epoch: 18, 213000/ 848835 points] total loss per batch: 0.00861
# Value: -0.1192052960395813 0.06813919544219971
# Process ID: 678 [Epoch: 18, 214000/ 848835 points] total loss per batch: 0.01181
# Value: -0.08609271794557571 -0.12320230156183243
# Process ID: 678 [Epoch: 18, 215000/ 848835 points] total loss per batch: 0.01207
# Value: 0.1434878557920456 0.058973684906959534
# Process ID: 678 [Epoch: 18, 216000/ 848835 points] total loss per batch: 0.00985
# Value: -0.125827819108963 -0.1186424046754837
# Process ID: 678 [Epoch: 18, 217000/ 848835 points] total loss per batch: 0.01100
# Value: 0.3576158881187439 0.20112180709838867
# Process ID: 678 [Epoch: 18, 218000/ 848835 points] total loss per batch: 0.01128
# Value: 0.013245033100247383 -0.09348644316196442
# Process ID: 678 [Epoch: 18, 219000/ 848835 points] total loss per batch: 0.00982
# Value: -0.10816776752471924 -0.14684753119945526
# Process ID: 678 [Epoch: 18, 220000/ 848835 points] total loss per batch: 0.00971
# Value: -0.04856512323021889 -0.04198179394006729
# Process ID: 678 [Epoch: 18, 221000/ 848835 points] total loss per batch: 0.01015
# Value: 0.5143488049507141 0.4446043074131012
# Process ID: 678 [Epoch: 18, 222000/ 848835 points] total loss per batch: 0.01114
# Value: -0.10816776752471924 -0.18998493254184723
# Process ID: 678 [Epoch: 18, 223000/ 848835 points] total loss per batch: 0.01010
# Value: -0.2715231776237488 -0.14211316406726837
# Process ID: 678 [Epoch: 18, 224000/ 848835 points] total loss per batch: 0.00959
# Value: -0.11258278042078018 -0.1130366399884224
# Process ID: 678 [Epoch: 18, 225000/ 848835 points] total loss per batch: 0.01008
# Value: -0.17218543589115143 -0.11875705420970917
# Process ID: 678 [Epoch: 18, 226000/ 848835 points] total loss per batch: 0.00986
# Value: -0.10816776752471924 -0.1101468950510025
# Process ID: 678 [Epoch: 18, 227000/ 848835 points] total loss per batch: 0.01165
# Value: -0.14569535851478577 -0.1669834852218628
# Process ID: 678 [Epoch: 18, 228000/ 848835 points] total loss per batch: 0.00956
# Value: -0.04194260388612747 0.0019473311258479953
# Process ID: 678 [Epoch: 18, 229000/ 848835 points] total loss per batch: 0.00888
# Value: -0.04194260388612747 -0.0018461912404745817
# Process ID: 678 [Epoch: 18, 230000/ 848835 points] total loss per batch: 0.01103
# Value: -0.017660044133663177 -0.017258737236261368
# Process ID: 678 [Epoch: 18, 231000/ 848835 points] total loss per batch: 0.00990
# Value: -0.03311258181929588 -0.2655871510505676
# Process ID: 678 [Epoch: 18, 232000/ 848835 points] total loss per batch: 0.00874
# Value: -0.315673291683197 -0.2768476605415344
# Process ID: 678 [Epoch: 18, 233000/ 848835 points] total loss per batch: 0.01094
# Value: -0.11479029059410095 -0.20753678679466248
# Process ID: 678 [Epoch: 18, 234000/ 848835 points] total loss per batch: 0.00933
# Value: -0.125827819108963 -0.12957225739955902
# Process ID: 678 [Epoch: 18, 235000/ 848835 points] total loss per batch: 0.01025
# Value: 0.3554084002971649 0.4690150022506714
# Process ID: 678 [Epoch: 18, 236000/ 848835 points] total loss per batch: 0.01241
# Value: 0.028697572648525238 0.002452094806358218
# Process ID: 678 [Epoch: 18, 237000/ 848835 points] total loss per batch: 0.01029
# Value: -0.16997791826725006 -0.17627406120300293
# Process ID: 678 [Epoch: 18, 238000/ 848835 points] total loss per batch: 0.00855
# Value: -0.11037527769804001 -0.04901840537786484
# Process ID: 678 [Epoch: 18, 239000/ 848835 points] total loss per batch: 0.00969
# Value: -0.08609271794557571 -0.07223818451166153
# Process ID: 678 [Epoch: 18, 240000/ 848835 points] total loss per batch: 0.01044
# Value: -0.06401766091585159 -0.06245673820376396
# Process ID: 678 [Epoch: 18, 241000/ 848835 points] total loss per batch: 0.01071
# Value: -0.09050772339105606 -0.0621008463203907
# Process ID: 678 [Epoch: 18, 242000/ 848835 points] total loss per batch: 0.00950
# Value: -0.16997791826725006 -0.06417582929134369
# Process ID: 678 [Epoch: 18, 243000/ 848835 points] total loss per batch: 0.01217
# Value: -0.0794702023267746 -0.029001442715525627
# Process ID: 678 [Epoch: 18, 244000/ 848835 points] total loss per batch: 0.00964
# Value: -0.3421633541584015 -0.18298131227493286
# Process ID: 678 [Epoch: 18, 245000/ 848835 points] total loss per batch: 0.00899
# Value: -0.22075055539608002 -0.23193413019180298
# Process ID: 678 [Epoch: 18, 246000/ 848835 points] total loss per batch: 0.01078
# Value: -0.11479029059410095 -0.12983547151088715
# Process ID: 678 [Epoch: 18, 247000/ 848835 points] total loss per batch: 0.01127
# Value: -0.4525386393070221 -0.29449155926704407
# Process ID: 678 [Epoch: 18, 248000/ 848835 points] total loss per batch: 0.01051
# Value: 0.01545253861695528 0.07875245064496994
# Process ID: 678 [Epoch: 18, 249000/ 848835 points] total loss per batch: 0.01020
# Value: -0.06401766091585159 -0.18052560091018677
# Process ID: 678 [Epoch: 18, 250000/ 848835 points] total loss per batch: 0.01043
# Value: -0.05077262595295906 -0.06886741518974304
# Process ID: 678 [Epoch: 18, 251000/ 848835 points] total loss per batch: 0.01147
# Value: -0.17880794405937195 -0.14639194309711456
# Process ID: 678 [Epoch: 18, 252000/ 848835 points] total loss per batch: 0.01053
# Value: 0.15452538430690765 0.38000744581222534
# Process ID: 678 [Epoch: 18, 253000/ 848835 points] total loss per batch: 0.00978
# Value: 0.07064017653465271 0.01117334421724081
# Process ID: 678 [Epoch: 18, 254000/ 848835 points] total loss per batch: 0.00939
# Value: -0.7108168005943298 -0.7061754465103149
# Process ID: 678 [Epoch: 18, 255000/ 848835 points] total loss per batch: 0.00942
# Value: -0.29139071702957153 -0.21754053235054016
# Process ID: 678 [Epoch: 18, 256000/ 848835 points] total loss per batch: 0.01105
# Value: -0.8543046116828918 -0.8911608457565308
# Process ID: 678 [Epoch: 18, 257000/ 848835 points] total loss per batch: 0.00935
# Value: -0.12362030893564224 -0.17877861857414246
# Process ID: 678 [Epoch: 18, 258000/ 848835 points] total loss per batch: 0.00970
# Value: -0.0066225165501236916 -0.05423586815595627
# Process ID: 678 [Epoch: 18, 259000/ 848835 points] total loss per batch: 0.01076
# Value: -0.07726269215345383 -0.047162409871816635
# Process ID: 678 [Epoch: 18, 260000/ 848835 points] total loss per batch: 0.01060
# Value: -0.055187638849020004 -0.062433872371912
# Process ID: 678 [Epoch: 18, 261000/ 848835 points] total loss per batch: 0.01049
# Value: 0.10596026480197906 0.13234922289848328
# Process ID: 678 [Epoch: 18, 262000/ 848835 points] total loss per batch: 0.01025
# Value: -0.01545253861695528 -0.02805892936885357
# Process ID: 678 [Epoch: 18, 263000/ 848835 points] total loss per batch: 0.01384
# Value: -0.1501103788614273 -0.11798203736543655
# Process ID: 678 [Epoch: 18, 264000/ 848835 points] total loss per batch: 0.01203
# Value: -0.20750552415847778 -0.13601252436637878
# Process ID: 678 [Epoch: 18, 265000/ 848835 points] total loss per batch: 0.01132
# Value: 0.05960264801979065 -0.04208318144083023
# Process ID: 678 [Epoch: 18, 266000/ 848835 points] total loss per batch: 0.01131
# Value: -0.094922736287117 -0.20088815689086914
# Process ID: 678 [Epoch: 18, 267000/ 848835 points] total loss per batch: 0.01029
# Value: 0.37748345732688904 0.4108593761920929
# Process ID: 678 [Epoch: 18, 268000/ 848835 points] total loss per batch: 0.01177
# Value: -0.10816776752471924 0.013902464881539345
# Process ID: 678 [Epoch: 18, 269000/ 848835 points] total loss per batch: 0.01050
# Value: -0.1192052960395813 -0.18641036748886108
# Process ID: 678 [Epoch: 18, 270000/ 848835 points] total loss per batch: 0.00952
# Value: -0.09271523356437683 -0.030398182570934296
# Process ID: 678 [Epoch: 18, 271000/ 848835 points] total loss per batch: 0.00926
# Value: 0.03752759471535683 -0.03481632098555565
# Process ID: 678 [Epoch: 18, 272000/ 848835 points] total loss per batch: 0.01017
# Value: 0.12362030893564224 0.11245495826005936
# Process ID: 678 [Epoch: 18, 273000/ 848835 points] total loss per batch: 0.00993
# Value: -0.12141280621290207 -0.15350286662578583
# Process ID: 678 [Epoch: 18, 274000/ 848835 points] total loss per batch: 0.00856
# Value: 0.1346578299999237 0.22072184085845947
# Process ID: 678 [Epoch: 18, 275000/ 848835 points] total loss per batch: 0.01028
# Value: -0.18763796985149384 -0.1613900065422058
# Process ID: 678 [Epoch: 18, 276000/ 848835 points] total loss per batch: 0.01024
# Value: -0.11258278042078018 -0.10315128415822983
# Process ID: 678 [Epoch: 18, 277000/ 848835 points] total loss per batch: 0.00960
# Value: -0.08388520777225494 -0.05302020162343979
# Process ID: 678 [Epoch: 18, 278000/ 848835 points] total loss per batch: 0.01163
# Value: 0.4900662302970886 0.45336079597473145
# Process ID: 678 [Epoch: 18, 279000/ 848835 points] total loss per batch: 0.01081
# Value: 0.3112582862377167 0.24861815571784973
# Process ID: 678 [Epoch: 18, 280000/ 848835 points] total loss per batch: 0.01179
# Value: -0.1192052960395813 -0.0674932673573494
# Process ID: 678 [Epoch: 18, 281000/ 848835 points] total loss per batch: 0.01043
# Value: -0.14128035306930542 -0.16372257471084595
# Process ID: 678 [Epoch: 18, 282000/ 848835 points] total loss per batch: 0.01014
# Value: -0.04194260388612747 -0.020875494927167892
# Process ID: 678 [Epoch: 18, 283000/ 848835 points] total loss per batch: 0.00941
# Value: -0.17660044133663177 -0.11331449449062347
# Process ID: 678 [Epoch: 18, 284000/ 848835 points] total loss per batch: 0.01207
# Value: -0.094922736287117 -0.021155253052711487
# Process ID: 678 [Epoch: 18, 285000/ 848835 points] total loss per batch: 0.01231
# Value: -0.12141280621290207 -0.12944118678569794
# Process ID: 678 [Epoch: 18, 286000/ 848835 points] total loss per batch: 0.01013
# Value: 0.046357616782188416 0.01650550402700901
# Process ID: 678 [Epoch: 18, 287000/ 848835 points] total loss per batch: 0.00967
# Value: -0.4260485768318176 -0.4165184199810028
# Process ID: 678 [Epoch: 18, 288000/ 848835 points] total loss per batch: 0.00788
# Value: 0.3885209858417511 0.42564594745635986
# Process ID: 678 [Epoch: 18, 289000/ 848835 points] total loss per batch: 0.00880
# Value: -0.21854305267333984 -0.16340063512325287
# Process ID: 678 [Epoch: 18, 290000/ 848835 points] total loss per batch: 0.01088
# Value: 0.503311276435852 0.5726649165153503
# Process ID: 678 [Epoch: 18, 291000/ 848835 points] total loss per batch: 0.01127
# Value: 0.16556291282176971 0.09789109230041504
# Process ID: 678 [Epoch: 18, 292000/ 848835 points] total loss per batch: 0.00939
# Value: -0.13686534762382507 -0.0681847482919693
# Process ID: 678 [Epoch: 18, 293000/ 848835 points] total loss per batch: 0.01004
# Value: 0.34657835960388184 0.2902955114841461
# Process ID: 678 [Epoch: 18, 294000/ 848835 points] total loss per batch: 0.01059
# Value: -0.18543046712875366 -0.21284332871437073
# Process ID: 678 [Epoch: 18, 295000/ 848835 points] total loss per batch: 0.01044
# Value: 0.04856512323021889 -0.0923347994685173
# Process ID: 678 [Epoch: 18, 296000/ 848835 points] total loss per batch: 0.01108
# Value: -0.16335541009902954 -0.3002849519252777
# Process ID: 678 [Epoch: 18, 297000/ 848835 points] total loss per batch: 0.01071
# Value: 0.26710817217826843 0.26080623269081116
# Process ID: 678 [Epoch: 18, 298000/ 848835 points] total loss per batch: 0.01063
# Value: -0.19646799564361572 -0.23279699683189392
# Process ID: 678 [Epoch: 18, 299000/ 848835 points] total loss per batch: 0.01165
# Value: 0.19426049292087555 0.31083279848098755
# Process ID: 678 [Epoch: 18, 300000/ 848835 points] total loss per batch: 0.01065
# Value: 0.04856512323021889 0.22051087021827698
# Process ID: 678 [Epoch: 18, 301000/ 848835 points] total loss per batch: 0.00856
# Value: -0.29139071702957153 -0.2423119992017746
# Process ID: 678 [Epoch: 18, 302000/ 848835 points] total loss per batch: 0.00896
# Value: -0.6777042150497437 -0.5869609117507935
# Process ID: 678 [Epoch: 18, 303000/ 848835 points] total loss per batch: 0.01193
# Value: -0.13686534762382507 -0.3075200021266937
# Process ID: 678 [Epoch: 18, 304000/ 848835 points] total loss per batch: 0.01316
# Value: -0.20750552415847778 -0.339910089969635
# Process ID: 678 [Epoch: 18, 305000/ 848835 points] total loss per batch: 0.01050
# Value: -0.03311258181929588 -0.030324969440698624
# Process ID: 678 [Epoch: 18, 306000/ 848835 points] total loss per batch: 0.01078
# Value: -0.09933774918317795 -0.1750006526708603
# Process ID: 678 [Epoch: 18, 307000/ 848835 points] total loss per batch: 0.01169
# Value: 0.05298013240098953 -0.012337793596088886
# Process ID: 678 [Epoch: 18, 308000/ 848835 points] total loss per batch: 0.01161
# Value: -0.06843267381191254 -0.12107023596763611
# Process ID: 678 [Epoch: 18, 309000/ 848835 points] total loss per batch: 0.00901
# Value: -0.251655638217926 -0.31141501665115356
# Process ID: 678 [Epoch: 18, 310000/ 848835 points] total loss per batch: 0.01217
# Value: -0.026490066200494766 -0.08930543810129166
# Process ID: 678 [Epoch: 18, 311000/ 848835 points] total loss per batch: 0.01063
# Value: -0.1192052960395813 -0.10290293395519257
# Process ID: 678 [Epoch: 18, 312000/ 848835 points] total loss per batch: 0.01086
# Value: -0.2715231776237488 -0.07236295193433762
# Process ID: 678 [Epoch: 18, 313000/ 848835 points] total loss per batch: 0.01069
# Value: 0.002207505516707897 0.011221730150282383
# Process ID: 678 [Epoch: 18, 314000/ 848835 points] total loss per batch: 0.01179
# Value: 0.026490066200494766 -0.03147651627659798
# Process ID: 678 [Epoch: 18, 315000/ 848835 points] total loss per batch: 0.01104
# Value: 0.807947039604187 0.8373900651931763
# Process ID: 678 [Epoch: 18, 316000/ 848835 points] total loss per batch: 0.00980
# Value: -0.08609271794557571 -0.07365057617425919
# Process ID: 678 [Epoch: 18, 317000/ 848835 points] total loss per batch: 0.01090
# Value: -0.12803532183170319 -0.1401013284921646
# Process ID: 678 [Epoch: 18, 318000/ 848835 points] total loss per batch: 0.01042
# Value: -0.011037527583539486 -0.3335607349872589
# Process ID: 678 [Epoch: 18, 319000/ 848835 points] total loss per batch: 0.01207
# Value: -0.1192052960395813 -0.1310020387172699
# Process ID: 678 [Epoch: 18, 320000/ 848835 points] total loss per batch: 0.01046
# Value: -0.013245033100247383 0.03807888925075531
# Process ID: 678 [Epoch: 18, 321000/ 848835 points] total loss per batch: 0.01015
# Value: 0.05960264801979065 -0.009465666487812996
# Process ID: 678 [Epoch: 18, 322000/ 848835 points] total loss per batch: 0.01218
# Value: -0.17660044133663177 -0.1772618293762207
# Process ID: 678 [Epoch: 18, 323000/ 848835 points] total loss per batch: 0.01148
# Value: 0.08388520777225494 0.014160612598061562
# Process ID: 678 [Epoch: 18, 324000/ 848835 points] total loss per batch: 0.01084
# Value: -0.21854305267333984 -0.1469501554965973
# Process ID: 678 [Epoch: 18, 325000/ 848835 points] total loss per batch: 0.01107
# Value: -0.4039735198020935 -0.32884493470191956
# Process ID: 678 [Epoch: 18, 326000/ 848835 points] total loss per batch: 0.00956
# Value: -0.11699779331684113 -0.07222036272287369
# Process ID: 678 [Epoch: 18, 327000/ 848835 points] total loss per batch: 0.01033
# Value: -0.011037527583539486 0.011543777771294117
# Process ID: 678 [Epoch: 18, 328000/ 848835 points] total loss per batch: 0.01041
# Value: -0.45695364475250244 -0.14017748832702637
# Process ID: 678 [Epoch: 18, 329000/ 848835 points] total loss per batch: 0.01035
# Value: -0.5783664584159851 -0.41167882084846497
# Process ID: 678 [Epoch: 18, 330000/ 848835 points] total loss per batch: 0.01130
# Value: -0.5474613904953003 -0.3441844880580902
# Process ID: 678 [Epoch: 18, 331000/ 848835 points] total loss per batch: 0.00997
# Value: -0.29801324009895325 -0.14626385271549225
# Process ID: 678 [Epoch: 18, 332000/ 848835 points] total loss per batch: 0.01009
# Value: -0.24724061787128448 -0.21416962146759033
# Process ID: 678 [Epoch: 18, 333000/ 848835 points] total loss per batch: 0.01093
# Value: -0.17880794405937195 0.07215269654989243
# Process ID: 678 [Epoch: 18, 334000/ 848835 points] total loss per batch: 0.00917
# Value: 0.044150110334157944 0.20030896365642548
# Process ID: 678 [Epoch: 18, 335000/ 848835 points] total loss per batch: 0.01141
# Value: -0.16335541009902954 -0.014059492386877537
# Process ID: 678 [Epoch: 18, 336000/ 848835 points] total loss per batch: 0.00919
# Value: 0.2935982346534729 0.32387906312942505
# Process ID: 678 [Epoch: 18, 337000/ 848835 points] total loss per batch: 0.01037
# Value: 0.6666666865348816 0.6480197906494141
# Process ID: 678 [Epoch: 18, 338000/ 848835 points] total loss per batch: 0.01017
# Value: -0.9315673112869263 -0.7716456651687622
# Process ID: 678 [Epoch: 18, 339000/ 848835 points] total loss per batch: 0.00979
# Value: 0.06181015446782112 -0.0344119556248188
# Process ID: 678 [Epoch: 18, 340000/ 848835 points] total loss per batch: 0.00964
# Value: -0.03090507723391056 -0.018832765519618988
# Process ID: 678 [Epoch: 18, 341000/ 848835 points] total loss per batch: 0.01088
# Value: -0.30463576316833496 -0.008723090402781963
# Process ID: 678 [Epoch: 18, 342000/ 848835 points] total loss per batch: 0.01002
# Value: 0.24282561242580414 0.21624566614627838
# Process ID: 678 [Epoch: 18, 343000/ 848835 points] total loss per batch: 0.00994
# Value: -0.25827813148498535 -0.21928678452968597
# Process ID: 678 [Epoch: 18, 344000/ 848835 points] total loss per batch: 0.01045
# Value: -0.10596026480197906 -0.06929108500480652
# Process ID: 678 [Epoch: 18, 345000/ 848835 points] total loss per batch: 0.01057
# Value: -0.022075055167078972 0.0045167552307248116
# Process ID: 678 [Epoch: 18, 346000/ 848835 points] total loss per batch: 0.00976
# Value: -0.05298013240098953 -0.07471928000450134
# Process ID: 678 [Epoch: 18, 347000/ 848835 points] total loss per batch: 0.01012
# Value: 0.1743929386138916 0.15877622365951538
# Process ID: 678 [Epoch: 18, 348000/ 848835 points] total loss per batch: 0.01054
# Value: -0.1346578299999237 -0.030948257073760033
# Process ID: 678 [Epoch: 18, 349000/ 848835 points] total loss per batch: 0.01122
# Value: 0.07505518943071365 -0.07540897279977798
# Process ID: 678 [Epoch: 18, 350000/ 848835 points] total loss per batch: 0.01008
# Value: -0.20529800653457642 -0.1804325133562088
# Process ID: 678 [Epoch: 18, 351000/ 848835 points] total loss per batch: 0.01177
# Value: 0.6887417435646057 0.6756026148796082
# Process ID: 678 [Epoch: 18, 352000/ 848835 points] total loss per batch: 0.01136
# Value: 0.29801324009895325 0.28577741980552673
# Process ID: 678 [Epoch: 18, 353000/ 848835 points] total loss per batch: 0.00944
# Value: 0.366445928812027 0.36291375756263733
# Process ID: 678 [Epoch: 18, 354000/ 848835 points] total loss per batch: 0.00975
# Value: -0.06181015446782112 -0.10500022768974304
# Process ID: 678 [Epoch: 18, 355000/ 848835 points] total loss per batch: 0.01039
# Value: -0.1434878557920456 -0.16804824769496918
# Process ID: 678 [Epoch: 18, 356000/ 848835 points] total loss per batch: 0.00997
# Value: -0.046357616782188416 -0.0240324754267931
# Process ID: 678 [Epoch: 18, 357000/ 848835 points] total loss per batch: 0.01254
# Value: -0.1501103788614273 -0.07601293176412582
# Process ID: 678 [Epoch: 18, 358000/ 848835 points] total loss per batch: 0.00995
# Value: -0.07284767925739288 -0.007401845417916775
# Process ID: 678 [Epoch: 18, 359000/ 848835 points] total loss per batch: 0.01100
# Value: -0.11258278042078018 -0.09933529794216156
# Process ID: 678 [Epoch: 18, 360000/ 848835 points] total loss per batch: 0.01147
# Value: 0.0066225165501236916 0.03341289609670639
# Process ID: 678 [Epoch: 18, 361000/ 848835 points] total loss per batch: 0.00968
# Value: -0.1192052960395813 -0.4327600598335266
# Process ID: 678 [Epoch: 18, 362000/ 848835 points] total loss per batch: 0.01052
# Value: 0.1192052960395813 0.02708078920841217
# Process ID: 678 [Epoch: 18, 363000/ 848835 points] total loss per batch: 0.01132
# Value: -0.10375276207923889 -0.1097870022058487
# Process ID: 678 [Epoch: 18, 364000/ 848835 points] total loss per batch: 0.01132
# Value: -0.022075055167078972 0.05510258674621582
# Process ID: 678 [Epoch: 18, 365000/ 848835 points] total loss per batch: 0.00970
# Value: -0.1434878557920456 -0.11119589954614639
# Process ID: 678 [Epoch: 18, 366000/ 848835 points] total loss per batch: 0.00935
# Value: -0.8918322324752808 -0.7954292297363281
# Process ID: 678 [Epoch: 18, 367000/ 848835 points] total loss per batch: 0.01117
# Value: 0.1192052960395813 0.13970167934894562
# Process ID: 678 [Epoch: 18, 368000/ 848835 points] total loss per batch: 0.00998
# Value: -0.1501103788614273 -0.14218613505363464
# Process ID: 678 [Epoch: 18, 369000/ 848835 points] total loss per batch: 0.00989
# Value: 0.3355408310890198 0.4061540365219116
# Process ID: 678 [Epoch: 18, 370000/ 848835 points] total loss per batch: 0.00975
# Value: -0.06843267381191254 0.02277625910937786
# Process ID: 678 [Epoch: 18, 371000/ 848835 points] total loss per batch: 0.01136
# Value: 0.189845472574234 0.05783591791987419
# Process ID: 678 [Epoch: 18, 372000/ 848835 points] total loss per batch: 0.01178
# Value: -0.004415011033415794 -0.06612059473991394
# Process ID: 678 [Epoch: 18, 373000/ 848835 points] total loss per batch: 0.01095
# Value: -0.10375276207923889 -0.05253870040178299
# Process ID: 678 [Epoch: 18, 374000/ 848835 points] total loss per batch: 0.01225
# Value: 0.05077262595295906 -0.00872705690562725
# Process ID: 678 [Epoch: 18, 375000/ 848835 points] total loss per batch: 0.01081
# Value: -0.13907285034656525 -0.23367831110954285
# Process ID: 678 [Epoch: 18, 376000/ 848835 points] total loss per batch: 0.01039
# Value: -0.1192052960395813 -0.11556009948253632
# Process ID: 678 [Epoch: 18, 377000/ 848835 points] total loss per batch: 0.01093
# Value: -0.125827819108963 -0.08662692457437515
# Process ID: 678 [Epoch: 18, 378000/ 848835 points] total loss per batch: 0.01003
# Value: -0.30463576316833496 -0.21946404874324799
# Process ID: 678 [Epoch: 18, 379000/ 848835 points] total loss per batch: 0.01049
# Value: -0.24724061787128448 -0.22417430579662323
# Process ID: 678 [Epoch: 18, 380000/ 848835 points] total loss per batch: 0.00899
# Value: -0.14128035306930542 -0.21761804819107056
# Process ID: 678 [Epoch: 18, 381000/ 848835 points] total loss per batch: 0.01025
# Value: -0.12803532183170319 -0.16987577080726624
# Process ID: 678 [Epoch: 18, 382000/ 848835 points] total loss per batch: 0.01156
# Value: -0.13686534762382507 -0.07200717180967331
# Process ID: 678 [Epoch: 18, 383000/ 848835 points] total loss per batch: 0.01012
# Value: 0.01986755058169365 -0.0019661395344883204
# Process ID: 678 [Epoch: 18, 384000/ 848835 points] total loss per batch: 0.01031
# Value: -0.06401766091585159 -0.08844948559999466
# Process ID: 678 [Epoch: 18, 385000/ 848835 points] total loss per batch: 0.01109
# Value: 0.43267107009887695 0.4815948009490967
# Process ID: 678 [Epoch: 18, 386000/ 848835 points] total loss per batch: 0.01218
# Value: -0.2229580581188202 -0.27013495564460754
# Process ID: 678 [Epoch: 18, 387000/ 848835 points] total loss per batch: 0.01032
# Value: -0.16335541009902954 -0.08093143999576569
# Process ID: 678 [Epoch: 18, 388000/ 848835 points] total loss per batch: 0.01163
# Value: -0.13245032727718353 -0.057006943970918655
# Process ID: 678 [Epoch: 18, 389000/ 848835 points] total loss per batch: 0.01033
# Value: 0.07726269215345383 0.01571255922317505
# Process ID: 678 [Epoch: 18, 390000/ 848835 points] total loss per batch: 0.01101
# Value: -0.18763796985149384 -0.11652453988790512
# Process ID: 678 [Epoch: 18, 391000/ 848835 points] total loss per batch: 0.00939
# Value: -0.443708598613739 -0.4490891098976135
# Process ID: 678 [Epoch: 18, 392000/ 848835 points] total loss per batch: 0.01132
# Value: 0.12362030893564224 0.09093426913022995
# Process ID: 678 [Epoch: 18, 393000/ 848835 points] total loss per batch: 0.01006
# Value: -0.10375276207923889 -0.08821599185466766
# Process ID: 678 [Epoch: 18, 394000/ 848835 points] total loss per batch: 0.01013
# Value: 0.17218543589115143 0.4669894874095917
# Process ID: 678 [Epoch: 18, 395000/ 848835 points] total loss per batch: 0.01030
# Value: -0.17880794405937195 -0.14934977889060974
# Process ID: 678 [Epoch: 18, 396000/ 848835 points] total loss per batch: 0.01005
# Value: -0.1589404046535492 -0.07547467201948166
# Process ID: 678 [Epoch: 18, 397000/ 848835 points] total loss per batch: 0.00976
# Value: -0.11479029059410095 -0.07084106653928757
# Process ID: 678 [Epoch: 18, 398000/ 848835 points] total loss per batch: 0.01115
# Value: 0.13245032727718353 0.15229292213916779
# Process ID: 678 [Epoch: 18, 399000/ 848835 points] total loss per batch: 0.01117
# Value: -0.8984547257423401 -0.8168051242828369
# Process ID: 678 [Epoch: 18, 400000/ 848835 points] total loss per batch: 0.00949
# Value: -0.04856512323021889 -0.05708561837673187
# Process ID: 678 [Epoch: 18, 401000/ 848835 points] total loss per batch: 0.01099
# Value: -0.1589404046535492 -0.18553894758224487
# Process ID: 678 [Epoch: 18, 402000/ 848835 points] total loss per batch: 0.00982
# Value: 0.23399558663368225 0.10778390616178513
# Process ID: 678 [Epoch: 18, 403000/ 848835 points] total loss per batch: 0.01027
# Value: -0.14790287613868713 -0.11588753014802933
# Process ID: 678 [Epoch: 18, 404000/ 848835 points] total loss per batch: 0.01264
# Value: -0.1986754983663559 -0.09226182848215103
# Process ID: 678 [Epoch: 18, 405000/ 848835 points] total loss per batch: 0.01103
# Value: 0.1501103788614273 -0.057182759046554565
# Process ID: 678 [Epoch: 18, 406000/ 848835 points] total loss per batch: 0.01030
# Value: -0.14569535851478577 -0.11886919289827347
# Process ID: 678 [Epoch: 18, 407000/ 848835 points] total loss per batch: 0.01133
# Value: 0.41059601306915283 0.42308494448661804
# Process ID: 678 [Epoch: 18, 408000/ 848835 points] total loss per batch: 0.01236
# Value: 0.2869757115840912 0.24267934262752533
# Process ID: 678 [Epoch: 18, 409000/ 848835 points] total loss per batch: 0.01078
# Value: -0.04194260388612747 -0.08466802537441254
# Process ID: 678 [Epoch: 18, 410000/ 848835 points] total loss per batch: 0.00917
# Value: 0.8741722106933594 0.884775698184967
# Process ID: 678 [Epoch: 18, 411000/ 848835 points] total loss per batch: 0.01195
# Value: -0.094922736287117 -0.01125037670135498
# Process ID: 678 [Epoch: 18, 412000/ 848835 points] total loss per batch: 0.01029
# Value: -0.2229580581188202 -0.1871299296617508
# Process ID: 678 [Epoch: 18, 413000/ 848835 points] total loss per batch: 0.01006
# Value: 0.19426049292087555 0.17373742163181305
# Process ID: 678 [Epoch: 18, 414000/ 848835 points] total loss per batch: 0.01050
# Value: -0.01986755058169365 -0.10333007574081421
# Process ID: 678 [Epoch: 18, 415000/ 848835 points] total loss per batch: 0.01176
# Value: -0.20309050381183624 -0.18348659574985504
# Process ID: 678 [Epoch: 18, 416000/ 848835 points] total loss per batch: 0.01125
# Value: -0.49668875336647034 -0.46316757798194885
# Process ID: 678 [Epoch: 18, 417000/ 848835 points] total loss per batch: 0.01314
# Value: 0.3554084002971649 0.2537570297718048
# Process ID: 678 [Epoch: 18, 418000/ 848835 points] total loss per batch: 0.00967
# Value: -0.08830022066831589 -0.13072575628757477
# Process ID: 678 [Epoch: 18, 419000/ 848835 points] total loss per batch: 0.01031
# Value: -0.8432670831680298 -0.5388720035552979
# Process ID: 678 [Epoch: 18, 420000/ 848835 points] total loss per batch: 0.00996
# ...
# Process ID: 678 [Epoch: 20, 726000/ 848835 points] total loss per batch: 0.01291
# Value: 0.5298013091087341 0.4167022705078125
# Process ID: 678 [Epoch: 20, 727000/ 848835 points] total loss per batch: 0.01136
# Value: -0.10596026480197906 -0.18200509250164032
# Process ID: 678 [Epoch: 20, 728000/ 848835 points] total loss per batch: 0.01277
# Value: 0.1501103788614273 -0.04581955075263977
# Process ID: 678 [Epoch: 20, 729000/ 848835 points] total loss per batch: 0.01001
# Value: -0.026490066200494766 0.06701851636171341
# Process ID: 678 [Epoch: 20, 730000/ 848835 points] total loss per batch: 0.00926
# Value: -0.10154525190591812 -0.09968563914299011
# Process ID: 678 [Epoch: 20, 731000/ 848835 points] total loss per batch: 0.00917
# Value: -0.17218543589115143 -0.3278464078903198
# Process ID: 678 [Epoch: 20, 732000/ 848835 points] total loss per batch: 0.01055
# Value: -0.2935982346534729 -0.17307473719120026
# Process ID: 678 [Epoch: 20, 733000/ 848835 points] total loss per batch: 0.01054
# Value: -0.08388520777225494 -0.010429730638861656
# Process ID: 678 [Epoch: 20, 734000/ 848835 points] total loss per batch: 0.01171
# Value: -0.10154525190591812 0.053863171488046646
# Process ID: 678 [Epoch: 20, 735000/ 848835 points] total loss per batch: 0.01112
# Value: -0.24944812059402466 -0.16880331933498383
# Process ID: 678 [Epoch: 20, 736000/ 848835 points] total loss per batch: 0.01091
# Value: 0.3642384111881256 0.12284546345472336
# Process ID: 678 [Epoch: 20, 737000/ 848835 points] total loss per batch: 0.01066
# Value: -0.08167770504951477 -0.043185051530599594
# Process ID: 678 [Epoch: 20, 738000/ 848835 points] total loss per batch: 0.00945
# Value: -0.2715231776237488 -0.18245920538902283
# Process ID: 678 [Epoch: 20, 739000/ 848835 points] total loss per batch: 0.01012
# Value: 0.2869757115840912 0.3025890588760376
# Process ID: 678 [Epoch: 20, 740000/ 848835 points] total loss per batch: 0.01121
# Value: 0.01545253861695528 -0.09410436451435089
# Process ID: 678 [Epoch: 20, 741000/ 848835 points] total loss per batch: 0.00923
# Value: -0.3399558365345001 -0.26404765248298645
# Process ID: 678 [Epoch: 20, 742000/ 848835 points] total loss per batch: 0.00870
# Value: 0.6666666865348816 0.4655349552631378
# Process ID: 678 [Epoch: 20, 743000/ 848835 points] total loss per batch: 0.00858
# Value: 0.03752759471535683 -0.027072414755821228
# Process ID: 678 [Epoch: 20, 744000/ 848835 points] total loss per batch: 0.00957
# Value: 0.01986755058169365 0.014664854854345322
# Process ID: 678 [Epoch: 20, 745000/ 848835 points] total loss per batch: 0.01032
# Value: 0.1346578299999237 0.06645932793617249
# Process ID: 678 [Epoch: 20, 746000/ 848835 points] total loss per batch: 0.00945
# Value: -0.09713024646043777 -0.06372198462486267
# Process ID: 678 [Epoch: 20, 747000/ 848835 points] total loss per batch: 0.01023
# Value: 0.10154525190591812 0.013870684430003166
# Process ID: 678 [Epoch: 20, 748000/ 848835 points] total loss per batch: 0.00954
# Value: 0.21633553504943848 0.4553435444831848
# Process ID: 678 [Epoch: 20, 749000/ 848835 points] total loss per batch: 0.01011
# Value: -0.1832229644060135 -0.27384623885154724
# Process ID: 678 [Epoch: 20, 750000/ 848835 points] total loss per batch: 0.00872
# Value: 0.21192052960395813 0.32953932881355286
# Process ID: 678 [Epoch: 20, 751000/ 848835 points] total loss per batch: 0.01146
# Value: -0.15673288702964783 -0.16577903926372528
# Process ID: 678 [Epoch: 20, 752000/ 848835 points] total loss per batch: 0.00933
# Value: -0.4503311216831207 -0.3760966658592224
# Process ID: 678 [Epoch: 20, 753000/ 848835 points] total loss per batch: 0.01040
# Value: 0.13245032727718353 0.030763931572437286
# Process ID: 678 [Epoch: 20, 754000/ 848835 points] total loss per batch: 0.00982
# Value: 0.03311258181929588 -0.018703388050198555
# Process ID: 678 [Epoch: 20, 755000/ 848835 points] total loss per batch: 0.01073
# Value: -0.10154525190591812 -0.16974793374538422
# Process ID: 678 [Epoch: 20, 756000/ 848835 points] total loss per batch: 0.00921
# Value: 0.3973509967327118 0.33837080001831055
# Process ID: 678 [Epoch: 20, 757000/ 848835 points] total loss per batch: 0.00999
# Value: 0.11699779331684113 0.12356061488389969
# Process ID: 678 [Epoch: 20, 758000/ 848835 points] total loss per batch: 0.00843
# Value: -0.03090507723391056 -0.013109400868415833
# Process ID: 678 [Epoch: 20, 759000/ 848835 points] total loss per batch: 0.00970
# Value: -0.13686534762382507 -0.04645630344748497
# Process ID: 678 [Epoch: 20, 760000/ 848835 points] total loss per batch: 0.00961
# Value: 0.30463576316833496 0.4509945213794708
# Process ID: 678 [Epoch: 20, 761000/ 848835 points] total loss per batch: 0.01102
# Value: -0.07284767925739288 -0.06635469198226929
# Process ID: 678 [Epoch: 20, 762000/ 848835 points] total loss per batch: 0.01040
# Value: 0.3245033025741577 0.27517813444137573
# Process ID: 678 [Epoch: 20, 763000/ 848835 points] total loss per batch: 0.00917
# Value: -0.2450331151485443 -0.19970044493675232
# Process ID: 678 [Epoch: 20, 764000/ 848835 points] total loss per batch: 0.00928
# Value: -0.1346578299999237 -0.06600221991539001
# Process ID: 678 [Epoch: 20, 765000/ 848835 points] total loss per batch: 0.00956
# Value: -0.07505518943071365 -0.12776830792427063
# Process ID: 678 [Epoch: 20, 766000/ 848835 points] total loss per batch: 0.00930
# Value: -0.5320088267326355 -0.4346839189529419
# Process ID: 678 [Epoch: 20, 767000/ 848835 points] total loss per batch: 0.01024
# Value: 0.022075055167078972 -0.09877137839794159
# Process ID: 678 [Epoch: 20, 768000/ 848835 points] total loss per batch: 0.00899
# Value: 0.017660044133663177 -0.04594660922884941
# Process ID: 678 [Epoch: 20, 769000/ 848835 points] total loss per batch: 0.00845
# Value: 0.07505518943071365 0.051808666437864304
# Process ID: 678 [Epoch: 20, 770000/ 848835 points] total loss per batch: 0.00919
# Value: -0.06622516363859177 -0.28042158484458923
# Process ID: 678 [Epoch: 20, 771000/ 848835 points] total loss per batch: 0.00944
# Value: -0.13024282455444336 -0.1260984092950821
# Process ID: 678 [Epoch: 20, 772000/ 848835 points] total loss per batch: 0.00966
# Value: -0.8145695328712463 -0.8524906039237976
# Process ID: 678 [Epoch: 20, 773000/ 848835 points] total loss per batch: 0.00966
# Value: -0.3267108201980591 -0.3589995503425598
# Process ID: 678 [Epoch: 20, 774000/ 848835 points] total loss per batch: 0.01063
# Value: -0.5452538728713989 -0.36316075921058655
# Process ID: 678 [Epoch: 20, 775000/ 848835 points] total loss per batch: 0.00953
# Value: -0.20309050381183624 -0.004048115108162165
# Process ID: 678 [Epoch: 20, 776000/ 848835 points] total loss per batch: 0.00964
# Value: 0.11037527769804001 0.06243553385138512
# Process ID: 678 [Epoch: 20, 777000/ 848835 points] total loss per batch: 0.00913
# Value: -0.07284767925739288 -0.08264394849538803
# Process ID: 678 [Epoch: 20, 778000/ 848835 points] total loss per batch: 0.01010
# Value: 0.03752759471535683 -0.028829045593738556
# Process ID: 678 [Epoch: 20, 779000/ 848835 points] total loss per batch: 0.00974
# Value: -0.09933774918317795 -0.11283769458532333
# Process ID: 678 [Epoch: 20, 780000/ 848835 points] total loss per batch: 0.00987
# Value: 0.14790287613868713 0.09697160124778748
# Process ID: 678 [Epoch: 20, 781000/ 848835 points] total loss per batch: 0.00959
# Value: 0.15231788158416748 0.09964945167303085
# Process ID: 678 [Epoch: 20, 782000/ 848835 points] total loss per batch: 0.00924
# Value: -0.23178808391094208 -0.29396986961364746
# Process ID: 678 [Epoch: 20, 783000/ 848835 points] total loss per batch: 0.01163
# Value: -0.9161148071289062 -0.7680347561836243
# Process ID: 678 [Epoch: 20, 784000/ 848835 points] total loss per batch: 0.01119
# Value: 0.4348785877227783 0.2885969579219818
# Process ID: 678 [Epoch: 20, 785000/ 848835 points] total loss per batch: 0.00988
# Value: 0.8432670831680298 0.7691881656646729
# Process ID: 678 [Epoch: 20, 786000/ 848835 points] total loss per batch: 0.00945
# Value: -0.14790287613868713 -0.05998724699020386
# Process ID: 678 [Epoch: 20, 787000/ 848835 points] total loss per batch: 0.00981
# Value: 0.057395145297050476 0.07075685262680054
# Process ID: 678 [Epoch: 20, 788000/ 848835 points] total loss per batch: 0.01096
# Value: -0.17880794405937195 -0.12420167028903961
# Process ID: 678 [Epoch: 20, 789000/ 848835 points] total loss per batch: 0.01044
# Value: -0.17660044133663177 -0.12155306339263916
# Process ID: 678 [Epoch: 20, 790000/ 848835 points] total loss per batch: 0.00803
# Value: -0.18543046712875366 -0.235601544380188
# Process ID: 678 [Epoch: 20, 791000/ 848835 points] total loss per batch: 0.00985
# Value: -0.1434878557920456 -0.1299973726272583
# Process ID: 678 [Epoch: 20, 792000/ 848835 points] total loss per batch: 0.01006
# Value: 0.07284767925739288 0.12075537443161011
# Process ID: 678 [Epoch: 20, 793000/ 848835 points] total loss per batch: 0.01007
# Value: 0.06622516363859177 0.12372196465730667
# Process ID: 678 [Epoch: 20, 794000/ 848835 points] total loss per batch: 0.00906
# Value: -0.0066225165501236916 0.036977432668209076
# Process ID: 678 [Epoch: 20, 795000/ 848835 points] total loss per batch: 0.00942
# Value: 0.09050772339105606 0.019199546426534653
# Process ID: 678 [Epoch: 20, 796000/ 848835 points] total loss per batch: 0.01059
# Value: -0.14569535851478577 -0.065172478556633
# Process ID: 678 [Epoch: 20, 797000/ 848835 points] total loss per batch: 0.00888
# Value: -0.026490066200494766 -0.005172919947654009
# Process ID: 678 [Epoch: 20, 798000/ 848835 points] total loss per batch: 0.00835
# Value: 0.251655638217926 0.3669078052043915
# Process ID: 678 [Epoch: 20, 799000/ 848835 points] total loss per batch: 0.00980
# Value: 0.5761589407920837 0.5796627998352051
# Process ID: 678 [Epoch: 20, 800000/ 848835 points] total loss per batch: 0.00942
# Value: -0.13245032727718353 -0.10915978997945786
# Process ID: 678 [Epoch: 20, 801000/ 848835 points] total loss per batch: 0.00906
# Value: 0.06622516363859177 0.02380572445690632
# Process ID: 678 [Epoch: 20, 802000/ 848835 points] total loss per batch: 0.00930
# Value: -0.08830022066831589 -0.07084851711988449
# Process ID: 678 [Epoch: 20, 803000/ 848835 points] total loss per batch: 0.00935
# Value: -0.10375276207923889 -0.09771343320608139
# Process ID: 678 [Epoch: 20, 804000/ 848835 points] total loss per batch: 0.01087
# Value: -0.12362030893564224 -0.04244212433695793
# Process ID: 678 [Epoch: 20, 805000/ 848835 points] total loss per batch: 0.01152
# Value: -0.17660044133663177 -0.0690910816192627
# Process ID: 678 [Epoch: 20, 806000/ 848835 points] total loss per batch: 0.00959
# Value: 0.09271523356437683 0.16577407717704773
# Process ID: 678 [Epoch: 20, 807000/ 848835 points] total loss per batch: 0.00907
# Value: 0.18763796985149384 0.14732781052589417
# Process ID: 678 [Epoch: 20, 808000/ 848835 points] total loss per batch: 0.00993
# Value: -0.1434878557920456 -0.14854608476161957
# Process ID: 678 [Epoch: 20, 809000/ 848835 points] total loss per batch: 0.01103
# Value: -0.09050772339105606 0.05618474259972572
# Process ID: 678 [Epoch: 20, 810000/ 848835 points] total loss per batch: 0.01098
# Value: 0.03752759471535683 -0.017017787322402
# Process ID: 678 [Epoch: 20, 811000/ 848835 points] total loss per batch: 0.01127
# Value: -0.1986754983663559 -0.29413241147994995
# Process ID: 678 [Epoch: 20, 812000/ 848835 points] total loss per batch: 0.00965
# Value: -0.11258278042078018 -0.06711617857217789
# Process ID: 678 [Epoch: 20, 813000/ 848835 points] total loss per batch: 0.00968
# Value: -0.06843267381191254 -0.09033689647912979
# Process ID: 678 [Epoch: 20, 814000/ 848835 points] total loss per batch: 0.01153
# Value: -0.13024282455444336 -0.1552600860595703
# Process ID: 678 [Epoch: 20, 815000/ 848835 points] total loss per batch: 0.01171
# Value: -0.10375276207923889 -0.01200074702501297
# Process ID: 678 [Epoch: 20, 816000/ 848835 points] total loss per batch: 0.01178
# Value: -0.05960264801979065 -0.18537838757038116
# Process ID: 678 [Epoch: 20, 817000/ 848835 points] total loss per batch: 0.01098
# Value: -0.094922736287117 -0.39388877153396606
# Process ID: 678 [Epoch: 20, 818000/ 848835 points] total loss per batch: 0.00807
# Value: -0.03752759471535683 -0.0451127327978611
# Process ID: 678 [Epoch: 20, 819000/ 848835 points] total loss per batch: 0.01031
# Value: -0.07726269215345383 -0.1427592784166336
# Process ID: 678 [Epoch: 20, 820000/ 848835 points] total loss per batch: 0.01061
# Value: 0.9646798968315125 0.7859629988670349
# Process ID: 678 [Epoch: 20, 821000/ 848835 points] total loss per batch: 0.00990
# Value: 0.03090507723391056 0.005977813154459
# Process ID: 678 [Epoch: 20, 822000/ 848835 points] total loss per batch: 0.01034
# Value: 0.20971302688121796 -0.03779268637299538
# Process ID: 678 [Epoch: 20, 823000/ 848835 points] total loss per batch: 0.01086
# Value: 0.48123618960380554 0.16380728781223297
# Process ID: 678 [Epoch: 20, 824000/ 848835 points] total loss per batch: 0.00967
# Value: 0.3907284736633301 0.5345982909202576
# Process ID: 678 [Epoch: 20, 825000/ 848835 points] total loss per batch: 0.00946
# Value: 0.17218543589115143 0.06721623986959457
# Process ID: 678 [Epoch: 20, 826000/ 848835 points] total loss per batch: 0.01120
# Value: -0.6114790439605713 -0.7226499319076538
# Process ID: 678 [Epoch: 20, 827000/ 848835 points] total loss per batch: 0.00973
# Value: 0.08167770504951477 0.041372206062078476
# Process ID: 678 [Epoch: 20, 828000/ 848835 points] total loss per batch: 0.01044
# Value: -0.004415011033415794 -0.07290942221879959
# Process ID: 678 [Epoch: 20, 829000/ 848835 points] total loss per batch: 0.00988
# Value: -0.1677704155445099 -0.12925408780574799
# Process ID: 678 [Epoch: 20, 830000/ 848835 points] total loss per batch: 0.00989
# Value: 0.2229580581188202 0.2803569734096527
# Process ID: 678 [Epoch: 20, 831000/ 848835 points] total loss per batch: 0.00886
# Value: -0.13024282455444336 -0.10145466774702072
# Process ID: 678 [Epoch: 20, 832000/ 848835 points] total loss per batch: 0.01053
# Value: -0.7152317762374878 -0.8649113774299622
# Process ID: 678 [Epoch: 20, 833000/ 848835 points] total loss per batch: 0.01028
# Value: -0.20529800653457642 -0.24701306223869324
# Process ID: 678 [Epoch: 20, 834000/ 848835 points] total loss per batch: 0.01070
# Value: 0.024282561615109444 -0.08153387904167175
# Process ID: 678 [Epoch: 20, 835000/ 848835 points] total loss per batch: 0.00997
# Value: -0.5651214122772217 -0.3968786597251892
# Process ID: 678 [Epoch: 20, 836000/ 848835 points] total loss per batch: 0.01046
# Value: 0.13686534762382507 -0.07600484043359756
# Process ID: 678 [Epoch: 20, 837000/ 848835 points] total loss per batch: 0.00980
# Value: -0.33774834871292114 -0.4185250699520111
# Process ID: 678 [Epoch: 20, 838000/ 848835 points] total loss per batch: 0.01112
# Value: -0.19646799564361572 -0.15906408429145813
# Process ID: 678 [Epoch: 20, 839000/ 848835 points] total loss per batch: 0.01013
# Value: 0.1832229644060135 0.19176456332206726
# Process ID: 678 [Epoch: 20, 840000/ 848835 points] total loss per batch: 0.00984
# Value: -0.04856512323021889 -0.05139700695872307
# Process ID: 678 [Epoch: 20, 841000/ 848835 points] total loss per batch: 0.01156
# Value: -0.2450331151485443 -0.21220453083515167
# Process ID: 678 [Epoch: 20, 842000/ 848835 points] total loss per batch: 0.01112
# Value: 0.10816776752471924 0.010356852784752846
# Process ID: 678 [Epoch: 20, 843000/ 848835 points] total loss per batch: 0.01161
# Value: -0.11699779331684113 -0.1327325701713562
# Process ID: 678 [Epoch: 20, 844000/ 848835 points] total loss per batch: 0.01046
# Value: -0.29580575227737427 -0.2505859136581421
# Process ID: 678 [Epoch: 20, 845000/ 848835 points] total loss per batch: 0.01212
# Value: 0.10596026480197906 0.04126548767089844
# Process ID: 678 [Epoch: 20, 846000/ 848835 points] total loss per batch: 0.01363
# Value: -0.06401766091585159 -0.09868217259645462
# Process ID: 678 [Epoch: 20, 847000/ 848835 points] total loss per batch: 0.01219
# Value: -0.26490065455436707 -0.21652851998806
# Process ID: 678 [Epoch: 20, 848000/ 848835 points] total loss per batch: 0.00915
# Value: 0.3818984627723694 0.3838566541671753
# Validation MSE Loss: 0.01831
# Current learning rate: 0.01
# Early stopping! No improvement in validation loss for 5 epochs.

# %%
losses_per_epoch_training = []
losses_per_epoch_validation = []
lr = []
for i in range(50):
    try:
        losses = np.load("Supervised_Learning/model/ResNet7_Mar27_losses_per_epoch_epoch{}.npz".format(i))
        losses_per_epoch_training.extend(losses['train_loss'])
        losses_per_epoch_validation.extend(losses['val_loss'])
        lr.extend(losses['lr'])
        except:
            continue

# plot loss per epoch
fig, axs = plt.subplots(1, 3, figsize=(12, 5))

axs[0].scatter([e for e in range(1, len(losses_per_epoch_training)+1)], losses_per_epoch_training)
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Loss per batch")
axs[0].set_title("Training Loss vs Epoch")

axs[1].scatter([e for e in range(1, len(losses_per_epoch_training)+1)], losses_per_epoch_validation)
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss per batch")
axs[1].set_title("Validation Loss vs Epoch")

axs[2].scatter([e for e in range(1, len(losses_per_epoch_training)+1)], lr)
axs[2].set_xlabel("Epoch")
axs[2].set_ylabel("Loss per batch")
axs[2].set_title("Learning Rate vs Epoch")

plt.tight_layout()
plt.show()
