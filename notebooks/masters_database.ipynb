# %%
import psycopg2
from psycopg2 import sql
from psycopg2.extras import execute_values
from joblib import load

from board_utils import *

# %%
assets_path = os.path.join(os.path.dirname(os.getcwd()), 'data')
single_path = os.path.join(assets_path, 'caissa_master.pgn')
total_games = 619384

#games = load_pgns(single_path, total_games)
#games = [game for game in games if len(str(game.mainline_moves())) > 0]
#print(f'Pre-arranged draw rate: {len(games)/total_games:.2f}%')
#print(f'Total Games: {len(games)}')

# %%
def get_keys_func(board_vec):
    self_material_count = int(sum(board_vec[780:785] * [0,6,6,10,9]))
    opp_material_count = int(sum(board_vec[785:790] * [0,6,6,10,9]))
    diff_material_count = self_material_count - opp_material_count
    self_castle_available = int(sum(board_vec[768:770]) > 0)
    opp_castle_available = int(sum(board_vec[770:772]) > 0)
    position_in_endgame = int(sum(board_vec[780:790] * [0,2,2,2,1,0,2,2,2,1]) < 6)
    return self_material_count, opp_material_count, diff_material_count, self_castle_available, opp_castle_available, position_in_endgame

# %%
conn = psycopg2.connect(
    dbname="capstone",
    user="postgres",
    password="postgres",
)

cur = conn.cursor()

# %%
def insert_or_get_player_id(player_details):
    cur.execute("SELECT player_id FROM players WHERE player_fide_id = %s OR player_name = %s", 
                (player_details['fide_id'], player_details['name']))
    result = cur.fetchone()
    if result:
        return result[0]
    else:
        cur.execute("INSERT INTO players (player_fide_id, player_name) VALUES (%s, %s) RETURNING player_id", 
                    (player_details['fide_id'], player_details['name']))
        conn.commit()
        return cur.fetchone()[0]

def make_capstone_table():
    create_table_positions = """
    CREATE TABLE IF NOT EXISTS positions (
        position_id SERIAL,
        game_id INT,
        self_material_count INT,
        opp_material_count INT,
        diff_material_count INT,
        self_castle_available INT,
        opp_castle_available INT,
        position_in_endgame INT,
        vector_int INT[],
        vector_float REAL[],
        PRIMARY KEY(position_id)
    )
    """

    create_table_players = """
    CREATE TABLE IF NOT EXISTS players (
        player_id SERIAL,
        player_fide_id INT,
        player_name VARCHAR(256),
        PRIMARY KEY(player_id)
    )
    """

    create_table_game_details = """
    CREATE TABLE IF NOT EXISTS games (
        game_id SERIAL,
        white_id INT,
        black_id INT,
        white_elo INT,
        black_elo INT,
        white_title VARCHAR(16),
        black_title VARCHAR(16),
        event VARCHAR(256),
        site VARCHAR(256),
        date VARCHAR(64),
        round VARCHAR(64),
        result VARCHAR(16),
        eco VARCHAR(16),
        opening VARCHAR(256),
        variation VARCHAR(256),
        PRIMARY KEY(game_id)
    )
    """

    cur.execute("DROP TABLE IF EXISTS positions")
    cur.execute("DROP TABLE IF EXISTS players")
    cur.execute("DROP TABLE IF EXISTS games")
    cur.execute(create_table_positions)
    cur.execute(create_table_players)
    cur.execute(create_table_game_details)

    for game_count, game in enumerate(games):
        metadata_dict = dict(game.headers)
        game_matrix = game_to_csr_matrix(game, csr=False)

        cur.execute("""
        INSERT INTO games (event, site, date, round, result, eco, opening, variation, white_elo, black_elo, white_title, black_title) 
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s) RETURNING game_id
        """, (
            metadata_dict.get('Event'), metadata_dict.get('Site'), metadata_dict.get('Date'),
            metadata_dict.get('Round'), metadata_dict.get('Result'), metadata_dict.get('ECO'),
            metadata_dict.get('Opening'), metadata_dict.get('Variation'), metadata_dict.get('WhiteElo'),
            metadata_dict.get('BlackElo'), metadata_dict.get('WhiteTitle'), metadata_dict.get('BlackTitle')
        ))
        game_id = cur.fetchone()[0]
        
        white_id = insert_or_get_player_id({'fide_id': metadata_dict.get('WhiteFideId'), 'name': metadata_dict['White']})
        black_id = insert_or_get_player_id({'fide_id': metadata_dict.get('BlackFideId'), 'name': metadata_dict['Black']})
        cur.execute("UPDATE games SET white_id = %s, black_id = %s WHERE game_id = %s", (white_id, black_id, game_id))

        integer_matrix = game_matrix[:, :780]
        float_matrix = game_matrix[:, 780:]
        
        position_records = []
        for i in range(len(game_matrix)):
            position_vars = get_keys_func(np.concatenate([integer_matrix[i], float_matrix[i]]))
            position_record = (game_id, *position_vars, list(integer_matrix[i]), list(float_matrix[i]))
            position_records.append(position_record)

        execute_values(cur, """
        INSERT INTO positions (game_id, self_material_count, opp_material_count, diff_material_count, 
        self_castle_available, opp_castle_available, position_in_endgame, vector_int, vector_float) 
        VALUES %s
        """, position_records)
        if game_count % 64 == 0:
            conn.commit()
    conn.commit()

# %%
def clear_column(colname='pgn_string', table='games', data="VARCHAR(4096)", cur=cur, conn=conn):
    query = f"ALTER TABLE {table} DROP COLUMN IF EXISTS {colname}"
    cur.execute(query)
    query = f"ALTER TABLE {table} ADD COLUMN {colname} {data}"
    cur.execute(query)
    conn.commit()

# %%
def pgn_into_capstone_table():
    full_pgn_gen = (str(g) for g in games)
    clear_column('pgn_string')
    game_id = 0

    for pgn_string in full_pgn_gen:
        game_id += 1
        insert_pgn = """UPDATE games SET pgn_string = %s WHERE game_id = %s"""
        cur.execute(insert_pgn, (pgn_string, game_id))

        if game_id%100==0:
            conn.commit()
    conn.commit()

def insert_svd_vectors(cur, conn, total_rows, batch_size):
    svd = load('orient_svd_model.joblib')
    total_batches = (total_rows + batch_size - 1) // batch_size
    print('Initializing svd_vector...')
    clear_column('svd_vector', 'positions', 'REAL[]')
    
    print('Processing Positions...')
    for current_batch in range(1, total_batches + 1):
        query = f"""
        SELECT position_id, vector_int || vector_float 
        FROM positions WHERE position_id > {(current_batch-1)*batch_size} 
        AND position_id <= {current_batch*batch_size}
        ORDER BY position_id
        """

        cur.execute(query)
        matches = cur.fetchall()

        matches_mat = np.array([m[1][:790] for m in matches])
        mat_reduced = svd.transform(matches_mat)

        for idx, (position_id, _) in enumerate(matches):
            update_query = "UPDATE positions SET svd_vector = %s WHERE position_id = %s"
            cur.execute(update_query, (mat_reduced[idx].tolist(), position_id))
            
        conn.commit()

        print(f"Batch {current_batch}/{total_batches} processed and updated.")

# %%
total_pos = 53301303
batch_size = 100000

#make_capstone_table() # 30 hours
#pgn_into_capstone_table() # 30 minutes
#insert_svd_vectors(cur, conn, total_pos, batch_size) #6.5 hours
# Out:
# Initializing svd_vector...
# Processing Positions...
# Batch 1/534 processed and updated.
# Batch 2/534 processed and updated.
# Batch 3/534 processed and updated.
# Batch 4/534 processed and updated.
# Batch 5/534 processed and updated.
# Batch 6/534 processed and updated.
# Batch 7/534 processed and updated.
# Batch 8/534 processed and updated.
# Batch 9/534 processed and updated.
# Batch 10/534 processed and updated.
# Batch 11/534 processed and updated.
# Batch 12/534 processed and updated.
# Batch 13/534 processed and updated.
# Batch 14/534 processed and updated.
# Batch 15/534 processed and updated.
# Batch 16/534 processed and updated.
# Batch 17/534 processed and updated.
# Batch 18/534 processed and updated.
# Batch 19/534 processed and updated.
# Batch 20/534 processed and updated.
# Batch 21/534 processed and updated.
# Batch 22/534 processed and updated.
# Batch 23/534 processed and updated.
# Batch 24/534 processed and updated.
# Batch 25/534 processed and updated.
# Batch 26/534 processed and updated.
# Batch 27/534 processed and updated.
# Batch 28/534 processed and updated.
# Batch 29/534 processed and updated.
# Batch 30/534 processed and updated.
# Batch 31/534 processed and updated.
# Batch 32/534 processed and updated.
# Batch 33/534 processed and updated.
# Batch 34/534 processed and updated.
# Batch 35/534 processed and updated.
# Batch 36/534 processed and updated.
# Batch 37/534 processed and updated.
# Batch 38/534 processed and updated.
# Batch 39/534 processed and updated.
# Batch 40/534 processed and updated.
# Batch 41/534 processed and updated.
# Batch 42/534 processed and updated.
# Batch 43/534 processed and updated.
# Batch 44/534 processed and updated.
# Batch 45/534 processed and updated.
# Batch 46/534 processed and updated.
# Batch 47/534 processed and updated.
# Batch 48/534 processed and updated.
# Batch 49/534 processed and updated.
# Batch 50/534 processed and updated.
# Batch 51/534 processed and updated.
# Batch 52/534 processed and updated.
# Batch 53/534 processed and updated.
# Batch 54/534 processed and updated.
# Batch 55/534 processed and updated.
# Batch 56/534 processed and updated.
# Batch 57/534 processed and updated.
# Batch 58/534 processed and updated.
# Batch 59/534 processed and updated.
# Batch 60/534 processed and updated.
# Batch 61/534 processed and updated.
# Batch 62/534 processed and updated.
# Batch 63/534 processed and updated.
# Batch 64/534 processed and updated.
# Batch 65/534 processed and updated.
# Batch 66/534 processed and updated.
# Batch 67/534 processed and updated.
# Batch 68/534 processed and updated.
# Batch 69/534 processed and updated.
# Batch 70/534 processed and updated.
# Batch 71/534 processed and updated.
# Batch 72/534 processed and updated.
# Batch 73/534 processed and updated.
# Batch 74/534 processed and updated.
# Batch 75/534 processed and updated.
# Batch 76/534 processed and updated.
# Batch 77/534 processed and updated.
# Batch 78/534 processed and updated.
# Batch 79/534 processed and updated.
# Batch 80/534 processed and updated.
# Batch 81/534 processed and updated.
# Batch 82/534 processed and updated.
# Batch 83/534 processed and updated.
# Batch 84/534 processed and updated.
# Batch 85/534 processed and updated.
# Batch 86/534 processed and updated.
# Batch 87/534 processed and updated.
# Batch 88/534 processed and updated.
# Batch 89/534 processed and updated.
# Batch 90/534 processed and updated.
# Batch 91/534 processed and updated.
# Batch 92/534 processed and updated.
# Batch 93/534 processed and updated.
# Batch 94/534 processed and updated.
# Batch 95/534 processed and updated.
# Batch 96/534 processed and updated.
# Batch 97/534 processed and updated.
# Batch 98/534 processed and updated.
# Batch 99/534 processed and updated.
# Batch 100/534 processed and updated.
# Batch 101/534 processed and updated.
# Batch 102/534 processed and updated.
# Batch 103/534 processed and updated.
# Batch 104/534 processed and updated.
# Batch 105/534 processed and updated.
# Batch 106/534 processed and updated.
# Batch 107/534 processed and updated.
# Batch 108/534 processed and updated.
# Batch 109/534 processed and updated.
# Batch 110/534 processed and updated.
# Batch 111/534 processed and updated.
# Batch 112/534 processed and updated.
# Batch 113/534 processed and updated.
# Batch 114/534 processed and updated.
# Batch 115/534 processed and updated.
# Batch 116/534 processed and updated.
# Batch 117/534 processed and updated.
# Batch 118/534 processed and updated.
# Batch 119/534 processed and updated.
# Batch 120/534 processed and updated.
# Batch 121/534 processed and updated.
# Batch 122/534 processed and updated.
# Batch 123/534 processed and updated.
# Batch 124/534 processed and updated.
# Batch 125/534 processed and updated.
# Batch 126/534 processed and updated.
# Batch 127/534 processed and updated.
# Batch 128/534 processed and updated.
# Batch 129/534 processed and updated.
# Batch 130/534 processed and updated.
# Batch 131/534 processed and updated.
# Batch 132/534 processed and updated.
# Batch 133/534 processed and updated.
# Batch 134/534 processed and updated.
# Batch 135/534 processed and updated.
# Batch 136/534 processed and updated.
# Batch 137/534 processed and updated.
# Batch 138/534 processed and updated.
# Batch 139/534 processed and updated.
# Batch 140/534 processed and updated.
# Batch 141/534 processed and updated.
# Batch 142/534 processed and updated.
# Batch 143/534 processed and updated.
# Batch 144/534 processed and updated.
# Batch 145/534 processed and updated.
# Batch 146/534 processed and updated.
# Batch 147/534 processed and updated.
# Batch 148/534 processed and updated.
# Batch 149/534 processed and updated.
# Batch 150/534 processed and updated.
# Batch 151/534 processed and updated.
# Batch 152/534 processed and updated.
# Batch 153/534 processed and updated.
# Batch 154/534 processed and updated.
# Batch 155/534 processed and updated.
# Batch 156/534 processed and updated.
# Batch 157/534 processed and updated.
# Batch 158/534 processed and updated.
# Batch 159/534 processed and updated.
# Batch 160/534 processed and updated.
# Batch 161/534 processed and updated.
# Batch 162/534 processed and updated.
# Batch 163/534 processed and updated.
# Batch 164/534 processed and updated.
# Batch 165/534 processed and updated.
# Batch 166/534 processed and updated.
# Batch 167/534 processed and updated.
# Batch 168/534 processed and updated.
# Batch 169/534 processed and updated.
# Batch 170/534 processed and updated.
# Batch 171/534 processed and updated.
# Batch 172/534 processed and updated.
# Batch 173/534 processed and updated.
# Batch 174/534 processed and updated.
# Batch 175/534 processed and updated.
# Batch 176/534 processed and updated.
# Batch 177/534 processed and updated.
# Batch 178/534 processed and updated.
# Batch 179/534 processed and updated.
# Batch 180/534 processed and updated.
# Batch 181/534 processed and updated.
# Batch 182/534 processed and updated.
# Batch 183/534 processed and updated.
# Batch 184/534 processed and updated.
# Batch 185/534 processed and updated.
# Batch 186/534 processed and updated.
# Batch 187/534 processed and updated.
# Batch 188/534 processed and updated.
# Batch 189/534 processed and updated.
# Batch 190/534 processed and updated.
# Batch 191/534 processed and updated.
# Batch 192/534 processed and updated.
# Batch 193/534 processed and updated.
# Batch 194/534 processed and updated.
# Batch 195/534 processed and updated.
# Batch 196/534 processed and updated.
# Batch 197/534 processed and updated.
# Batch 198/534 processed and updated.
# Batch 199/534 processed and updated.
# Batch 200/534 processed and updated.
# Batch 201/534 processed and updated.
# Batch 202/534 processed and updated.
# Batch 203/534 processed and updated.
# Batch 204/534 processed and updated.
# Batch 205/534 processed and updated.
# Batch 206/534 processed and updated.
# Batch 207/534 processed and updated.
# Batch 208/534 processed and updated.
# Batch 209/534 processed and updated.
# Batch 210/534 processed and updated.
# Batch 211/534 processed and updated.
# Batch 212/534 processed and updated.
# Batch 213/534 processed and updated.
# Batch 214/534 processed and updated.
# Batch 215/534 processed and updated.
# Batch 216/534 processed and updated.
# Batch 217/534 processed and updated.
# Batch 218/534 processed and updated.
# Batch 219/534 processed and updated.
# Batch 220/534 processed and updated.
# Batch 221/534 processed and updated.
# Batch 222/534 processed and updated.
# Batch 223/534 processed and updated.
# Batch 224/534 processed and updated.
# Batch 225/534 processed and updated.
# Batch 226/534 processed and updated.
# Batch 227/534 processed and updated.
# Batch 228/534 processed and updated.
# Batch 229/534 processed and updated.
# Batch 230/534 processed and updated.
# Batch 231/534 processed and updated.
# Batch 232/534 processed and updated.
# Batch 233/534 processed and updated.
# Batch 234/534 processed and updated.
# Batch 235/534 processed and updated.
# Batch 236/534 processed and updated.
# Batch 237/534 processed and updated.
# Batch 238/534 processed and updated.
# Batch 239/534 processed and updated.
# Batch 240/534 processed and updated.
# Batch 241/534 processed and updated.
# Batch 242/534 processed and updated.
# Batch 243/534 processed and updated.
# Batch 244/534 processed and updated.
# Batch 245/534 processed and updated.
# Batch 246/534 processed and updated.
# Batch 247/534 processed and updated.
# Batch 248/534 processed and updated.
# Batch 249/534 processed and updated.
# Batch 250/534 processed and updated.
# Batch 251/534 processed and updated.
# Batch 252/534 processed and updated.
# Batch 253/534 processed and updated.
# Batch 254/534 processed and updated.
# Batch 255/534 processed and updated.
# Batch 256/534 processed and updated.
# Batch 257/534 processed and updated.
# Batch 258/534 processed and updated.
# Batch 259/534 processed and updated.
# Batch 260/534 processed and updated.
# Batch 261/534 processed and updated.
# Batch 262/534 processed and updated.
# Batch 263/534 processed and updated.
# Batch 264/534 processed and updated.
# Batch 265/534 processed and updated.
# Batch 266/534 processed and updated.
# Batch 267/534 processed and updated.
# Batch 268/534 processed and updated.
# Batch 269/534 processed and updated.
# Batch 270/534 processed and updated.
# Batch 271/534 processed and updated.
# Batch 272/534 processed and updated.
# Batch 273/534 processed and updated.
# Batch 274/534 processed and updated.
# Batch 275/534 processed and updated.
# Batch 276/534 processed and updated.
# Batch 277/534 processed and updated.
# Batch 278/534 processed and updated.
# Batch 279/534 processed and updated.
# Batch 280/534 processed and updated.
# Batch 281/534 processed and updated.
# Batch 282/534 processed and updated.
# Batch 283/534 processed and updated.
# Batch 284/534 processed and updated.
# Batch 285/534 processed and updated.
# Batch 286/534 processed and updated.
# Batch 287/534 processed and updated.
# Batch 288/534 processed and updated.
# Batch 289/534 processed and updated.
# Batch 290/534 processed and updated.
# Batch 291/534 processed and updated.
# Batch 292/534 processed and updated.
# Batch 293/534 processed and updated.
# Batch 294/534 processed and updated.
# Batch 295/534 processed and updated.
# Batch 296/534 processed and updated.
# Batch 297/534 processed and updated.
# Batch 298/534 processed and updated.
# Batch 299/534 processed and updated.
# Batch 300/534 processed and updated.
# Batch 301/534 processed and updated.
# Batch 302/534 processed and updated.
# Batch 303/534 processed and updated.
# Batch 304/534 processed and updated.
# Batch 305/534 processed and updated.
# Batch 306/534 processed and updated.
# Batch 307/534 processed and updated.
# Batch 308/534 processed and updated.
# Batch 309/534 processed and updated.
# Batch 310/534 processed and updated.
# Batch 311/534 processed and updated.
# Batch 312/534 processed and updated.
# Batch 313/534 processed and updated.
# Batch 314/534 processed and updated.
# Batch 315/534 processed and updated.
# Batch 316/534 processed and updated.
# Batch 317/534 processed and updated.
# Batch 318/534 processed and updated.
# Batch 319/534 processed and updated.
# Batch 320/534 processed and updated.
# Batch 321/534 processed and updated.
# Batch 322/534 processed and updated.
# Batch 323/534 processed and updated.
# Batch 324/534 processed and updated.
# Batch 325/534 processed and updated.
# Batch 326/534 processed and updated.
# Batch 327/534 processed and updated.
# Batch 328/534 processed and updated.
# Batch 329/534 processed and updated.
# Batch 330/534 processed and updated.
# Batch 331/534 processed and updated.
# Batch 332/534 processed and updated.
# Batch 333/534 processed and updated.
# Batch 334/534 processed and updated.
# Batch 335/534 processed and updated.
# Batch 336/534 processed and updated.
# Batch 337/534 processed and updated.
# Batch 338/534 processed and updated.
# Batch 339/534 processed and updated.
# Batch 340/534 processed and updated.
# Batch 341/534 processed and updated.
# Batch 342/534 processed and updated.
# Batch 343/534 processed and updated.
# Batch 344/534 processed and updated.
# Batch 345/534 processed and updated.
# Batch 346/534 processed and updated.
# Batch 347/534 processed and updated.
# Batch 348/534 processed and updated.
# Batch 349/534 processed and updated.
# Batch 350/534 processed and updated.
# Batch 351/534 processed and updated.
# Batch 352/534 processed and updated.
# Batch 353/534 processed and updated.
# Batch 354/534 processed and updated.
# Batch 355/534 processed and updated.
# Batch 356/534 processed and updated.
# Batch 357/534 processed and updated.
# Batch 358/534 processed and updated.
# Batch 359/534 processed and updated.
# Batch 360/534 processed and updated.
# Batch 361/534 processed and updated.
# Batch 362/534 processed and updated.
# Batch 363/534 processed and updated.
# Batch 364/534 processed and updated.
# Batch 365/534 processed and updated.
# Batch 366/534 processed and updated.
# Batch 367/534 processed and updated.
# Batch 368/534 processed and updated.
# Batch 369/534 processed and updated.
# Batch 370/534 processed and updated.
# Batch 371/534 processed and updated.
# Batch 372/534 processed and updated.
# Batch 373/534 processed and updated.
# Batch 374/534 processed and updated.
# Batch 375/534 processed and updated.
# Batch 376/534 processed and updated.
# Batch 377/534 processed and updated.
# Batch 378/534 processed and updated.
# Batch 379/534 processed and updated.
# Batch 380/534 processed and updated.
# Batch 381/534 processed and updated.
# Batch 382/534 processed and updated.
# Batch 383/534 processed and updated.
# Batch 384/534 processed and updated.
# Batch 385/534 processed and updated.
# Batch 386/534 processed and updated.
# Batch 387/534 processed and updated.
# Batch 388/534 processed and updated.
# Batch 389/534 processed and updated.
# Batch 390/534 processed and updated.
# Batch 391/534 processed and updated.
# Batch 392/534 processed and updated.
# Batch 393/534 processed and updated.
# Batch 394/534 processed and updated.
# Batch 395/534 processed and updated.
# Batch 396/534 processed and updated.
# Batch 397/534 processed and updated.
# Batch 398/534 processed and updated.
# Batch 399/534 processed and updated.
# Batch 400/534 processed and updated.
# Batch 401/534 processed and updated.
# Batch 402/534 processed and updated.
# Batch 403/534 processed and updated.
# Batch 404/534 processed and updated.
# Batch 405/534 processed and updated.
# Batch 406/534 processed and updated.
# Batch 407/534 processed and updated.
# Batch 408/534 processed and updated.
# Batch 409/534 processed and updated.
# Batch 410/534 processed and updated.
# Batch 411/534 processed and updated.
# Batch 412/534 processed and updated.
# Batch 413/534 processed and updated.
# Batch 414/534 processed and updated.
# Batch 415/534 processed and updated.
# Batch 416/534 processed and updated.
# Batch 417/534 processed and updated.
# Batch 418/534 processed and updated.
# Batch 419/534 processed and updated.
# Batch 420/534 processed and updated.
# Batch 421/534 processed and updated.
# Batch 422/534 processed and updated.
# Batch 423/534 processed and updated.
# Batch 424/534 processed and updated.
# Batch 425/534 processed and updated.
# Batch 426/534 processed and updated.
# Batch 427/534 processed and updated.
# Batch 428/534 processed and updated.
# Batch 429/534 processed and updated.
# Batch 430/534 processed and updated.
# Batch 431/534 processed and updated.
# Batch 432/534 processed and updated.
# Batch 433/534 processed and updated.
# Batch 434/534 processed and updated.
# Batch 435/534 processed and updated.
# Batch 436/534 processed and updated.
# Batch 437/534 processed and updated.
# Batch 438/534 processed and updated.
# Batch 439/534 processed and updated.
# Batch 440/534 processed and updated.
# Batch 441/534 processed and updated.
# Batch 442/534 processed and updated.
# Batch 443/534 processed and updated.
# Batch 444/534 processed and updated.
# Batch 445/534 processed and updated.
# Batch 446/534 processed and updated.
# Batch 447/534 processed and updated.
# Batch 448/534 processed and updated.
# Batch 449/534 processed and updated.
# Batch 450/534 processed and updated.
# Batch 451/534 processed and updated.
# Batch 452/534 processed and updated.
# Batch 453/534 processed and updated.
# Batch 454/534 processed and updated.
# Batch 455/534 processed and updated.
# Batch 456/534 processed and updated.
# Batch 457/534 processed and updated.
# Batch 458/534 processed and updated.
# Batch 459/534 processed and updated.
# Batch 460/534 processed and updated.
# Batch 461/534 processed and updated.
# Batch 462/534 processed and updated.
# Batch 463/534 processed and updated.
# Batch 464/534 processed and updated.
# Batch 465/534 processed and updated.
# Batch 466/534 processed and updated.
# Batch 467/534 processed and updated.
# Batch 468/534 processed and updated.
# Batch 469/534 processed and updated.
# Batch 470/534 processed and updated.
# Batch 471/534 processed and updated.
# Batch 472/534 processed and updated.
# Batch 473/534 processed and updated.
# Batch 474/534 processed and updated.
# Batch 475/534 processed and updated.
# Batch 476/534 processed and updated.
# Batch 477/534 processed and updated.
# Batch 478/534 processed and updated.
# Batch 479/534 processed and updated.
# Batch 480/534 processed and updated.
# Batch 481/534 processed and updated.
# Batch 482/534 processed and updated.
# Batch 483/534 processed and updated.
# Batch 484/534 processed and updated.
# Batch 485/534 processed and updated.
# Batch 486/534 processed and updated.
# Batch 487/534 processed and updated.
# Batch 488/534 processed and updated.
# Batch 489/534 processed and updated.
# Batch 490/534 processed and updated.
# Batch 491/534 processed and updated.
# Batch 492/534 processed and updated.
# Batch 493/534 processed and updated.
# Batch 494/534 processed and updated.
# Batch 495/534 processed and updated.
# Batch 496/534 processed and updated.
# Batch 497/534 processed and updated.
# Batch 498/534 processed and updated.
# Batch 499/534 processed and updated.
# Batch 500/534 processed and updated.
# Batch 501/534 processed and updated.
# Batch 502/534 processed and updated.
# Batch 503/534 processed and updated.
# Batch 504/534 processed and updated.
# Batch 505/534 processed and updated.
# Batch 506/534 processed and updated.
# Batch 507/534 processed and updated.
# Batch 508/534 processed and updated.
# Batch 509/534 processed and updated.
# Batch 510/534 processed and updated.
# Batch 511/534 processed and updated.
# Batch 512/534 processed and updated.
# Batch 513/534 processed and updated.
# Batch 514/534 processed and updated.
# Batch 515/534 processed and updated.
# Batch 516/534 processed and updated.
# Batch 517/534 processed and updated.
# Batch 518/534 processed and updated.
# Batch 519/534 processed and updated.
# Batch 520/534 processed and updated.
# Batch 521/534 processed and updated.
# Batch 522/534 processed and updated.
# Batch 523/534 processed and updated.
# Batch 524/534 processed and updated.
# Batch 525/534 processed and updated.
# Batch 526/534 processed and updated.
# Batch 527/534 processed and updated.
# Batch 528/534 processed and updated.
# Batch 529/534 processed and updated.
# Batch 530/534 processed and updated.
# Batch 531/534 processed and updated.
# Batch 532/534 processed and updated.
# Batch 533/534 processed and updated.
# Batch 534/534 processed and updated.

# %%
query = """
WITH combined_ids AS (
    SELECT black_id AS player_id FROM games
    UNION ALL
    SELECT white_id AS player_id FROM games
),
frequency AS (
    SELECT player_id, COUNT(*) AS freq
    FROM combined_ids
    GROUP BY player_id
)
SELECT p.player_name, f.freq
FROM frequency f
JOIN players p ON p.player_id = f.player_id
ORDER BY f.freq DESC LIMIT 20;
"""

cur.execute(query)
matches = cur.fetchall()
print("All matches in the database:")
for match in matches:
    print(match)

#self_material_count, opp_material_count, diff_material_count, self_castle_available, opp_castle_available, position_in_endgame
#query_fen = 'rnb2b1r/2Nnkppp/p2pp3/8/PPBN1P2/2p3Pq/4Q2P/R3K1R1 w Q - 1 17' #wild opening
#query_fen = 'rnbq1rk1/pp2ppbp/3p1np1/8/3NP3/2N1BP2/PPP3PP/R2QKB1R w KQ - 1 8' #dragon
#query_fen = 'r1bq1rk1/ppp2pbp/2np1np1/4p3/2PPP3/2N2N2/PP2BPPP/R1BQ1RK1 w - - 2 8' #kid
#query_fen = '6k1/5p2/1r2p1p1/3p1n2/3P3p/1P1R3P/4NPP1/6K1 b - - 2 36' #knight rook endgame
#query_fen = 'r4rk1/ppqn1ppp/3bpn2/3pN3/3P4/2P2N2/PP2QPPP/R1B1R1K1 b - - 4 12' #carlsbad caro
query_fen = 'r1b1r1k1/pp1nqppp/2p5/3p4/3Pn3/2NBPN2/PPQ2PPP/R4RK1 w - - 2 12' #carlsbad
query_array = board_to_array(chess.Board(fen=query_fen))
query_array = orient_board(query_array, query_fen.split()[1]=='w')

keys = (8, 8, 0, 1, 1, 1) #knightrookend
#keys = get_keys_func(query_array) #(28, 28, 0, 0, 0, 0) #carlsbad

sm, om, dm, sc, oc, pe = keys

query = f'''SELECT position_id FROM positions
WHERE self_material_count < {sm+5.5} AND self_material_count > {sm-5.5} 
AND opp_material_count < {om+5.5} AND opp_material_count > {om-5.5} 
AND diff_material_count < {dm+1.5} AND diff_material_count > {dm-1.5} 
AND (self_castle_available = {sc} OR opp_castle_available = {oc})
AND position_in_endgame = {pe}'''

cur.execute(query)
matches = cur.fetchall()
print()
print('Number of matches:')
print(len(matches))
# Out:
# All matches in the database:
# ('Nakamura, Hi', 4679)
# ('Sarana, A', 3526)
# ('Andreikin, D', 3277)
# ('Kamsky, G', 3188)
# ('Carlsen, M', 3151)
# ('Jobava, Ba', 3063)
# ('Fedoseev, Vl3', 3007)
# ('Vachier Lagrave, M', 2968)
# ('Mamedyarov, S', 2933)
# ('Kosteniuk, A', 2928)
# ('Grischuk, A', 2891)
# ('Dubov, Daniil', 2810)
# ('Xiong, Jeffery', 2806)
# ('Zhigalko, S', 2800)
# ('So, W', 2757)
# ('Sjugirov, S', 2746)
# ('Chigaev, M', 2731)
# ('Bortnyk, Olexandr', 2691)
# ('Paravyan, D', 2662)
# ('Caruana, F', 2661)
#
# Number of matches:
# 4927

# %%
cur.close()
conn.close()
