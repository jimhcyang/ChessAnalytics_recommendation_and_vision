# %%
pip install chess
# Out:
# Collecting chess
#   Downloading chess-1.10.0-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: chess
# Successfully installed chess-1.10.0

# %%
import os
import datetime
import chess
import chess.engine
import random
import numpy as np
import math
from tqdm import tqdm
import io
import json
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import display, SVG
from sklearn.preprocessing import MinMaxScaler

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !apt-get install -y stockfish
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   polyglot xboard | scid
# The following NEW packages will be installed:
#   stockfish
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 24.8 MB of archives.
# After this operation, 47.4 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 stockfish amd64 14.1-1 [24.8 MB]
# Fetched 24.8 MB in 2s (10.2 MB/s)
# Selecting previously unselected package stockfish.
# (Reading database ... 121753 files and directories currently installed.)
# Preparing to unpack .../stockfish_14.1-1_amd64.deb ...
# Unpacking stockfish (14.1-1) ...
# Setting up stockfish (14.1-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# help functions

def stockfish(board, depth):
  with chess.engine.SimpleEngine.popen_uci("/usr/games/stockfish") as sf:
    result = sf.analyse(board, chess.engine.Limit(depth=depth))
    score = result['score'].white().score()
  return score

def board_encoder(board):
  encoded_board = np.zeros([8,8,13]).astype(np.int8)
  fen = board.fen()
  fen_field = fen.split(' ')
  PiecePlacement = fen_field[0].split('/')
  piece_dict = {"R":0, "N":1, "B":2, "Q":3, "K":4, "P":5,
                "r":6, "n":7, "b":8, "q":9, "k":10, "p":11
                }
  for rank in range(8):
    pieces = ''
    for c in PiecePlacement[rank]:
      if c.isnumeric():
        pieces += '-'*int(c)
      else:
        pieces += c
    for file in range(8):
      if pieces[file] != '-':
        encoded_board[rank, file, piece_dict[pieces[file]]] = 1
  # # plane 12 encodes all the legal moves of white
  # aux = board.turn
  # board.turn = chess.WHITE
  # for move in board.legal_moves:
  #   encoded_board[7-np.unravel_index(move.to_square, (8,8))[0], np.unravel_index(move.to_square, (8,8))[1], 12] = 1
  # # plane 13 encodes all the legal moves of black
  # board.turn = chess.BLACK
  # for move in board.legal_moves:
  #   encoded_board[7-np.unravel_index(move.to_square, (8,8))[0], np.unravel_index(move.to_square, (8,8))[1], 13] = 1
  # board.turn = aux
  # plane 14 encodes the current player to move: white is 1, black is 0
  if fen_field[1] == 'w':
    encoded_board[:,:,12] = 1
  else:
    encoded_board[:,:,12] = 0
  return encoded_board

# %%
# Set the random seed
np.random.seed(42)

# %%
# load training data
for i in range(1,10):
  data = np.load("/content/drive/MyDrive/dataset_lichess{}.Mar18.npz".format(i))
  if i == 1:
    X = data['X']
    y = data['y']
  else:
    X = np.concatenate((X, data['X']))
    y = np.concatenate((y, data['y']))

idx_to_pick = np.concatenate((np.arange(0, 12), [14]))
# inputdata = {'X': X[:,:,:,idx_to_pick], 'y': y}

# outlier removal on the training data

mean = np.mean(y)
std_dev = np.std(y)
thres_high = mean + 2 * std_dev
thres_low = mean - 2 * std_dev

print(thres_high)
print(thres_low)

# Find the indices of samples that satisfy the filtering condition
filtered_indices = np.where((y <= thres_high) & (y >= thres_low))[0]

X_filtered = X[filtered_indices]
X_filtered = X_filtered[:,:,:,idx_to_pick]
y_filtered = y[filtered_indices]
inputdata = {'X': X_filtered, 'y': y_filtered}
# Out:
# 507.62531026745927
# -399.41332253696027

# %%
# load validation data and outlier removal

valdata = np.load("/content/drive/MyDrive/dataset_lichess10.Mar18.npz")

mean = np.mean(valdata['y'])
std_dev = np.std(valdata['y'])
thres_high = mean + 2 * std_dev
thres_low = mean - 2 * std_dev

print(thres_high)
print(thres_low)

# Find the indices of samples that satisfy the filtering condition
filtered_indices = np.where((valdata['y'] <= thres_high) & (valdata['y'] >= thres_low))[0]

# Get the filtered data based on the filtered indices
filtered_data = inputdata['y'][filtered_indices]

X_filtered = valdata['X'][filtered_indices]
X_filtered = X_filtered[:,:,:,idx_to_pick]
y_filtered = valdata['y'][filtered_indices]
validation_set = {'X': X_filtered, 'y': y_filtered}
# Out:
# 396.3441964522211
# -269.15814295056794

# %%
# model components

class InBlock(nn.Module):
    def __init__(self, channel_in=13, channel_out=256, kernel_size=3, stride=1):
        super(InBlock, self).__init__()
        self.channel_in = channel_in
        self.conv1 = nn.Conv2d(channel_in, channel_out, kernel_size=kernel_size,
                               stride=stride, padding=1)
        self.bn1 = nn.BatchNorm2d(channel_out)

    def forward(self, s):
        if s.dtype != torch.float32:
            s = s.float()
        s = s.view(-1, self.channel_in, 8, 8)  # batch_size x channels x board_x x board_y
        s = self.conv1(s)
        s = self.bn1(s)
        s = F.relu(s)
        return s

class ConvBlock(nn.Module):
    def __init__(self, channel_in=256, channel_out=256, kernel_size=3, stride=1):
        super(ConvBlock, self).__init__()
        padding = (kernel_size - 1) // 2
        self.conv1 = nn.Conv2d(channel_in, channel_out, kernel_size=kernel_size,
                               stride=stride,
                     padding=padding, bias=False)
        self.bn1 = nn.BatchNorm2d(channel_out)
        self.conv2 = nn.Conv2d(channel_out, channel_out, kernel_size=kernel_size,
                               stride=stride,
                     padding=padding, bias=False)
        self.bn2 = nn.BatchNorm2d(channel_out)

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = F.relu(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out = F.relu(out)
        return out

class OutBlock(nn.Module):
    def __init__(self):
        super(OutBlock, self).__init__()
        self.conv = nn.Conv2d(256, 1, kernel_size=1, stride=1)
        self.bn = nn.BatchNorm2d(1)
        self.fc1 = nn.Linear(8*8, 256)
        self.fc2 = nn.Linear(256, 1)

    def forward(self,s):
        v = self.conv(s)
        v = self.bn(v)
        v = F.relu(v)
        v = v.view(-1, 8*8)  # batch_size x channels x board_x x board_y
        v = self.fc1(v)
        v = F.relu(v)
        v = self.fc2(v)
        v = torch.tanh(v)

        return v

# %%
# 3 layers of convolutional blocks

class PlainNet3(nn.Module):
    def __init__(self):
        super(PlainNet3, self).__init__()
        self.conv = InBlock()
        self.convblocks = nn.ModuleList([ConvBlock() for _ in range(3)])
        self.outblock = OutBlock()

    def forward(self,s):
        s = self.conv(s)
        for convblock in self.convblocks:
            s = convblock(s)
        s = self.outblock(s)
        return s

# %%
# initialize a normalizer for the evaluation score

normalizer = MinMaxScaler(feature_range=(-1, 1)).fit(inputdata['y'].reshape(-1,1))

# %%
class data_prep():
    def __init__(self, dataset): # dataset = np.array of (s, v)
        # self.X = dataset[:,0]
        # self.y = dataset[:,1]
        self.X = dataset['X']
        self.y = normalizer.transform(dataset['y'].reshape(-1,1))
        self.y = self.y.reshape(-1,)

    def __len__(self):
        return len(self.X)

    def __getitem__(self,idx):
        return self.X[idx].transpose(2,0,1), self.y[idx]

# %%
# validation function

def validate(net, val_loader, criterion):
    net.eval()  # Switch model to evaluation mode
    total_loss = 0.0
    num_batches = 0
    for i, data in enumerate(val_loader):
        state, value = data
        if cuda:
            state, value = state.cuda().float(), value.cuda().float()
        value = value.float()  # Convert to torch.float32
        with torch.no_grad():  # Disable gradient calculation
            value_pred = net(state)  # value_pred = torch.Size([batch, 1])
            loss = criterion(value_pred[:, 0], value)
        total_loss += loss.item()
        num_batches += 1
    average_loss = total_loss / num_batches
    return average_loss

# %%
def train(net, train_data, val_data, batch_size=100, epoch_start=0, epoch_stop=20, checkpoint_interval=10, early_stop_patience=5):
    cuda = torch.cuda.is_available()
    net.train()
    criterion = nn.MSELoss()
    optimizer = optim.Adam(net.parameters(), lr=0.01)
    # scheduler = optim.lr_scheduler.MultiStepLR(optimizer,
                                              #  milestones=[100,200,300,400],
                                              #  gamma=0.2)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=5, factor=0.2)
    train_set = data_prep(train_data)
    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True,
                              num_workers=2, pin_memory=False)
    val_set = data_prep(val_data)
    val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False,
                            num_workers=2, pin_memory=False)
    losses_per_epoch = []
    val_losses_per_epoch = []
    lr = []
    patience_count = 0
    for epoch in range(epoch_start, epoch_stop):
        total_loss = 0.0
        losses_per_batch = []
        for i,data in enumerate(train_loader):
            state, value = data
            if cuda:
                state, value = state.cuda().float(), value.cuda().float()
            value = value.float()  # Convert to torch.float32
            optimizer.zero_grad()
            value_pred = net(state) # value_pred = torch.Size([batch, 1])
            loss = criterion(value_pred[:,0], value)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            if i % 10 == 9:    # print every 10 mini-batches of size = batch_size
                print('Process ID: %d [Epoch: %d, %5d/ %d points] total loss per batch: %.5f' %
                      (os.getpid(), epoch + 1, (i + 1)*batch_size, len(train_set), total_loss/10))
                print("Value:",value[0].item(),value_pred[0,0].item())
                losses_per_batch.append(total_loss/10)
                total_loss = 0.0
        losses_per_epoch.append(sum(losses_per_batch)/len(losses_per_batch))
        # Validation
        val_loss = validate(net, val_loader, criterion)
        print(f'Validation MSE Loss: {val_loss:.5f}')
        val_losses_per_epoch.append(val_loss)
        scheduler.step(val_loss)
        # Print learning rate
        current_lr = optimizer.param_groups[0]['lr']
        print(f"Current learning rate: {current_lr}")
        lr.append(current_lr)
        # Early stopping: validation loss has to reduce at least 5% per epoch
        if len(val_losses_per_epoch) >= 6:
          loss_avg = np.average(val_losses_per_epoch[-6:-1])
          if val_loss <= 0.95 * loss_avg:
            patience_count = 0  # Reset patience count
          else:
            patience_count += 1
        if patience_count >= early_stop_patience:
          np.savez("/content/drive/MyDrive/PlainNet3_Apr1/PlainNet3_Apr1_losses_per_epoch_epoch{}.npz".format(epoch+1),
                train_loss=losses_per_epoch,
                val_loss=val_losses_per_epoch,
                lr=lr
                )
          torch.save({'state_dict': net.state_dict()},
                  "/content/drive/MyDrive/PlainNet3_Apr1/PlainNet3_Apr1_training_earlystopped_epoch{}.pth".format(epoch+1))
          print(f'Early stopping! No improvement in validation loss for {early_stop_patience} epochs.')
          break
        # Save checkpoints
        if (epoch+1) % checkpoint_interval == 5:
          np.savez("/content/drive/MyDrive/PlainNet3_Apr1/PlainNet3_Apr1_losses_per_epoch_epoch{}.npz".format(epoch+1),
                   train_loss=losses_per_epoch,
                   val_loss=val_losses_per_epoch,
                   lr=lr
                   )
          # losses_per_epoch = []
          # val_losses_per_epoch = []
          # lr = []
          torch.save({'state_dict': net.state_dict()},
                     "/content/drive/MyDrive/PlainNet3_Apr1/PlainNet3_Apr1_training_checkpoint_epoch{}.ckpt".format(epoch+1))

# %%
# train net
net = PlainNet3()
cuda = torch.cuda.is_available()
if cuda:
  net.cuda()
train(net,inputdata, validation_set, epoch_stop=50)
# save results
torch.save({'state_dict': net.state_dict()}, "/content/drive/MyDrive/PlainNet3_Apr1/PlainNet3_Apr1_trained.pth")
from google.colab import runtime
runtime.unassign()
# Out:
# Streaming output truncated to the last 5000 lines.
# Value: -0.06181015446782112 -0.019569911062717438
# Process ID: 542 [Epoch: 8, 49000/ 848835 points] total loss per batch: 0.10477
# Value: -0.17660044133663177 -0.023448076099157333
# Process ID: 542 [Epoch: 8, 50000/ 848835 points] total loss per batch: 0.11336
# Value: -0.09050772339105606 -0.021831655874848366
# Process ID: 542 [Epoch: 8, 51000/ 848835 points] total loss per batch: 0.09756
# Value: -0.19205297529697418 -0.015634743496775627
# Process ID: 542 [Epoch: 8, 52000/ 848835 points] total loss per batch: 0.08701
# Value: 0.37748345732688904 -0.012269726023077965
# Process ID: 542 [Epoch: 8, 53000/ 848835 points] total loss per batch: 0.09874
# Value: 0.17660044133663177 -0.008787715807557106
# Process ID: 542 [Epoch: 8, 54000/ 848835 points] total loss per batch: 0.09200
# Value: -0.08388520777225494 -0.0076352073810994625
# Process ID: 542 [Epoch: 8, 55000/ 848835 points] total loss per batch: 0.09345
# Value: -0.11699779331684113 -0.008162579499185085
# Process ID: 542 [Epoch: 8, 56000/ 848835 points] total loss per batch: 0.09299
# Value: -0.044150110334157944 -0.010108131915330887
# Process ID: 542 [Epoch: 8, 57000/ 848835 points] total loss per batch: 0.09413
# Value: -0.5938189625740051 -0.011747844517230988
# Process ID: 542 [Epoch: 8, 58000/ 848835 points] total loss per batch: 0.10450
# Value: 0.6688741445541382 -0.011579414829611778
# Process ID: 542 [Epoch: 8, 59000/ 848835 points] total loss per batch: 0.09882
# Value: -0.14569535851478577 -0.011356603354215622
# Process ID: 542 [Epoch: 8, 60000/ 848835 points] total loss per batch: 0.09234
# Value: -0.017660044133663177 -0.011251638643443584
# Process ID: 542 [Epoch: 8, 61000/ 848835 points] total loss per batch: 0.08057
# Value: -0.05960264801979065 -0.013373974710702896
# Process ID: 542 [Epoch: 8, 62000/ 848835 points] total loss per batch: 0.10807
# Value: -0.09271523356437683 -0.012173979543149471
# Process ID: 542 [Epoch: 8, 63000/ 848835 points] total loss per batch: 0.09577
# Value: -0.2626931667327881 -0.010424178093671799
# Process ID: 542 [Epoch: 8, 64000/ 848835 points] total loss per batch: 0.08883
# Value: 0.08830022066831589 -0.01838763803243637
# Process ID: 542 [Epoch: 8, 65000/ 848835 points] total loss per batch: 0.09021
# Value: -0.05298013240098953 -0.022637099027633667
# Process ID: 542 [Epoch: 8, 66000/ 848835 points] total loss per batch: 0.10610
# Value: -0.09933774918317795 -0.020077450200915337
# Process ID: 542 [Epoch: 8, 67000/ 848835 points] total loss per batch: 0.10077
# Value: 0.3642384111881256 -0.01847805455327034
# Process ID: 542 [Epoch: 8, 68000/ 848835 points] total loss per batch: 0.09278
# Value: 0.04194260388612747 -0.014679168350994587
# Process ID: 542 [Epoch: 8, 69000/ 848835 points] total loss per batch: 0.09362
# Value: -0.15452538430690765 -0.009170494973659515
# Process ID: 542 [Epoch: 8, 70000/ 848835 points] total loss per batch: 0.09538
# Value: -0.21854305267333984 -0.0062276506796479225
# Process ID: 542 [Epoch: 8, 71000/ 848835 points] total loss per batch: 0.09597
# Value: -0.08388520777225494 -0.007055109366774559
# Process ID: 542 [Epoch: 8, 72000/ 848835 points] total loss per batch: 0.09876
# Value: 0.024282561615109444 -0.010641910135746002
# Process ID: 542 [Epoch: 8, 73000/ 848835 points] total loss per batch: 0.10080
# Value: -0.14569535851478577 -0.010378509759902954
# Process ID: 542 [Epoch: 8, 74000/ 848835 points] total loss per batch: 0.10716
# Value: 0.10154525190591812 -0.009399065747857094
# Process ID: 542 [Epoch: 8, 75000/ 848835 points] total loss per batch: 0.08790
# Value: -0.11037527769804001 -0.007226848974823952
# Process ID: 542 [Epoch: 8, 76000/ 848835 points] total loss per batch: 0.09687
# Value: 0.5496688485145569 -0.00800192542374134
# Process ID: 542 [Epoch: 8, 77000/ 848835 points] total loss per batch: 0.08258
# Value: -0.15452538430690765 -0.009533881209790707
# Process ID: 542 [Epoch: 8, 78000/ 848835 points] total loss per batch: 0.10075
# Value: -0.08830022066831589 -0.00582564203068614
# Process ID: 542 [Epoch: 8, 79000/ 848835 points] total loss per batch: 0.09738
# Value: -0.3002207577228546 -0.008727789856493473
# Process ID: 542 [Epoch: 8, 80000/ 848835 points] total loss per batch: 0.08101
# Value: -0.08388520777225494 -0.015215814113616943
# Process ID: 542 [Epoch: 8, 81000/ 848835 points] total loss per batch: 0.09328
# Value: -0.07284767925739288 -0.023172477260231972
# Process ID: 542 [Epoch: 8, 82000/ 848835 points] total loss per batch: 0.08846
# Value: 0.16114790737628937 -0.024294795468449593
# Process ID: 542 [Epoch: 8, 83000/ 848835 points] total loss per batch: 0.07943
# Value: -0.19646799564361572 -0.023884743452072144
# Process ID: 542 [Epoch: 8, 84000/ 848835 points] total loss per batch: 0.10054
# Value: -0.002207505516707897 -0.022388845682144165
# Process ID: 542 [Epoch: 8, 85000/ 848835 points] total loss per batch: 0.09324
# Value: -0.1501103788614273 -0.015742331743240356
# Process ID: 542 [Epoch: 8, 86000/ 848835 points] total loss per batch: 0.08818
# Value: -0.6158940196037292 -0.012970056384801865
# Process ID: 542 [Epoch: 8, 87000/ 848835 points] total loss per batch: 0.08355
# Value: 0.11258278042078018 -0.016075586900115013
# Process ID: 542 [Epoch: 8, 88000/ 848835 points] total loss per batch: 0.09662
# Value: -0.0066225165501236916 -0.01847766526043415
# Process ID: 542 [Epoch: 8, 89000/ 848835 points] total loss per batch: 0.10363
# Value: -0.1346578299999237 -0.019629303365945816
# Process ID: 542 [Epoch: 8, 90000/ 848835 points] total loss per batch: 0.09401
# Value: -0.1192052960395813 -0.015080111101269722
# Process ID: 542 [Epoch: 8, 91000/ 848835 points] total loss per batch: 0.09728
# Value: -0.2384105920791626 -0.012614737264811993
# Process ID: 542 [Epoch: 8, 92000/ 848835 points] total loss per batch: 0.09215
# Value: 0.6622516512870789 -0.012738813646137714
# Process ID: 542 [Epoch: 8, 93000/ 848835 points] total loss per batch: 0.09186
# Value: -0.026490066200494766 -0.016257256269454956
# Process ID: 542 [Epoch: 8, 94000/ 848835 points] total loss per batch: 0.09654
# Value: -0.251655638217926 -0.01579500548541546
# Process ID: 542 [Epoch: 8, 95000/ 848835 points] total loss per batch: 0.08923
# Value: -0.21854305267333984 -0.014566542580723763
# Process ID: 542 [Epoch: 8, 96000/ 848835 points] total loss per batch: 0.10396
# Value: -0.09933774918317795 -0.01556447148323059
# Process ID: 542 [Epoch: 8, 97000/ 848835 points] total loss per batch: 0.09710
# Value: -0.3554084002971649 -0.013356350362300873
# Process ID: 542 [Epoch: 8, 98000/ 848835 points] total loss per batch: 0.08479
# Value: -0.04194260388612747 -0.01120467483997345
# Process ID: 542 [Epoch: 8, 99000/ 848835 points] total loss per batch: 0.10041
# Value: 0.20088300108909607 -0.004718502052128315
# Process ID: 542 [Epoch: 8, 100000/ 848835 points] total loss per batch: 0.09215
# Value: -0.5187637805938721 -0.00021776666108053178
# Process ID: 542 [Epoch: 8, 101000/ 848835 points] total loss per batch: 0.09802
# Value: -0.028697572648525238 -0.003610330866649747
# Process ID: 542 [Epoch: 8, 102000/ 848835 points] total loss per batch: 0.10492
# Value: -0.06181015446782112 -0.009118003770709038
# Process ID: 542 [Epoch: 8, 103000/ 848835 points] total loss per batch: 0.09766
# Value: 0.6887417435646057 -0.012505603022873402
# Process ID: 542 [Epoch: 8, 104000/ 848835 points] total loss per batch: 0.09358
# Value: -0.14128035306930542 -0.011808481067419052
# Process ID: 542 [Epoch: 8, 105000/ 848835 points] total loss per batch: 0.09472
# Value: 0.49448123574256897 -0.015267020091414452
# Process ID: 542 [Epoch: 8, 106000/ 848835 points] total loss per batch: 0.10446
# Value: 0.18543046712875366 -0.01638941280543804
# Process ID: 542 [Epoch: 8, 107000/ 848835 points] total loss per batch: 0.10125
# Value: -0.17880794405937195 -0.014730784110724926
# Process ID: 542 [Epoch: 8, 108000/ 848835 points] total loss per batch: 0.09998
# Value: 0.004415011033415794 -0.014876891858875751
# Process ID: 542 [Epoch: 8, 109000/ 848835 points] total loss per batch: 0.09339
# Value: 0.09713024646043777 -0.01668207347393036
# Process ID: 542 [Epoch: 8, 110000/ 848835 points] total loss per batch: 0.08568
# Value: -0.13686534762382507 -0.015683261677622795
# Process ID: 542 [Epoch: 8, 111000/ 848835 points] total loss per batch: 0.09414
# Value: -0.12362030893564224 -0.014424704015254974
# Process ID: 542 [Epoch: 8, 112000/ 848835 points] total loss per batch: 0.08919
# Value: 0.07064017653465271 -0.014965808019042015
# Process ID: 542 [Epoch: 8, 113000/ 848835 points] total loss per batch: 0.10150
# Value: -0.03311258181929588 -0.012657484970986843
# Process ID: 542 [Epoch: 8, 114000/ 848835 points] total loss per batch: 0.08649
# Value: -0.14128035306930542 -0.010092031210660934
# Process ID: 542 [Epoch: 8, 115000/ 848835 points] total loss per batch: 0.09848
# Value: -0.06401766091585159 -0.012131590396165848
# Process ID: 542 [Epoch: 8, 116000/ 848835 points] total loss per batch: 0.10160
# Value: 0.2626931667327881 -0.008160850033164024
# Process ID: 542 [Epoch: 8, 117000/ 848835 points] total loss per batch: 0.08867
# Value: -0.024282561615109444 -0.011852151714265347
# Process ID: 542 [Epoch: 8, 118000/ 848835 points] total loss per batch: 0.10444
# Value: -5.551115123125783e-17 -0.01485460065305233
# Process ID: 542 [Epoch: 8, 119000/ 848835 points] total loss per batch: 0.09315
# Value: 0.26710817217826843 -0.016689451411366463
# Process ID: 542 [Epoch: 8, 120000/ 848835 points] total loss per batch: 0.09463
# Value: -0.9911699891090393 -0.01846393384039402
# Process ID: 542 [Epoch: 8, 121000/ 848835 points] total loss per batch: 0.09531
# Value: -0.057395145297050476 -0.01603005640208721
# Process ID: 542 [Epoch: 8, 122000/ 848835 points] total loss per batch: 0.09359
# Value: -0.07726269215345383 -0.012009693309664726
# Process ID: 542 [Epoch: 8, 123000/ 848835 points] total loss per batch: 0.09289
# Value: -0.057395145297050476 -0.01194772683084011
# Process ID: 542 [Epoch: 8, 124000/ 848835 points] total loss per batch: 0.08585
# Value: 0.12141280621290207 -0.016816895455121994
# Process ID: 542 [Epoch: 8, 125000/ 848835 points] total loss per batch: 0.09727
# Value: 0.07726269215345383 -0.0178773682564497
# Process ID: 542 [Epoch: 8, 126000/ 848835 points] total loss per batch: 0.09614
# Value: -0.06843267381191254 -0.014252622611820698
# Process ID: 542 [Epoch: 8, 127000/ 848835 points] total loss per batch: 0.08939
# Value: -0.14790287613868713 -0.015915827825665474
# Process ID: 542 [Epoch: 8, 128000/ 848835 points] total loss per batch: 0.09078
# Value: -0.2626931667327881 -0.02364921197295189
# Process ID: 542 [Epoch: 8, 129000/ 848835 points] total loss per batch: 0.09828
# Value: -0.3487858772277832 -0.02170557714998722
# Process ID: 542 [Epoch: 8, 130000/ 848835 points] total loss per batch: 0.09748
# Value: -0.1986754983663559 -0.016182785853743553
# Process ID: 542 [Epoch: 8, 131000/ 848835 points] total loss per batch: 0.10034
# Value: 0.2935982346534729 -0.010560892522335052
# Process ID: 542 [Epoch: 8, 132000/ 848835 points] total loss per batch: 0.09822
# Value: -0.1192052960395813 -0.0018090188968926668
# Process ID: 542 [Epoch: 8, 133000/ 848835 points] total loss per batch: 0.09058
# Value: -0.16114790737628937 -0.0017684788908809423
# Process ID: 542 [Epoch: 8, 134000/ 848835 points] total loss per batch: 0.09669
# Value: -0.01986755058169365 -0.008284534327685833
# Process ID: 542 [Epoch: 8, 135000/ 848835 points] total loss per batch: 0.10578
# Value: 0.03311258181929588 -0.012668811716139317
# Process ID: 542 [Epoch: 8, 136000/ 848835 points] total loss per batch: 0.10053
# Value: -0.9205297827720642 -0.016451144590973854
# Process ID: 542 [Epoch: 8, 137000/ 848835 points] total loss per batch: 0.10345
# Value: -0.20971302688121796 -0.01321376208215952
# Process ID: 542 [Epoch: 8, 138000/ 848835 points] total loss per batch: 0.09037
# Value: -0.1434878557920456 -0.00854564644396305
# Process ID: 542 [Epoch: 8, 139000/ 848835 points] total loss per batch: 0.09295
# Value: -0.1192052960395813 -0.00962804164737463
# Process ID: 542 [Epoch: 8, 140000/ 848835 points] total loss per batch: 0.09171
# Value: -0.13024282455444336 -0.01170737948268652
# Process ID: 542 [Epoch: 8, 141000/ 848835 points] total loss per batch: 0.09506
# Value: -0.07505518943071365 -0.00942743569612503
# Process ID: 542 [Epoch: 8, 142000/ 848835 points] total loss per batch: 0.09601
# Value: 0.251655638217926 -0.008662005886435509
# Process ID: 542 [Epoch: 8, 143000/ 848835 points] total loss per batch: 0.08973
# Value: 0.43929359316825867 -0.005288423504680395
# Process ID: 542 [Epoch: 8, 144000/ 848835 points] total loss per batch: 0.09422
# Value: 0.013245033100247383 -0.006493426393717527
# Process ID: 542 [Epoch: 8, 145000/ 848835 points] total loss per batch: 0.09646
# Value: -0.32229581475257874 -0.009583542123436928
# Process ID: 542 [Epoch: 8, 146000/ 848835 points] total loss per batch: 0.10239
# Value: -0.1192052960395813 -0.018761085346341133
# Process ID: 542 [Epoch: 8, 147000/ 848835 points] total loss per batch: 0.09297
# Value: -0.2869757115840912 -0.022325534373521805
# Process ID: 542 [Epoch: 8, 148000/ 848835 points] total loss per batch: 0.09480
# Value: -0.057395145297050476 -0.017695194110274315
# Process ID: 542 [Epoch: 8, 149000/ 848835 points] total loss per batch: 0.08778
# Value: 0.3245033025741577 -0.01691511459648609
# Process ID: 542 [Epoch: 8, 150000/ 848835 points] total loss per batch: 0.08903
# Value: 0.6556291580200195 -0.016813144087791443
# Process ID: 542 [Epoch: 8, 151000/ 848835 points] total loss per batch: 0.09169
# Value: -0.24282561242580414 -0.020344236865639687
# Process ID: 542 [Epoch: 8, 152000/ 848835 points] total loss per batch: 0.09842
# Value: 0.32891830801963806 -0.015929128974676132
# Process ID: 542 [Epoch: 8, 153000/ 848835 points] total loss per batch: 0.10054
# Value: -0.1192052960395813 -0.014569909311830997
# Process ID: 542 [Epoch: 8, 154000/ 848835 points] total loss per batch: 0.08946
# Value: -0.125827819108963 -0.014792006462812424
# Process ID: 542 [Epoch: 8, 155000/ 848835 points] total loss per batch: 0.09844
# Value: 0.028697572648525238 -0.01614491455256939
# Process ID: 542 [Epoch: 8, 156000/ 848835 points] total loss per batch: 0.09019
# Value: 0.5584989190101624 -0.015860455110669136
# Process ID: 542 [Epoch: 8, 157000/ 848835 points] total loss per batch: 0.09530
# Value: -0.06843267381191254 -0.01650156080722809
# Process ID: 542 [Epoch: 8, 158000/ 848835 points] total loss per batch: 0.09203
# Value: 0.05298013240098953 -0.016649404540657997
# Process ID: 542 [Epoch: 8, 159000/ 848835 points] total loss per batch: 0.09502
# Value: -0.1192052960395813 -0.012776114977896214
# Process ID: 542 [Epoch: 8, 160000/ 848835 points] total loss per batch: 0.09766
# Value: -0.10375276207923889 -0.010496927425265312
# Process ID: 542 [Epoch: 8, 161000/ 848835 points] total loss per batch: 0.09766
# Value: -0.10154525190591812 -0.007893886417150497
# Process ID: 542 [Epoch: 8, 162000/ 848835 points] total loss per batch: 0.09218
# Value: 0.04856512323021889 -0.010458591394126415
# Process ID: 542 [Epoch: 8, 163000/ 848835 points] total loss per batch: 0.09890
# Value: 0.013245033100247383 -0.014337214641273022
# Process ID: 542 [Epoch: 8, 164000/ 848835 points] total loss per batch: 0.09035
# Value: 0.09713024646043777 -0.015186450444161892
# Process ID: 542 [Epoch: 8, 165000/ 848835 points] total loss per batch: 0.09237
# Value: -0.7064017653465271 -0.01416503544896841
# Process ID: 542 [Epoch: 8, 166000/ 848835 points] total loss per batch: 0.09751
# Value: 0.4348785877227783 -0.014661121182143688
# Process ID: 542 [Epoch: 8, 167000/ 848835 points] total loss per batch: 0.08404
# Value: -0.06622516363859177 -0.013071822002530098
# Process ID: 542 [Epoch: 8, 168000/ 848835 points] total loss per batch: 0.10662
# Value: -0.09050772339105606 -0.0072660972364246845
# Process ID: 542 [Epoch: 8, 169000/ 848835 points] total loss per batch: 0.09741
# Value: -0.11699779331684113 -0.0071232859045267105
# Process ID: 542 [Epoch: 8, 170000/ 848835 points] total loss per batch: 0.09559
# Value: -0.07284767925739288 -0.00728105753660202
# Process ID: 542 [Epoch: 8, 171000/ 848835 points] total loss per batch: 0.08246
# Value: -0.18101544678211212 -0.008341335691511631
# Process ID: 542 [Epoch: 8, 172000/ 848835 points] total loss per batch: 0.10517
# Value: -0.01545253861695528 -0.007306359242647886
# Process ID: 542 [Epoch: 8, 173000/ 848835 points] total loss per batch: 0.09574
# Value: 0.09050772339105606 -0.007117067463696003
# Process ID: 542 [Epoch: 8, 174000/ 848835 points] total loss per batch: 0.09110
# Value: -0.46357616782188416 -0.010385187342762947
# Process ID: 542 [Epoch: 8, 175000/ 848835 points] total loss per batch: 0.10576
# Value: -0.008830022066831589 -0.01207613106817007
# Process ID: 542 [Epoch: 8, 176000/ 848835 points] total loss per batch: 0.09125
# Value: -0.01986755058169365 -0.011590621434152126
# Process ID: 542 [Epoch: 8, 177000/ 848835 points] total loss per batch: 0.08652
# Value: -0.6534216403961182 -0.01081162504851818
# Process ID: 542 [Epoch: 8, 178000/ 848835 points] total loss per batch: 0.09301
# Value: -0.013245033100247383 -0.012976971454918385
# Process ID: 542 [Epoch: 8, 179000/ 848835 points] total loss per batch: 0.09377
# Value: -0.04856512323021889 -0.012010832317173481
# Process ID: 542 [Epoch: 8, 180000/ 848835 points] total loss per batch: 0.09883
# Value: -0.3421633541584015 -0.008588255383074284
# Process ID: 542 [Epoch: 8, 181000/ 848835 points] total loss per batch: 0.09369
# Value: -0.04856512323021889 -0.013278020545840263
# Process ID: 542 [Epoch: 8, 182000/ 848835 points] total loss per batch: 0.09381
# Value: -0.008830022066831589 -0.01663467101752758
# Process ID: 542 [Epoch: 8, 183000/ 848835 points] total loss per batch: 0.09406
# Value: -0.3024282455444336 -0.01514524221420288
# Process ID: 542 [Epoch: 8, 184000/ 848835 points] total loss per batch: 0.07876
# Value: 0.0066225165501236916 -0.015526429750025272
# Process ID: 542 [Epoch: 8, 185000/ 848835 points] total loss per batch: 0.08762
# Value: -0.17660044133663177 -0.015669068321585655
# Process ID: 542 [Epoch: 8, 186000/ 848835 points] total loss per batch: 0.09860
# Value: -0.12803532183170319 -0.014779975637793541
# Process ID: 542 [Epoch: 8, 187000/ 848835 points] total loss per batch: 0.09740
# Value: 0.3576158881187439 -0.009815160185098648
# Process ID: 542 [Epoch: 8, 188000/ 848835 points] total loss per batch: 0.09092
# Value: 0.7417218685150146 -0.012190865352749825
# Process ID: 542 [Epoch: 8, 189000/ 848835 points] total loss per batch: 0.09673
# Value: -0.1192052960395813 -0.019075429067015648
# Process ID: 542 [Epoch: 8, 190000/ 848835 points] total loss per batch: 0.09951
# Value: 0.4282560646533966 -0.020936915650963783
# Process ID: 542 [Epoch: 8, 191000/ 848835 points] total loss per batch: 0.09508
# Value: -0.08167770504951477 -0.020212946459650993
# Process ID: 542 [Epoch: 8, 192000/ 848835 points] total loss per batch: 0.09143
# Value: 0.13686534762382507 -0.020507166162133217
# Process ID: 542 [Epoch: 8, 193000/ 848835 points] total loss per batch: 0.09625
# Value: -0.2781457006931305 -0.020977254956960678
# Process ID: 542 [Epoch: 8, 194000/ 848835 points] total loss per batch: 0.08985
# Value: -0.42384105920791626 -0.018310027197003365
# Process ID: 542 [Epoch: 8, 195000/ 848835 points] total loss per batch: 0.09795
# Value: -0.20750552415847778 -0.013408713042736053
# Process ID: 542 [Epoch: 8, 196000/ 848835 points] total loss per batch: 0.09888
# Value: -0.057395145297050476 -0.00949008297175169
# Process ID: 542 [Epoch: 8, 197000/ 848835 points] total loss per batch: 0.09198
# Value: 0.9602649211883545 -0.0058335354551672935
# Process ID: 542 [Epoch: 8, 198000/ 848835 points] total loss per batch: 0.09685
# Value: -0.29580575227737427 -0.0028533528093248606
# Process ID: 542 [Epoch: 8, 199000/ 848835 points] total loss per batch: 0.08988
# Value: -0.13024282455444336 -0.009828345850110054
# Process ID: 542 [Epoch: 8, 200000/ 848835 points] total loss per batch: 0.09260
# Value: -0.4768211841583252 -0.016323905438184738
# Process ID: 542 [Epoch: 8, 201000/ 848835 points] total loss per batch: 0.08873
# Value: -0.044150110334157944 -0.018468091264367104
# Process ID: 542 [Epoch: 8, 202000/ 848835 points] total loss per batch: 0.08817
# Value: 0.20971302688121796 -0.019787229597568512
# Process ID: 542 [Epoch: 8, 203000/ 848835 points] total loss per batch: 0.10332
# Value: 0.4503311216831207 -0.01676216349005699
# Process ID: 542 [Epoch: 8, 204000/ 848835 points] total loss per batch: 0.08747
# Value: -0.09713024646043777 -0.017082691192626953
# Process ID: 542 [Epoch: 8, 205000/ 848835 points] total loss per batch: 0.09281
# Value: -0.1346578299999237 -0.019507523626089096
# Process ID: 542 [Epoch: 8, 206000/ 848835 points] total loss per batch: 0.09419
# Value: 0.6799116730690002 -0.017457371577620506
# Process ID: 542 [Epoch: 8, 207000/ 848835 points] total loss per batch: 0.09503
# Value: -0.1192052960395813 -0.012598845176398754
# Process ID: 542 [Epoch: 8, 208000/ 848835 points] total loss per batch: 0.09337
# Value: -0.17660044133663177 -0.012527820654213428
# Process ID: 542 [Epoch: 8, 209000/ 848835 points] total loss per batch: 0.10512
# Value: -0.13024282455444336 -0.014542171731591225
# Process ID: 542 [Epoch: 8, 210000/ 848835 points] total loss per batch: 0.10407
# Value: -0.2803531885147095 -0.00552789494395256
# Process ID: 542 [Epoch: 8, 211000/ 848835 points] total loss per batch: 0.09702
# Value: 0.3090507686138153 0.0022542576771229506
# Process ID: 542 [Epoch: 8, 212000/ 848835 points] total loss per batch: 0.09488
# Value: -0.20750552415847778 -0.007080746348947287
# Process ID: 542 [Epoch: 8, 213000/ 848835 points] total loss per batch: 0.09371
# Value: -0.1192052960395813 -0.019091645255684853
# Process ID: 542 [Epoch: 8, 214000/ 848835 points] total loss per batch: 0.09355
# Value: -0.22737306356430054 -0.02452879585325718
# Process ID: 542 [Epoch: 8, 215000/ 848835 points] total loss per batch: 0.08602
# Value: -0.1192052960395813 -0.028280172497034073
# Process ID: 542 [Epoch: 8, 216000/ 848835 points] total loss per batch: 0.09746
# Value: 0.1986754983663559 -0.0235795509070158
# Process ID: 542 [Epoch: 8, 217000/ 848835 points] total loss per batch: 0.09009
# Value: 0.094922736287117 -0.014860627241432667
# Process ID: 542 [Epoch: 8, 218000/ 848835 points] total loss per batch: 0.10633
# Value: -0.44150111079216003 -0.010353552177548409
# Process ID: 542 [Epoch: 8, 219000/ 848835 points] total loss per batch: 0.09204
# Value: -0.10375276207923889 -0.011755421757698059
# Process ID: 542 [Epoch: 8, 220000/ 848835 points] total loss per batch: 0.09278
# Value: -0.06843267381191254 -0.016560891643166542
# Process ID: 542 [Epoch: 8, 221000/ 848835 points] total loss per batch: 0.10720
# Value: -0.22516556084156036 -0.01532235648483038
# Process ID: 542 [Epoch: 8, 222000/ 848835 points] total loss per batch: 0.09678
# Value: 0.7152317762374878 -0.008484095335006714
# Process ID: 542 [Epoch: 8, 223000/ 848835 points] total loss per batch: 0.09632
# Value: 0.5452538728713989 -0.0069570415653288364
# Process ID: 542 [Epoch: 8, 224000/ 848835 points] total loss per batch: 0.08899
# Value: 0.022075055167078972 -0.006834035273641348
# Process ID: 542 [Epoch: 8, 225000/ 848835 points] total loss per batch: 0.10558
# Value: -0.15673288702964783 -0.008860129863023758
# Process ID: 542 [Epoch: 8, 226000/ 848835 points] total loss per batch: 0.08974
# Value: -0.09271523356437683 -0.013532859273254871
# Process ID: 542 [Epoch: 8, 227000/ 848835 points] total loss per batch: 0.10105
# Value: -0.03752759471535683 -0.011125843040645123
# Process ID: 542 [Epoch: 8, 228000/ 848835 points] total loss per batch: 0.09579
# Value: 0.7682119011878967 -0.010450730100274086
# Process ID: 542 [Epoch: 8, 229000/ 848835 points] total loss per batch: 0.09319
# Value: -0.1346578299999237 -0.01045590452849865
# Process ID: 542 [Epoch: 8, 230000/ 848835 points] total loss per batch: 0.10208
# Value: -0.057395145297050476 -0.013387676328420639
# Process ID: 542 [Epoch: 8, 231000/ 848835 points] total loss per batch: 0.09704
# Value: -0.094922736287117 -0.015944933518767357
# Process ID: 542 [Epoch: 8, 232000/ 848835 points] total loss per batch: 0.10250
# Value: 0.2141280323266983 -0.014181610196828842
# Process ID: 542 [Epoch: 8, 233000/ 848835 points] total loss per batch: 0.09662
# Value: -0.028697572648525238 -0.013338897377252579
# Process ID: 542 [Epoch: 8, 234000/ 848835 points] total loss per batch: 0.10727
# Value: -0.07064017653465271 -0.01438854169100523
# Process ID: 542 [Epoch: 8, 235000/ 848835 points] total loss per batch: 0.09573
# Value: -0.08830022066831589 -0.012700562365353107
# Process ID: 542 [Epoch: 8, 236000/ 848835 points] total loss per batch: 0.08968
# Value: 0.046357616782188416 -0.01724989339709282
# Process ID: 542 [Epoch: 8, 237000/ 848835 points] total loss per batch: 0.10286
# Value: -0.10154525190591812 -0.017584344372153282
# Process ID: 542 [Epoch: 8, 238000/ 848835 points] total loss per batch: 0.09150
# Value: 0.7395143508911133 -0.01430383138358593
# Process ID: 542 [Epoch: 8, 239000/ 848835 points] total loss per batch: 0.08822
# Value: 0.32008829712867737 -0.012525557540357113
# Process ID: 542 [Epoch: 8, 240000/ 848835 points] total loss per batch: 0.08592
# Value: -0.7615894079208374 -0.01316097192466259
# Process ID: 542 [Epoch: 8, 241000/ 848835 points] total loss per batch: 0.09613
# Value: 0.6600441336631775 -0.016797427088022232
# Process ID: 542 [Epoch: 8, 242000/ 848835 points] total loss per batch: 0.10338
# Value: 0.017660044133663177 -0.013046576641499996
# Process ID: 542 [Epoch: 8, 243000/ 848835 points] total loss per batch: 0.09652
# Value: -0.04194260388612747 -0.014650187455117702
# Process ID: 542 [Epoch: 8, 244000/ 848835 points] total loss per batch: 0.09903
# Value: 0.20309050381183624 -0.010568743571639061
# Process ID: 542 [Epoch: 8, 245000/ 848835 points] total loss per batch: 0.09443
# Value: 0.812362015247345 -0.004655343014746904
# Process ID: 542 [Epoch: 8, 246000/ 848835 points] total loss per batch: 0.09302
# Value: 0.07064017653465271 -0.008580761030316353
# Process ID: 542 [Epoch: 8, 247000/ 848835 points] total loss per batch: 0.09205
# Value: -0.0397351011633873 -0.015537885017693043
# Process ID: 542 [Epoch: 8, 248000/ 848835 points] total loss per batch: 0.09266
# Value: 0.024282561615109444 -0.0184478797018528
# Process ID: 542 [Epoch: 8, 249000/ 848835 points] total loss per batch: 0.08820
# Value: 0.16114790737628937 -0.021628858521580696
# Process ID: 542 [Epoch: 8, 250000/ 848835 points] total loss per batch: 0.10160
# Value: 0.3951434791088104 -0.026012662798166275
# Process ID: 542 [Epoch: 8, 251000/ 848835 points] total loss per batch: 0.09206
# Value: 0.7549669146537781 -0.028110092505812645
# Process ID: 542 [Epoch: 8, 252000/ 848835 points] total loss per batch: 0.10245
# Value: 0.16114790737628937 -0.026034770533442497
# Process ID: 542 [Epoch: 8, 253000/ 848835 points] total loss per batch: 0.09790
# Value: -0.11258278042078018 -0.02581896260380745
# Process ID: 542 [Epoch: 8, 254000/ 848835 points] total loss per batch: 0.09857
# Value: -0.29580575227737427 -0.020011981949210167
# Process ID: 542 [Epoch: 8, 255000/ 848835 points] total loss per batch: 0.09829
# Value: -0.15452538430690765 -0.011736733838915825
# Process ID: 542 [Epoch: 8, 256000/ 848835 points] total loss per batch: 0.09850
# Value: -0.05298013240098953 -0.009795324876904488
# Process ID: 542 [Epoch: 8, 257000/ 848835 points] total loss per batch: 0.10991
# Value: -0.14790287613868713 -0.018143629655241966
# Process ID: 542 [Epoch: 8, 258000/ 848835 points] total loss per batch: 0.10082
# Value: 0.03090507723391056 -0.021263595670461655
# Process ID: 542 [Epoch: 8, 259000/ 848835 points] total loss per batch: 0.10027
# Value: -0.6026490330696106 -0.021712256595492363
# Process ID: 542 [Epoch: 8, 260000/ 848835 points] total loss per batch: 0.09943
# Value: -0.2604856491088867 -0.02324031852185726
# Process ID: 542 [Epoch: 8, 261000/ 848835 points] total loss per batch: 0.09383
# Value: -0.035320088267326355 -0.018267035484313965
# Process ID: 542 [Epoch: 8, 262000/ 848835 points] total loss per batch: 0.10255
# Value: -0.13024282455444336 -0.010610263794660568
# Process ID: 542 [Epoch: 8, 263000/ 848835 points] total loss per batch: 0.10480
# Value: 0.13245032727718353 -0.0074676391668617725
# Process ID: 542 [Epoch: 8, 264000/ 848835 points] total loss per batch: 0.09286
# Value: 0.6534216403961182 -0.009902602061629295
# Process ID: 542 [Epoch: 8, 265000/ 848835 points] total loss per batch: 0.09783
# Value: 0.31346577405929565 -0.013325837440788746
# Process ID: 542 [Epoch: 8, 266000/ 848835 points] total loss per batch: 0.10165
# Value: 0.11037527769804001 -0.014623339287936687
# Process ID: 542 [Epoch: 8, 267000/ 848835 points] total loss per batch: 0.09935
# Value: 0.05077262595295906 -0.011923376470804214
# Process ID: 542 [Epoch: 8, 268000/ 848835 points] total loss per batch: 0.09149
# Value: 0.09050772339105606 -0.017570100724697113
# Process ID: 542 [Epoch: 8, 269000/ 848835 points] total loss per batch: 0.09746
# Value: -0.017660044133663177 -0.01720390096306801
# Process ID: 542 [Epoch: 8, 270000/ 848835 points] total loss per batch: 0.09184
# Value: -0.8830022215843201 -0.015076490119099617
# Process ID: 542 [Epoch: 8, 271000/ 848835 points] total loss per batch: 0.10246
# Value: -0.10154525190591812 -0.011731699109077454
# Process ID: 542 [Epoch: 8, 272000/ 848835 points] total loss per batch: 0.08739
# Value: -0.15452538430690765 -0.012033646926283836
# Process ID: 542 [Epoch: 8, 273000/ 848835 points] total loss per batch: 0.09484
# Value: -0.16335541009902954 -0.013508305884897709
# Process ID: 542 [Epoch: 8, 274000/ 848835 points] total loss per batch: 0.09861
# Value: -0.6666666865348816 -0.012044671922922134
# Process ID: 542 [Epoch: 8, 275000/ 848835 points] total loss per batch: 0.08748
# Value: -0.19426049292087555 -0.01208655908703804
# Process ID: 542 [Epoch: 8, 276000/ 848835 points] total loss per batch: 0.09722
# Value: -0.04194260388612747 -0.01617405004799366
# Process ID: 542 [Epoch: 8, 277000/ 848835 points] total loss per batch: 0.10238
# Value: -0.15452538430690765 -0.0157188531011343
# Process ID: 542 [Epoch: 8, 278000/ 848835 points] total loss per batch: 0.08714
# Value: -0.06401766091585159 -0.017615467309951782
# Process ID: 542 [Epoch: 8, 279000/ 848835 points] total loss per batch: 0.08511
# Value: -0.14569535851478577 -0.02101818285882473
# Process ID: 542 [Epoch: 8, 280000/ 848835 points] total loss per batch: 0.08958
# Value: 0.12362030893564224 -0.02259109541773796
# Process ID: 542 [Epoch: 8, 281000/ 848835 points] total loss per batch: 0.09867
# Value: -0.10596026480197906 -0.01464846171438694
# Process ID: 542 [Epoch: 8, 282000/ 848835 points] total loss per batch: 0.09266
# Value: -0.2781457006931305 -0.012011541053652763
# Process ID: 542 [Epoch: 8, 283000/ 848835 points] total loss per batch: 0.09996
# Value: 0.0066225165501236916 -0.015706291422247887
# Process ID: 542 [Epoch: 8, 284000/ 848835 points] total loss per batch: 0.08508
# Value: -0.7770419716835022 -0.018727628514170647
# Process ID: 542 [Epoch: 8, 285000/ 848835 points] total loss per batch: 0.08324
# Value: -0.11037527769804001 -0.024137498810887337
# Process ID: 542 [Epoch: 8, 286000/ 848835 points] total loss per batch: 0.08452
# Value: -0.022075055167078972 -0.027115382254123688
# Process ID: 542 [Epoch: 8, 287000/ 848835 points] total loss per batch: 0.10067
# Value: -0.044150110334157944 -0.015979547053575516
# Process ID: 542 [Epoch: 8, 288000/ 848835 points] total loss per batch: 0.08096
# Value: -0.022075055167078972 -0.009630532003939152
# Process ID: 542 [Epoch: 8, 289000/ 848835 points] total loss per batch: 0.09836
# Value: -0.5518763661384583 -0.013682462275028229
# Process ID: 542 [Epoch: 8, 290000/ 848835 points] total loss per batch: 0.08268
# Value: -0.13686534762382507 -0.012582377530634403
# Process ID: 542 [Epoch: 8, 291000/ 848835 points] total loss per batch: 0.09056
# Value: -0.366445928812027 -0.012295984663069248
# Process ID: 542 [Epoch: 8, 292000/ 848835 points] total loss per batch: 0.09245
# Value: -0.17660044133663177 -0.01542168203741312
# Process ID: 542 [Epoch: 8, 293000/ 848835 points] total loss per batch: 0.10152
# Value: 0.01986755058169365 -0.01887226104736328
# Process ID: 542 [Epoch: 8, 294000/ 848835 points] total loss per batch: 0.08748
# Value: 0.01545253861695528 -0.02689886838197708
# Process ID: 542 [Epoch: 8, 295000/ 848835 points] total loss per batch: 0.08836
# Value: 0.3554084002971649 -0.027797702699899673
# Process ID: 542 [Epoch: 8, 296000/ 848835 points] total loss per batch: 0.08938
# Value: 0.3245033025741577 -0.023137642070651054
# Process ID: 542 [Epoch: 8, 297000/ 848835 points] total loss per batch: 0.10435
# Value: -0.1501103788614273 -0.01930036023259163
# Process ID: 542 [Epoch: 8, 298000/ 848835 points] total loss per batch: 0.08754
# Value: 0.06622516363859177 -0.018959803506731987
# Process ID: 542 [Epoch: 8, 299000/ 848835 points] total loss per batch: 0.09489
# Value: -0.13686534762382507 -0.0189405158162117
# Process ID: 542 [Epoch: 8, 300000/ 848835 points] total loss per batch: 0.08414
# Value: 0.695364236831665 -0.02124149724841118
# Process ID: 542 [Epoch: 8, 301000/ 848835 points] total loss per batch: 0.09172
# Value: -0.022075055167078972 -0.022686224430799484
# Process ID: 542 [Epoch: 8, 302000/ 848835 points] total loss per batch: 0.09968
# Value: 0.017660044133663177 -0.017878755927085876
# Process ID: 542 [Epoch: 8, 303000/ 848835 points] total loss per batch: 0.09347
# Value: -0.046357616782188416 -0.013391094282269478
# Process ID: 542 [Epoch: 8, 304000/ 848835 points] total loss per batch: 0.09524
# Value: 0.15673288702964783 -0.014416469261050224
# Process ID: 542 [Epoch: 8, 305000/ 848835 points] total loss per batch: 0.10335
# Value: 0.33112582564353943 -0.017085278406739235
# Process ID: 542 [Epoch: 8, 306000/ 848835 points] total loss per batch: 0.07422
# Value: 0.1434878557920456 -0.018657028675079346
# Process ID: 542 [Epoch: 8, 307000/ 848835 points] total loss per batch: 0.09242
# Value: -0.06401766091585159 -0.017142731696367264
# Process ID: 542 [Epoch: 8, 308000/ 848835 points] total loss per batch: 0.09551
# Value: -0.1986754983663559 -0.015088412910699844
# Process ID: 542 [Epoch: 8, 309000/ 848835 points] total loss per batch: 0.09958
# Value: 0.16556291282176971 -0.010931605473160744
# Process ID: 542 [Epoch: 8, 310000/ 848835 points] total loss per batch: 0.08349
# Value: 0.951434850692749 -0.011079510673880577
# Process ID: 542 [Epoch: 8, 311000/ 848835 points] total loss per batch: 0.09876
# Value: -0.6247240900993347 -0.01724300906062126
# Process ID: 542 [Epoch: 8, 312000/ 848835 points] total loss per batch: 0.09649
# Value: -0.125827819108963 -0.01967400312423706
# Process ID: 542 [Epoch: 8, 313000/ 848835 points] total loss per batch: 0.08737
# Value: -0.026490066200494766 -0.018199283629655838
# Process ID: 542 [Epoch: 8, 314000/ 848835 points] total loss per batch: 0.09164
# Value: -0.3002207577228546 -0.017537951469421387
# Process ID: 542 [Epoch: 8, 315000/ 848835 points] total loss per batch: 0.09516
# Value: 0.7019867300987244 -0.0161408931016922
# Process ID: 542 [Epoch: 8, 316000/ 848835 points] total loss per batch: 0.09836
# Value: -0.3090507686138153 -0.011855817399919033
# Process ID: 542 [Epoch: 8, 317000/ 848835 points] total loss per batch: 0.09531
# Value: -0.1832229644060135 -0.014587366953492165
# Process ID: 542 [Epoch: 8, 318000/ 848835 points] total loss per batch: 0.08729
# Value: -0.15231788158416748 -0.017139926552772522
# Process ID: 542 [Epoch: 8, 319000/ 848835 points] total loss per batch: 0.09848
# Value: -0.125827819108963 -0.01572626829147339
# Process ID: 542 [Epoch: 8, 320000/ 848835 points] total loss per batch: 0.09550
# Value: -0.22737306356430054 -0.013301574625074863
# Process ID: 542 [Epoch: 8, 321000/ 848835 points] total loss per batch: 0.10411
# Value: 0.028697572648525238 -0.006341402884572744
# Process ID: 542 [Epoch: 8, 322000/ 848835 points] total loss per batch: 0.09576
# Value: 0.04194260388612747 -0.004252961371093988
# Process ID: 542 [Epoch: 8, 323000/ 848835 points] total loss per batch: 0.09830
# Value: -0.8388521075248718 -0.004556688945740461
# Process ID: 542 [Epoch: 8, 324000/ 848835 points] total loss per batch: 0.09304
# Value: -0.23620308935642242 -0.0023604659363627434
# Process ID: 542 [Epoch: 8, 325000/ 848835 points] total loss per batch: 0.09998
# Value: -0.16997791826725006 -0.005543714389204979
# Process ID: 542 [Epoch: 8, 326000/ 848835 points] total loss per batch: 0.09804
# Value: 0.40838852524757385 -0.008762946352362633
# Process ID: 542 [Epoch: 8, 327000/ 848835 points] total loss per batch: 0.07892
# Value: -0.11037527769804001 -0.014623623341321945
# Process ID: 542 [Epoch: 8, 328000/ 848835 points] total loss per batch: 0.09044
# Value: -0.5209712982177734 -0.017550965771079063
# Process ID: 542 [Epoch: 8, 329000/ 848835 points] total loss per batch: 0.09314
# Value: 0.20529800653457642 -0.0160125270485878
# Process ID: 542 [Epoch: 8, 330000/ 848835 points] total loss per batch: 0.09466
# Value: -0.08830022066831589 -0.0139143206179142
# Process ID: 542 [Epoch: 8, 331000/ 848835 points] total loss per batch: 0.09373
# Value: 0.09050772339105606 -0.012136725708842278
# Process ID: 542 [Epoch: 8, 332000/ 848835 points] total loss per batch: 0.10574
# Value: -0.9646798968315125 -0.010375584475696087
# Process ID: 542 [Epoch: 8, 333000/ 848835 points] total loss per batch: 0.10012
# Value: -0.06181015446782112 -0.008898182772099972
# Process ID: 542 [Epoch: 8, 334000/ 848835 points] total loss per batch: 0.08795
# Value: -0.06843267381191254 -0.019404586404561996
# Process ID: 542 [Epoch: 8, 335000/ 848835 points] total loss per batch: 0.08182
# Value: 0.094922736287117 -0.024070804938673973
# Process ID: 542 [Epoch: 8, 336000/ 848835 points] total loss per batch: 0.08862
# Value: 0.2715231776237488 -0.02506747655570507
# Process ID: 542 [Epoch: 8, 337000/ 848835 points] total loss per batch: 0.09853
# Value: -0.16997791826725006 -0.022565795108675957
# Process ID: 542 [Epoch: 8, 338000/ 848835 points] total loss per batch: 0.09623
# Value: -0.10375276207923889 -0.0144541896879673
# Process ID: 542 [Epoch: 8, 339000/ 848835 points] total loss per batch: 0.08628
# Value: -0.06181015446782112 -0.009290517307817936
# Process ID: 542 [Epoch: 8, 340000/ 848835 points] total loss per batch: 0.08594
# Value: -0.16556291282176971 -0.011258803308010101
# Process ID: 542 [Epoch: 8, 341000/ 848835 points] total loss per batch: 0.08664
# Value: 0.2141280323266983 -0.016967296600341797
# Process ID: 542 [Epoch: 8, 342000/ 848835 points] total loss per batch: 0.10188
# Value: 0.04856512323021889 -0.016976945102214813
# Process ID: 542 [Epoch: 8, 343000/ 848835 points] total loss per batch: 0.08766
# Value: -0.33112582564353943 -0.017982447519898415
# Process ID: 542 [Epoch: 8, 344000/ 848835 points] total loss per batch: 0.09238
# Value: 0.19205297529697418 -0.015649698674678802
# Process ID: 542 [Epoch: 8, 345000/ 848835 points] total loss per batch: 0.09795
# Value: 0.8631346821784973 -0.01714036427438259
# Process ID: 542 [Epoch: 8, 346000/ 848835 points] total loss per batch: 0.09961
# Value: -0.1501103788614273 -0.014600560069084167
# Process ID: 542 [Epoch: 8, 347000/ 848835 points] total loss per batch: 0.10401
# Value: -0.14790287613868713 -0.009536574594676495
# Process ID: 542 [Epoch: 8, 348000/ 848835 points] total loss per batch: 0.10531
# Value: 0.33774834871292114 -0.01273467019200325
# Process ID: 542 [Epoch: 8, 349000/ 848835 points] total loss per batch: 0.09539
# Value: 0.046357616782188416 -0.013282074593007565
# Process ID: 542 [Epoch: 8, 350000/ 848835 points] total loss per batch: 0.09463
# Value: 0.002207505516707897 -0.01840304583311081
# Process ID: 542 [Epoch: 8, 351000/ 848835 points] total loss per batch: 0.08749
# Value: -0.01545253861695528 -0.023159248754382133
# Process ID: 542 [Epoch: 8, 352000/ 848835 points] total loss per batch: 0.09140
# Value: 0.026490066200494766 -0.02823271043598652
# Process ID: 542 [Epoch: 8, 353000/ 848835 points] total loss per batch: 0.09388
# Value: -0.11037527769804001 -0.02882670983672142
# Process ID: 542 [Epoch: 8, 354000/ 848835 points] total loss per batch: 0.10062
# Value: -0.0794702023267746 -0.024792315438389778
# Process ID: 542 [Epoch: 8, 355000/ 848835 points] total loss per batch: 0.09825
# Value: -0.125827819108963 -0.018229147419333458
# Process ID: 542 [Epoch: 8, 356000/ 848835 points] total loss per batch: 0.09649
# Value: -0.06401766091585159 -0.016496002674102783
# Process ID: 542 [Epoch: 8, 357000/ 848835 points] total loss per batch: 0.10445
# Value: 0.14790287613868713 -0.01488994900137186
# Process ID: 542 [Epoch: 8, 358000/ 848835 points] total loss per batch: 0.10237
# Value: -0.035320088267326355 -0.016197718679904938
# Process ID: 542 [Epoch: 8, 359000/ 848835 points] total loss per batch: 0.09416
# Value: 0.09713024646043777 -0.014853882603347301
# Process ID: 542 [Epoch: 8, 360000/ 848835 points] total loss per batch: 0.09157
# Value: -0.15452538430690765 -0.018871037289500237
# Process ID: 542 [Epoch: 8, 361000/ 848835 points] total loss per batch: 0.08204
# Value: -0.13907285034656525 -0.027873052284121513
# Process ID: 542 [Epoch: 8, 362000/ 848835 points] total loss per batch: 0.09594
# Value: -0.002207505516707897 -0.028026403859257698
# Process ID: 542 [Epoch: 8, 363000/ 848835 points] total loss per batch: 0.10096
# Value: 0.094922736287117 -0.022254247218370438
# Process ID: 542 [Epoch: 8, 364000/ 848835 points] total loss per batch: 0.09626
# Value: 0.8675496578216553 -0.005978060886263847
# Process ID: 542 [Epoch: 8, 365000/ 848835 points] total loss per batch: 0.10388
# Value: -0.3002207577228546 0.0010019721230491996
# Process ID: 542 [Epoch: 8, 366000/ 848835 points] total loss per batch: 0.09020
# Value: 0.08167770504951477 -0.0018339366652071476
# Process ID: 542 [Epoch: 8, 367000/ 848835 points] total loss per batch: 0.08876
# Value: -0.2450331151485443 -0.009067080914974213
# Process ID: 542 [Epoch: 8, 368000/ 848835 points] total loss per batch: 0.09966
# Value: 0.13907285034656525 -0.013759280554950237
# Process ID: 542 [Epoch: 8, 369000/ 848835 points] total loss per batch: 0.09740
# Value: -0.16114790737628937 -0.015501497313380241
# Process ID: 542 [Epoch: 8, 370000/ 848835 points] total loss per batch: 0.10317
# Value: -0.3399558365345001 -0.010030288249254227
# Process ID: 542 [Epoch: 8, 371000/ 848835 points] total loss per batch: 0.08846
# Value: -0.16997791826725006 -0.005769716575741768
# Process ID: 542 [Epoch: 8, 372000/ 848835 points] total loss per batch: 0.09386
# Value: 0.29801324009895325 -0.006861846894025803
# Process ID: 542 [Epoch: 8, 373000/ 848835 points] total loss per batch: 0.10181
# Value: 0.16997791826725006 -0.011592675000429153
# Process ID: 542 [Epoch: 8, 374000/ 848835 points] total loss per batch: 0.08949
# Value: 0.15673288702964783 -0.014081576839089394
# Process ID: 542 [Epoch: 8, 375000/ 848835 points] total loss per batch: 0.09299
# Value: -0.22516556084156036 -0.01850022003054619
# Process ID: 542 [Epoch: 8, 376000/ 848835 points] total loss per batch: 0.09939
# Value: 0.6004415154457092 -0.022003566846251488
# Process ID: 542 [Epoch: 8, 377000/ 848835 points] total loss per batch: 0.09583
# Value: 0.14569535851478577 -0.022023897618055344
# Process ID: 542 [Epoch: 8, 378000/ 848835 points] total loss per batch: 0.09123
# Value: -0.1192052960395813 -0.01975851319730282
# Process ID: 542 [Epoch: 8, 379000/ 848835 points] total loss per batch: 0.09448
# Value: 0.028697572648525238 -0.016834968701004982
# Process ID: 542 [Epoch: 8, 380000/ 848835 points] total loss per batch: 0.07976
# Value: -0.03311258181929588 -0.02062433958053589
# Process ID: 542 [Epoch: 8, 381000/ 848835 points] total loss per batch: 0.10337
# Value: -0.08167770504951477 -0.019550565630197525
# Process ID: 542 [Epoch: 8, 382000/ 848835 points] total loss per batch: 0.08930
# Value: -0.057395145297050476 -0.01592664048075676
# Process ID: 542 [Epoch: 8, 383000/ 848835 points] total loss per batch: 0.10022
# Value: 0.6754966974258423 -0.007617630530148745
# Process ID: 542 [Epoch: 8, 384000/ 848835 points] total loss per batch: 0.09565
# Value: -0.14790287613868713 -0.0035197751130908728
# Process ID: 542 [Epoch: 8, 385000/ 848835 points] total loss per batch: 0.07609
# Value: -0.07726269215345383 -0.01049778237938881
# Process ID: 542 [Epoch: 8, 386000/ 848835 points] total loss per batch: 0.09369
# Value: -0.07505518943071365 -0.026171043515205383
# Process ID: 542 [Epoch: 8, 387000/ 848835 points] total loss per batch: 0.09851
# Value: -0.01545253861695528 -0.03163006156682968
# Process ID: 542 [Epoch: 8, 388000/ 848835 points] total loss per batch: 0.10238
# Value: -0.16556291282176971 -0.02534499764442444
# Process ID: 542 [Epoch: 8, 389000/ 848835 points] total loss per batch: 0.10460
# Value: -0.7902869582176208 -0.024318132549524307
# Process ID: 542 [Epoch: 8, 390000/ 848835 points] total loss per batch: 0.09297
# Value: -0.10596026480197906 -0.021806303411722183
# Process ID: 542 [Epoch: 8, 391000/ 848835 points] total loss per batch: 0.09003
# Value: 0.03311258181929588 -0.018775219097733498
# Process ID: 542 [Epoch: 8, 392000/ 848835 points] total loss per batch: 0.09067
# Value: -0.0397351011633873 -0.016676533967256546
# Process ID: 542 [Epoch: 8, 393000/ 848835 points] total loss per batch: 0.09514
# Value: -0.028697572648525238 -0.014919893816113472
# Process ID: 542 [Epoch: 8, 394000/ 848835 points] total loss per batch: 0.11404
# Value: 0.017660044133663177 -0.011257370933890343
# Process ID: 542 [Epoch: 8, 395000/ 848835 points] total loss per batch: 0.09287
# Value: -0.14569535851478577 -0.011905902996659279
# Process ID: 542 [Epoch: 8, 396000/ 848835 points] total loss per batch: 0.09622
# Value: -0.026490066200494766 -0.01790577359497547
# Process ID: 542 [Epoch: 8, 397000/ 848835 points] total loss per batch: 0.07899
# Value: -0.022075055167078972 -0.021585650742053986
# Process ID: 542 [Epoch: 8, 398000/ 848835 points] total loss per batch: 0.09844
# Value: -0.11699779331684113 -0.019808460026979446
# Process ID: 542 [Epoch: 8, 399000/ 848835 points] total loss per batch: 0.09097
# Value: -0.41721853613853455 -0.012829187326133251
# Process ID: 542 [Epoch: 8, 400000/ 848835 points] total loss per batch: 0.09243
# Value: -0.07505518943071365 -0.007276819087564945
# Process ID: 542 [Epoch: 8, 401000/ 848835 points] total loss per batch: 0.08902
# Value: 0.759381890296936 -0.0079558240249753
# Process ID: 542 [Epoch: 8, 402000/ 848835 points] total loss per batch: 0.09763
# Value: -0.10154525190591812 -0.009738202206790447
# Process ID: 542 [Epoch: 8, 403000/ 848835 points] total loss per batch: 0.08790
# Value: 0.251655638217926 -0.013239236548542976
# Process ID: 542 [Epoch: 8, 404000/ 848835 points] total loss per batch: 0.10600
# Value: -0.20971302688121796 -0.01386494655162096
# Process ID: 542 [Epoch: 8, 405000/ 848835 points] total loss per batch: 0.09747
# Value: -0.002207505516707897 -0.011715344153344631
# Process ID: 542 [Epoch: 8, 406000/ 848835 points] total loss per batch: 0.10068
# Value: -0.10596026480197906 -0.009795654565095901
# Process ID: 542 [Epoch: 8, 407000/ 848835 points] total loss per batch: 0.09183
# Value: -0.06181015446782112 -0.011280172504484653
# Process ID: 542 [Epoch: 8, 408000/ 848835 points] total loss per batch: 0.09685
# Value: 0.6247240900993347 -0.011825865134596825
# Process ID: 542 [Epoch: 8, 409000/ 848835 points] total loss per batch: 0.08870
# Value: 0.7748344540596008 -0.007855287753045559
# Process ID: 542 [Epoch: 8, 410000/ 848835 points] total loss per batch: 0.08792
# Value: -0.0397351011633873 -0.009890061803162098
# Process ID: 542 [Epoch: 8, 411000/ 848835 points] total loss per batch: 0.09251
# Value: 0.7461368441581726 -0.011532992124557495
# Process ID: 542 [Epoch: 8, 412000/ 848835 points] total loss per batch: 0.10208
# Value: 0.10154525190591812 -0.008456166833639145
# Process ID: 542 [Epoch: 8, 413000/ 848835 points] total loss per batch: 0.09492
# Value: -0.09271523356437683 -0.008207328617572784
# Process ID: 542 [Epoch: 8, 414000/ 848835 points] total loss per batch: 0.09625
# Value: -0.1192052960395813 -0.009783685207366943
# Process ID: 542 [Epoch: 8, 415000/ 848835 points] total loss per batch: 0.08848
# Value: 0.42384105920791626 -0.015050162561237812
# Process ID: 542 [Epoch: 8, 416000/ 848835 points] total loss per batch: 0.08916
# Value: -0.12141280621290207 -0.016762740910053253
# Process ID: 542 [Epoch: 8, 417000/ 848835 points] total loss per batch: 0.08923
# Value: 0.12362030893564224 -0.015405327081680298
# Process ID: 542 [Epoch: 8, 418000/ 848835 points] total loss per batch: 0.09048
# Value: -0.09713024646043777 -0.011926311999559402
# Process ID: 542 [Epoch: 8, 419000/ 848835 points] total loss per batch: 0.09466
# Value: 0.3907284736633301 -0.011217162944376469
# ...
# Process ID: 542 [Epoch: 10, 727000/ 848835 points] total loss per batch: 0.10234
# Value: -0.04194260388612747 -0.012393098324537277
# Process ID: 542 [Epoch: 10, 728000/ 848835 points] total loss per batch: 0.09611
# Value: 0.8807947039604187 -0.011259899474680424
# Process ID: 542 [Epoch: 10, 729000/ 848835 points] total loss per batch: 0.09052
# Value: -0.026490066200494766 -0.010827740654349327
# Process ID: 542 [Epoch: 10, 730000/ 848835 points] total loss per batch: 0.10027
# Value: -0.04194260388612747 -0.012091316282749176
# Process ID: 542 [Epoch: 10, 731000/ 848835 points] total loss per batch: 0.09550
# Value: 0.2229580581188202 -0.016209881752729416
# Process ID: 542 [Epoch: 10, 732000/ 848835 points] total loss per batch: 0.09863
# Value: -0.125827819108963 -0.01708526350557804
# Process ID: 542 [Epoch: 10, 733000/ 848835 points] total loss per batch: 0.08708
# Value: -0.189845472574234 -0.01820085383951664
# Process ID: 542 [Epoch: 10, 734000/ 848835 points] total loss per batch: 0.09755
# Value: 0.10816776752471924 -0.018286939710378647
# Process ID: 542 [Epoch: 10, 735000/ 848835 points] total loss per batch: 0.10020
# Value: -0.09050772339105606 -0.013490173034369946
# Process ID: 542 [Epoch: 10, 736000/ 848835 points] total loss per batch: 0.10046
# Value: -0.028697572648525238 -0.010747276246547699
# Process ID: 542 [Epoch: 10, 737000/ 848835 points] total loss per batch: 0.10224
# Value: -0.1501103788614273 -0.0024026278406381607
# Process ID: 542 [Epoch: 10, 738000/ 848835 points] total loss per batch: 0.08671
# Value: -0.09713024646043777 0.0013922443613409996
# Process ID: 542 [Epoch: 10, 739000/ 848835 points] total loss per batch: 0.08831
# Value: -0.09271523356437683 2.433741610730067e-05
# Process ID: 542 [Epoch: 10, 740000/ 848835 points] total loss per batch: 0.09522
# Value: -0.11699779331684113 -0.008338958956301212
# Process ID: 542 [Epoch: 10, 741000/ 848835 points] total loss per batch: 0.08847
# Value: -0.11258278042078018 -0.0166135486215353
# Process ID: 542 [Epoch: 10, 742000/ 848835 points] total loss per batch: 0.09177
# Value: -0.046357616782188416 -0.01964837871491909
# Process ID: 542 [Epoch: 10, 743000/ 848835 points] total loss per batch: 0.09799
# Value: -0.21633553504943848 -0.01824132353067398
# Process ID: 542 [Epoch: 10, 744000/ 848835 points] total loss per batch: 0.09142
# Value: 0.03752759471535683 -0.017015650868415833
# Process ID: 542 [Epoch: 10, 745000/ 848835 points] total loss per batch: 0.08710
# Value: -0.15452538430690765 -0.01742134988307953
# Process ID: 542 [Epoch: 10, 746000/ 848835 points] total loss per batch: 0.09248
# Value: -0.022075055167078972 -0.01976451277732849
# Process ID: 542 [Epoch: 10, 747000/ 848835 points] total loss per batch: 0.09565
# Value: -0.14569535851478577 -0.01858058199286461
# Process ID: 542 [Epoch: 10, 748000/ 848835 points] total loss per batch: 0.10536
# Value: 0.1743929386138916 -0.020729713141918182
# Process ID: 542 [Epoch: 10, 749000/ 848835 points] total loss per batch: 0.09348
# Value: -0.1589404046535492 -0.01855682022869587
# Process ID: 542 [Epoch: 10, 750000/ 848835 points] total loss per batch: 0.09103
# Value: 0.7571743726730347 -0.019770167768001556
# Process ID: 542 [Epoch: 10, 751000/ 848835 points] total loss per batch: 0.09792
# Value: -0.10375276207923889 -0.01897679828107357
# Process ID: 542 [Epoch: 10, 752000/ 848835 points] total loss per batch: 0.09222
# Value: 0.9889624714851379 -0.017957134172320366
# Process ID: 542 [Epoch: 10, 753000/ 848835 points] total loss per batch: 0.08444
# Value: 0.32008829712867737 -0.018932277336716652
# Process ID: 542 [Epoch: 10, 754000/ 848835 points] total loss per batch: 0.10222
# Value: -0.004415011033415794 -0.01533089391887188
# Process ID: 542 [Epoch: 10, 755000/ 848835 points] total loss per batch: 0.08913
# Value: -0.04194260388612747 -0.009269669651985168
# Process ID: 542 [Epoch: 10, 756000/ 848835 points] total loss per batch: 0.09484
# Value: -0.1501103788614273 -0.008639924228191376
# Process ID: 542 [Epoch: 10, 757000/ 848835 points] total loss per batch: 0.10251
# Value: 0.33774834871292114 -0.007050099782645702
# Process ID: 542 [Epoch: 10, 758000/ 848835 points] total loss per batch: 0.09568
# Value: -0.2295805811882019 -0.009514223784208298
# Process ID: 542 [Epoch: 10, 759000/ 848835 points] total loss per batch: 0.10466
# Value: 0.47902870178222656 -0.012637589126825333
# Process ID: 542 [Epoch: 10, 760000/ 848835 points] total loss per batch: 0.10119
# Value: -0.17660044133663177 -0.016682855784893036
# Process ID: 542 [Epoch: 10, 761000/ 848835 points] total loss per batch: 0.08991
# Value: -0.09050772339105606 -0.016086885705590248
# Process ID: 542 [Epoch: 10, 762000/ 848835 points] total loss per batch: 0.09069
# Value: -0.14128035306930542 -0.017762893810868263
# Process ID: 542 [Epoch: 10, 763000/ 848835 points] total loss per batch: 0.09518
# Value: -0.15673288702964783 -0.015330721624195576
# Process ID: 542 [Epoch: 10, 764000/ 848835 points] total loss per batch: 0.10246
# Value: -0.008830022066831589 -0.008083685301244259
# Process ID: 542 [Epoch: 10, 765000/ 848835 points] total loss per batch: 0.09474
# Value: -0.12141280621290207 -0.003357239067554474
# Process ID: 542 [Epoch: 10, 766000/ 848835 points] total loss per batch: 0.08524
# Value: 0.03090507723391056 -0.004496092442423105
# Process ID: 542 [Epoch: 10, 767000/ 848835 points] total loss per batch: 0.09731
# Value: 0.9713024497032166 -0.010601055808365345
# Process ID: 542 [Epoch: 10, 768000/ 848835 points] total loss per batch: 0.08971
# Value: -0.6070640087127686 -0.011880360543727875
# Process ID: 542 [Epoch: 10, 769000/ 848835 points] total loss per batch: 0.09774
# Value: 0.6821191906929016 -0.015328570269048214
# Process ID: 542 [Epoch: 10, 770000/ 848835 points] total loss per batch: 0.10011
# Value: -0.16997791826725006 -0.017900148406624794
# Process ID: 542 [Epoch: 10, 771000/ 848835 points] total loss per batch: 0.09339
# Value: 0.1986754983663559 -0.02114623412489891
# Process ID: 542 [Epoch: 10, 772000/ 848835 points] total loss per batch: 0.09686
# Value: 0.812362015247345 -0.019759614020586014
# Process ID: 542 [Epoch: 10, 773000/ 848835 points] total loss per batch: 0.09339
# Value: -0.07064017653465271 -0.015847114846110344
# Process ID: 542 [Epoch: 10, 774000/ 848835 points] total loss per batch: 0.08693
# Value: -0.2295805811882019 -0.018105052411556244
# Process ID: 542 [Epoch: 10, 775000/ 848835 points] total loss per batch: 0.09644
# Value: -0.03752759471535683 -0.02047470211982727
# Process ID: 542 [Epoch: 10, 776000/ 848835 points] total loss per batch: 0.09188
# Value: 0.1346578299999237 -0.01872824691236019
# Process ID: 542 [Epoch: 10, 777000/ 848835 points] total loss per batch: 0.09518
# Value: -0.06843267381191254 -0.011601160280406475
# Process ID: 542 [Epoch: 10, 778000/ 848835 points] total loss per batch: 0.09419
# Value: 0.6799116730690002 -0.008428647182881832
# Process ID: 542 [Epoch: 10, 779000/ 848835 points] total loss per batch: 0.08674
# Value: -0.15673288702964783 -0.011521938256919384
# Process ID: 542 [Epoch: 10, 780000/ 848835 points] total loss per batch: 0.09495
# Value: -0.10816776752471924 -0.012419195845723152
# Process ID: 542 [Epoch: 10, 781000/ 848835 points] total loss per batch: 0.09481
# Value: -0.11037527769804001 -0.01758899912238121
# Process ID: 542 [Epoch: 10, 782000/ 848835 points] total loss per batch: 0.08839
# Value: -0.2295805811882019 -0.016428081318736076
# Process ID: 542 [Epoch: 10, 783000/ 848835 points] total loss per batch: 0.09263
# Value: 1.0 -0.016237173229455948
# Process ID: 542 [Epoch: 10, 784000/ 848835 points] total loss per batch: 0.09862
# Value: -0.35320088267326355 -0.017487339675426483
# Process ID: 542 [Epoch: 10, 785000/ 848835 points] total loss per batch: 0.09916
# Value: 0.7814569473266602 -0.015677619725465775
# Process ID: 542 [Epoch: 10, 786000/ 848835 points] total loss per batch: 0.08325
# Value: -0.04856512323021889 -0.015242984518408775
# Process ID: 542 [Epoch: 10, 787000/ 848835 points] total loss per batch: 0.08320
# Value: -0.08167770504951477 -0.021866243332624435
# Process ID: 542 [Epoch: 10, 788000/ 848835 points] total loss per batch: 0.09215
# Value: -0.20529800653457642 -0.02648484893143177
# Process ID: 542 [Epoch: 10, 789000/ 848835 points] total loss per batch: 0.09241
# Value: 0.13686534762382507 -0.029113350436091423
# Process ID: 542 [Epoch: 10, 790000/ 848835 points] total loss per batch: 0.09648
# Value: -0.1743929386138916 -0.019617749378085136
# Process ID: 542 [Epoch: 10, 791000/ 848835 points] total loss per batch: 0.08084
# Value: 0.017660044133663177 -0.016649313271045685
# Process ID: 542 [Epoch: 10, 792000/ 848835 points] total loss per batch: 0.09837
# Value: -0.28918322920799255 -0.018669934943318367
# Process ID: 542 [Epoch: 10, 793000/ 848835 points] total loss per batch: 0.08846
# Value: -0.12362030893564224 -0.021233541890978813
# Process ID: 542 [Epoch: 10, 794000/ 848835 points] total loss per batch: 0.09725
# Value: 0.27373069524765015 -0.020307833328843117
# Process ID: 542 [Epoch: 10, 795000/ 848835 points] total loss per batch: 0.09598
# Value: -0.18101544678211212 -0.015398628078401089
# Process ID: 542 [Epoch: 10, 796000/ 848835 points] total loss per batch: 0.09436
# Value: 0.7814569473266602 -0.011100332252681255
# Process ID: 542 [Epoch: 10, 797000/ 848835 points] total loss per batch: 0.09710
# Value: -0.14128035306930542 -0.008410739712417126
# Process ID: 542 [Epoch: 10, 798000/ 848835 points] total loss per batch: 0.09131
# Value: 0.4216335415840149 -0.012252628803253174
# Process ID: 542 [Epoch: 10, 799000/ 848835 points] total loss per batch: 0.09078
# Value: -0.1501103788614273 -0.013093621470034122
# Process ID: 542 [Epoch: 10, 800000/ 848835 points] total loss per batch: 0.09167
# Value: 0.06401766091585159 -0.01473822258412838
# Process ID: 542 [Epoch: 10, 801000/ 848835 points] total loss per batch: 0.08584
# Value: -0.08609271794557571 -0.019599270075559616
# Process ID: 542 [Epoch: 10, 802000/ 848835 points] total loss per batch: 0.10026
# Value: -0.06401766091585159 -0.022107327356934547
# Process ID: 542 [Epoch: 10, 803000/ 848835 points] total loss per batch: 0.09332
# Value: -0.06622516363859177 -0.02581936866044998
# Process ID: 542 [Epoch: 10, 804000/ 848835 points] total loss per batch: 0.09191
# Value: -0.21192052960395813 -0.02168400213122368
# Process ID: 542 [Epoch: 10, 805000/ 848835 points] total loss per batch: 0.09700
# Value: 0.028697572648525238 -0.016406379640102386
# Process ID: 542 [Epoch: 10, 806000/ 848835 points] total loss per batch: 0.10142
# Value: -0.01986755058169365 -0.009619861841201782
# Process ID: 542 [Epoch: 10, 807000/ 848835 points] total loss per batch: 0.10589
# Value: -0.09271523356437683 -0.0045370436273515224
# Process ID: 542 [Epoch: 10, 808000/ 848835 points] total loss per batch: 0.09811
# Value: 0.06401766091585159 -0.009800760075449944
# Process ID: 542 [Epoch: 10, 809000/ 848835 points] total loss per batch: 0.09347
# Value: -0.13245032727718353 -0.016790233552455902
# Process ID: 542 [Epoch: 10, 810000/ 848835 points] total loss per batch: 0.09976
# Value: 0.3267108201980591 -0.021091027185320854
# Process ID: 542 [Epoch: 10, 811000/ 848835 points] total loss per batch: 0.09053
# Value: 0.008830022066831589 -0.015688804909586906
# Process ID: 542 [Epoch: 10, 812000/ 848835 points] total loss per batch: 0.10050
# Value: -0.10154525190591812 -0.020143434405326843
# Process ID: 542 [Epoch: 10, 813000/ 848835 points] total loss per batch: 0.10206
# Value: 0.29801324009895325 -0.018868349492549896
# Process ID: 542 [Epoch: 10, 814000/ 848835 points] total loss per batch: 0.09901
# Value: -0.5231788158416748 -0.010508023202419281
# Process ID: 542 [Epoch: 10, 815000/ 848835 points] total loss per batch: 0.10723
# Value: -0.04194260388612747 -0.0036597929429262877
# Process ID: 542 [Epoch: 10, 816000/ 848835 points] total loss per batch: 0.09088
# Value: -0.1192052960395813 -0.007256439886987209
# Process ID: 542 [Epoch: 10, 817000/ 848835 points] total loss per batch: 0.09462
# Value: -0.22075055539608002 -0.015530123375356197
# Process ID: 542 [Epoch: 10, 818000/ 848835 points] total loss per batch: 0.09539
# Value: -0.3333333432674408 -0.018983477726578712
# Process ID: 542 [Epoch: 10, 819000/ 848835 points] total loss per batch: 0.10470
# Value: -0.32891830801963806 -0.014436144381761551
# Process ID: 542 [Epoch: 10, 820000/ 848835 points] total loss per batch: 0.10279
# Value: -0.1192052960395813 -0.008629968389868736
# Process ID: 542 [Epoch: 10, 821000/ 848835 points] total loss per batch: 0.09592
# Value: -0.4216335415840149 -0.0042552282102406025
# Process ID: 542 [Epoch: 10, 822000/ 848835 points] total loss per batch: 0.09082
# Value: -0.0397351011633873 -0.008114372380077839
# Process ID: 542 [Epoch: 10, 823000/ 848835 points] total loss per batch: 0.09525
# Value: -0.2295805811882019 -0.011278009973466396
# Process ID: 542 [Epoch: 10, 824000/ 848835 points] total loss per batch: 0.10406
# Value: -0.14569535851478577 -0.012255463749170303
# Process ID: 542 [Epoch: 10, 825000/ 848835 points] total loss per batch: 0.08416
# Value: -0.08388520777225494 -0.009924997575581074
# Process ID: 542 [Epoch: 10, 826000/ 848835 points] total loss per batch: 0.09564
# Value: 0.04856512323021889 -0.010971032083034515
# Process ID: 542 [Epoch: 10, 827000/ 848835 points] total loss per batch: 0.09129
# Value: -0.035320088267326355 -0.010844994336366653
# Process ID: 542 [Epoch: 10, 828000/ 848835 points] total loss per batch: 0.09314
# Value: -0.3576158881187439 -0.01169922761619091
# Process ID: 542 [Epoch: 10, 829000/ 848835 points] total loss per batch: 0.08548
# Value: 0.8432670831680298 -0.013878780417144299
# Process ID: 542 [Epoch: 10, 830000/ 848835 points] total loss per batch: 0.08891
# Value: -0.50772625207901 -0.01359561551362276
# Process ID: 542 [Epoch: 10, 831000/ 848835 points] total loss per batch: 0.09790
# Value: -0.25827813148498535 -0.013932228088378906
# Process ID: 542 [Epoch: 10, 832000/ 848835 points] total loss per batch: 0.09621
# Value: -0.026490066200494766 -0.008119856007397175
# Process ID: 542 [Epoch: 10, 833000/ 848835 points] total loss per batch: 0.09564
# Value: -0.017660044133663177 -0.004792527761310339
# Process ID: 542 [Epoch: 10, 834000/ 848835 points] total loss per batch: 0.09461
# Value: -0.10375276207923889 -0.009107900783419609
# Process ID: 542 [Epoch: 10, 835000/ 848835 points] total loss per batch: 0.09245
# Value: 0.27373069524765015 -0.016629323363304138
# Process ID: 542 [Epoch: 10, 836000/ 848835 points] total loss per batch: 0.09320
# Value: 0.12362030893564224 -0.01619880087673664
# Process ID: 542 [Epoch: 10, 837000/ 848835 points] total loss per batch: 0.09466
# Value: -5.551115123125783e-17 -0.014363482594490051
# Process ID: 542 [Epoch: 10, 838000/ 848835 points] total loss per batch: 0.09442
# Value: -0.2295805811882019 -0.00980929471552372
# Process ID: 542 [Epoch: 10, 839000/ 848835 points] total loss per batch: 0.08545
# Value: -0.10375276207923889 -0.00960108544677496
# Process ID: 542 [Epoch: 10, 840000/ 848835 points] total loss per batch: 0.09453
# Value: -0.2847682237625122 -0.014721821062266827
# Process ID: 542 [Epoch: 10, 841000/ 848835 points] total loss per batch: 0.10169
# Value: -0.3487858772277832 -0.013641679659485817
# Process ID: 542 [Epoch: 10, 842000/ 848835 points] total loss per batch: 0.09108
# Value: -0.125827819108963 -0.012834028340876102
# Process ID: 542 [Epoch: 10, 843000/ 848835 points] total loss per batch: 0.10867
# Value: 0.1192052960395813 -0.012491131201386452
# Process ID: 542 [Epoch: 10, 844000/ 848835 points] total loss per batch: 0.10341
# Value: -0.046357616782188416 -0.014251688495278358
# Process ID: 542 [Epoch: 10, 845000/ 848835 points] total loss per batch: 0.10415
# Value: -0.3267108201980591 -0.016310222446918488
# Process ID: 542 [Epoch: 10, 846000/ 848835 points] total loss per batch: 0.09792
# Value: 0.002207505516707897 -0.009082430973649025
# Process ID: 542 [Epoch: 10, 847000/ 848835 points] total loss per batch: 0.09069
# Value: -0.06622516363859177 -0.010984745807945728
# Process ID: 542 [Epoch: 10, 848000/ 848835 points] total loss per batch: 0.08624
# Value: -0.16997791826725006 -0.019879480823874474
# Validation MSE Loss: 0.04411
# Current learning rate: 0.002
# Early stopping! No improvement in validation loss for 5 epochs.

# %%
# loss per epoch of the PlainNet3_Apr1 model
# trained on 1M inputs
# 100k validation
# outlier removal on both training and validation sets
# early stopping on validation loss

# trainloss_PlainNet3_Mar31 = []
# valloss_PlainNet1_Mar31 = []
# lr_PlainNet1_Mar31 = []
# for i in range(50):
#   try:
losses = np.load("/content/drive/MyDrive/PlainNet3_Apr1/PlainNet3_Apr1_losses_per_epoch_epoch10.npz")
trainloss_PlainNet3_Apr1 = losses['train_loss']
valloss_PlainNet3_Apr1 = losses['val_loss']
lr_PlainNet3_Apr1 = losses['lr']
  # except:
  #   continue

# %%
# plot loss per epoch
fig, axs = plt.subplots(1, 3, figsize=(12, 5))

axs[0].scatter([e for e in range(1, len(trainloss_PlainNet3_Apr1)+1)], trainloss_PlainNet3_Apr1)
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Loss per batch")
axs[0].set_title("Training Loss vs Epoch")

axs[1].scatter([e for e in range(1, len(valloss_PlainNet3_Apr1)+1)], valloss_PlainNet3_Apr1)
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss per batch")
axs[1].set_title("Validation Loss vs Epoch")

axs[2].scatter([e for e in range(1, len(lr_PlainNet3_Apr1)+1)], lr_PlainNet3_Apr1)
axs[2].set_xlabel("Epoch")
axs[2].set_ylabel("Loss per batch")
axs[2].set_title("Learning Rate vs Epoch")

plt.tight_layout()
plt.show()
